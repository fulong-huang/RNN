# %%
import numpy as np


# To read the training data and make a vocabulary and dictiornary to index the chars
class DataReader:
    def __init__(self, path, seq_length, progress_len=5, max_trace_len = 200):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        print(chars)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length
        self.progress_len = progress_len
        self.max_trace_len = max_trace_len

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.progress_len
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer, start new epoch
            self.pointer = -1
        trace_start = 0
        if self.pointer > self.max_trace_len:
            trace_start = self.pointer - self.max_trace_len
        prev_input = [self.char_to_ix[ch] for ch in self.data[trace_start:input_start]]
        return prev_input, inputs, targets

    def new_epoch(self):
        return self.pointer == -1
    def start_epoch(self):
        self.pointer = 0

    def close(self):
        self.fp.close()

# %%
  
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, start, inputs):
        xs, hs, os, ycap = {}, {}, {}, {}

        oh_start = np.zeros((self.vocab_size, 1))
        hs_start = np.zeros((self.hidden_size, 1))
        for c in start:
            oh_start[c] = 1
            hs_start = np.tanh(np.dot(self.U, oh_start) + np.dot(self.W, hs_start)+self.b)
            oh_start[c] = 0
        
            
        hs[-1] = hs_start

        
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size,1))
            xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
            hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
            os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
            ycap[t] = self.softmax(os[t]) # probs for next char
        return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
        """loss for a sequence"""
        # calculate cross-entrpy loss
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = np.zeros((self.vocab_size, 1))
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = np.zeros((self.vocab_size,1))
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader, threshold = 0.01, max_epoch = 5, func_string = ""):
        epoches = 0
        loss = threshold + 1

        batch_count = 0
        while (loss > threshold and max_epoch > epoches):
            data_reader.start_epoch()
            while not data_reader.new_epoch():
                start, inputs, targets = data_reader.next_batch()
                batch_count += 1
                
                xs, hs, ps = self.forward(start, inputs)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                    
                
                exec(func_string)
                #     print(f'batch {batch_count} completed')
                #     predicted_string = ''.join(data_reader.ix_to_char[num_val] for num_val in ps)
                #     print(f'\tpredicted result: {predicted_string}\n')
                # predicted = self.predict(data_reader, 'Ham ', 50)
                # print(f'Epoch {epoches} prediction (Ham):\\n==========\\n {predicted}\\n==========')
                # xs, hs, ps = self.forward(start, inputs)
                # dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                # self.update_model(dU, dW, dV, db, dc)
                
            epoches += 1            
            loss = self.loss(ps, targets)
            print(f"Finished {epoches} epoches, Loss: {loss}")

    def predict(self, data_reader, start, n):

        #initialize input vector
        x = np.zeros((self.vocab_size, 1))
        chars = [ch for ch in start]
        ixes = []        
        h = np.zeros((self.hidden_size,1))

        for i in range(len(chars) - 1):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            ixes.append(ix)
            x[ix] = 0

        ix = data_reader.char_to_ix[chars[-1]]
        x[ix] = 1
        ixes.append(ix)
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            x[ix] = 0
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 50
#read text from the "input.txt" file
data_reader = DataReader("input.txt", seq_length, progress_len=80, max_trace_len = 500)
rnn = RNN(hidden_size=350, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
# Out:
# ['i', 'G', ',', 'r', 'l', 'e', 'V', '"', '&', 'Q', 'y', '[', ':', 'b', 'P', 'I', 'd', 'p', 'a', ';', 'E', 'm', '(', 'R', 'S', 'O', 's', ')', 'Y', 'W', 'v', '?', 'c', 'q', 'x', '1', 'A', 'j', 'n', 'o', 'U', 'J', 'D', 'f', 'T', 'K', 'F', "'", 't', ']', 'H', 'w', 'B', ' ', 'N', 'g', 'h', 'z', 'L', 'C', '-', 'M', 'k', '!', '\n', 'u', '.']

# %%
func_string = \
"""
if batch_count % 500 == 0:
    print(f'Epoch {epoches}, Batch {batch_count}, Previous Loss {self.loss(ps, targets)}: ')
    # print(f'Starting string for last batch: {"".join(data_reader.ix_to_char[i] for i in start)}')
    # print(f'Input string for last batch: {"".join(data_reader.ix_to_char[i] for i in inputs)}')
    predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]
    
    for num, phrase in enumerate(predict_phrases):
        result = self.predict(data_reader, phrase, 100)
        print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
    print("*****************************************************************")
"""

predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]

for num, phrase in enumerate(predict_phrases):
    result = rnn.predict(data_reader, phrase, 100)
    print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
print("*****************************************************************")
# """
# predicted = self.predict(data_reader, 'Ham ', 50)
# print(f'Epoch {epoches} prediction (Ham):\\n==========\\n {predicted}\\n==========')
# """
rnn.train(data_reader, func_string = func_string)
# Out:
# Prediction 1 (Hamlet): \nHamletL-UkRH&V
# -:eVQgAFWD)JCYGdRjg YrDnS(:1n;cuYor,-W d?gKSi.,qabJ"SV'x&rx; TfE:GiA&yV Ig:NWrIs]c;"BpCLnKN\n
# Prediction 2 (To be): \nTo ber JH.cM,Rx,N][?Q&bN]KCNNbbf))tBf1
# !BHcE;FwzsKPWH?.ivbu(aGWKdMlFs r1xsS.kBwBf DukrULoFQ.O,QEsOfsjPl
# (\n
# Prediction 3 (poison): \npoisonA1pV;?RdifKfbVz-afeQBTfk (P'xt!dW?&'jh)dfUi1[ .f[jm(KJ[?IVsKCvMdai(M].dkmvxnN,I xtRnLfBfE.)T&WfJmzj:\n
# Prediction 4 (King): \nKingSvTmwHTwpTjxkp:-lid H-CbLWL-p(dmscP.?&ay :xHb[?&:rfrars(mS(tjVIWfWtYNMPoHxBcRhewbB(ePUJn)mP nKG1'a1H\n
# Prediction 5 (Queen): \nQueene&IlIz?pfGhcCgeIMjP.fb'DqpFcJude]vLJSR';fFW;eSJ["kixzkJ?RogPLtb?)Wz[j1CKQ?wiVOls1zNF.'NULrW;mdyV]UCn\n
# *****************************************************************
# Epoch 0, Batch 500, Previous Loss 261.14874694768736:
# Prediction 1 (Hamlet):
# Hamletkaorra o, khra,koooooI
# ooaroo'r,
# yor a
# aoBrlko ga ooyoiosobrlran,sayy
# rv,lyo
#  a,
# ,oavurao, oor hau,
#
# Prediction 2 (To be):
# To beyooorakg
#    or
# otuoroo,ehk,lo
#
# go
# ,ooakn tr,s
# sao yoiou r rIToi,olrH s,uuooya
# y
# roogyy
# raroano yo,h
#
# Prediction 3 (poison):
# poisonso oolsTraoAu oo,ooei aTlyak oooaooeyo y,htlkor.yo  tm,k sooa,o  ,otr oHooeoyo
# ok,orto.kauyougaoamya
#
# Prediction 4 (King):
# Kingoo
# u.yo
#
#  o,n mrkk
# u
# .rgroo,Iooreoalaguo olofaoo
#
# d,roya,uIond r.ao'lrroo  bo t noT
# ms eo koy r
# oo,
#
# Prediction 5 (Queen):
# Queenyiasgoak,oasvkoomuhyulok ooooo o,
# yudo
# ondoo so,yn
# ooos, or
# oteort,
# r,o,o
# otyoo tylarod
# dohio
# oyroo
#
#
# *****************************************************************
# Epoch 0, Batch 1000, Previous Loss 160.3895375362932:
# Prediction 1 (Hamlet):
# Hamlet, sso,nn.mrhd  g tntsnh,n s  nvn   e
# e  nny e n esei  tme    n rr ueieeufesreet  m e  u ein  e ge ee
#
# Prediction 2 (To be):
# To besh  he  y e
# iry oun ,erpe eee p netcul  l,v e ,t ttn,n,es  ese u enecehiruwAra   ss nnnus g.,  .he
#
# Prediction 3 (poison):
# poison .,ae e,i ,esue  enegy
# na isnvneenasoues    s btre ei,    nrescu ey o  nH reauOtnnen    ne teests ee
#
# Prediction 4 (King):
# King   e  , re
#  evs   ie ba eHrneeh   h e  h . m  t d hassa e om Wlottnnet  e
# u    e W  sWumncn  viegeo
#
# Prediction 5 (Queen):
# Queen eagtewuycie  y meys
# h   ueeu   st h eW  d he c  s,  g hs  yea then e , sosi
# heWihg,nesn
#  m e ees
#
#
# *****************************************************************
# Epoch 0, Batch 1500, Previous Loss 152.22608769854668:
# Prediction 1 (Hamlet):
# Hamletr yudstop p   st sno r g,lr  tg  mrtu san   omctvu o iot os rottetosr sMyl econsmsuo  n sc n  t onsa
#
# Prediction 2 (To be):
# To be ao hs   t  lk, n cuyhhtnt osuoH ohv n?guyu  sIt  unostetruohs  s  t ss e
# tesho ds  olr.e aol
# uctuf
#
# Prediction 3 (poison):
# poison
# oeo
# am av estovtsauyns.aou ntuhr utoem  thk   . i uo uwuuon  m  inu ,sa t  auk ht ,tkts uhaputh  lr
#
# Prediction 4 (King):
# Kingseo  oH syo t u o h eaotultl  A nt uuoush
# t o.luold
#  u  tsttIae
# u  ot   ho, ttehi numtotr Sos  nyt
#
# Prediction 5 (Queen):
# Queenuo.n  ty u oops  otunottttt,es
# hshmA tcs lu  aos  doorhl ss, us  m s  ge    hstu  s buu ooeotst ec
#
# *****************************************************************
# Epoch 0, Batch 2000, Previous Loss 458.60626095229867:
# Prediction 1 (Hamlet):
# Hamletmo t  hsy.n
# h    s. essts..   ear nli
#  sy nr  oee
# ag'
# erond.n  tb
# s  hi     rei snh
#
# aa s .
#  t o
#
# Prediction 2 (To be):
# To be s
# g ha
# t.ei , 'n   sht
# h  ey     .ttn  ndhhwn.s teo
#  o  a  eh
#  L wHosie saCi
# t  tg  n u ao T   ra
#
# Prediction 3 (poison):
# poisontne
# ha  n
# a
#
# I t
# mh nt
#  ni t iadrn.
# nhnhds n . .ns
#     mdnniote nessa
#  i s  ne
# ..I  ag  .
#
# Prediction 4 (King):
# King ho e ce  's   s  c o m   sa    e . w  ns shes
#
# .e
# a mHv s m   t e   v.fiea H  ni     stn  oem
#
# Prediction 5 (Queen):
# Queen
# h a
#  C d    seith  nee   hC, ssri  n v
#  o ets  .h.s Ty    sn  a reie nisee   t
# pt  een   en s
#
# *****************************************************************
# Finished 1 epoches, Loss: 160.51436735479876
# Epoch 1, Batch 2500, Previous Loss 268.6485168416708:
# Prediction 1 (Hamlet):
# Hamletk u  f.l n  twco   e Agr eaekm h   ns r aaandfu oo ptv Bukn.e   lhoWnalna o  e aoags na caBpan pwl d
#
# Prediction 2 (To be):
# To bel r   k    has f oga nn ft r  us.iolyt  i i vttt ea tn mn u,ilsr iu  aooek n.  nt tsmaihrnerg tlas
#
#
# Prediction 3 (poison):
# poison  ho leny m u iunyr h hIpc   y i Wngkv nfigi i  e olaet uml t  o et    u  po l., u  g    u lh u gn .
#
# Prediction 4 (King):
# KingriGse m  c ,  wp a. i p u ln  e  l   uhie i u
#
# raw rbost reso n   ptl  a r .ltse  ca  nsagt gi ooM
#
# Prediction 5 (Queen):
# Queenlo .i fgpFuelt.nMn psn  sw   lag  aarea sgt avn's  at uanBedrefl i tos  t  vuuie nfl ul ,u ru   wus?
#
# *****************************************************************
# Epoch 1, Batch 3000, Previous Loss 159.253171272922:
# Prediction 1 (Hamlet):
# Hamlet  h ,y
# h  aidqd  a eh t oOyytmA
# t o ?y h  trIfdtn or.hlaeiwma  is'etfm.iantnnt ayoctdt? rhr ?ueh  r
#
# Prediction 2 (To be):
# To bee  il f  smddtd Id r nep
# d  ttdttdi ee lt
# m  etrfd d .
# dehimee   eeo oai irdm  ilIdbeh
# ta t dom ae
#
# Prediction 3 (poison):
# poisonemb  Or  ad mturrtdot.coIm ic d red h mug Itmdtai pe ' sirltiecmtihi  idmi iad rtd,eietiia  tdr  dd
#
# Prediction 4 (King):
# Kingy
# rfaad fdd h
#   rmeddiq h  etIyoI wineih
# ttrs,nIogos ttaimysddCe  I oo   qlchldf e t
#
# i
# r.I  ? .h qr
#
# Prediction 5 (Queen):
# QueenHe td u  a' tdu,it   .ah l  n , dho  tim.t' t y t? eriutrn. h.e llt
# rd i eq  u s iddt
# faI
# at  yd
#
# *****************************************************************
# Epoch 1, Batch 3500, Previous Loss 156.19058690808978:
# Prediction 1 (Hamlet):
# HamleteeutitwtpflIwoayrpam'upueaiabpawolteropfs
# labtr 'gr ee bstiw s
# ylessa
# el hr thkstisaatiohtror,e ooiw
#
# Prediction 2 (To be):
# To be
# st iawetllsripofadtt poitotastMfpsgaeorpti. e.twg]l alinssp -t,cOtaplpaoaa s gmtsm scpdotosderpeowh
#
# Prediction 3 (poison):
# poison surawdto sho lbtoo   diiihoprp-puotunsnedwplow ip y .piiuigaaekdyr  ra u .,spwu-ooa fp oagiodnttrie
#
# Prediction 4 (King):
# Kingpfvoitiip , p
# swtooijwu l elogrrofHsusse.  lfru aoy.s toiopaonppaf a opn yta ygtohayms sr   .iiuusaa
#
# Prediction 5 (Queen):
# Queenahet;ahsap-rmloo oinp fip
# rltu Lioaptswti  dasoiypNoi eoios witee oi  siprrao leearerra p doie,itiol
#
# *****************************************************************
# Epoch 1, Batch 4000, Previous Loss 165.23179188234184:
# Prediction 1 (Hamlet):
# Hamleta  e  a
# u e[i mtdr
#  oini iGt ih
# eiirrnsln
# e ebnht.unrhs tb  Wel hhY tB Pe rgi wnneew  g.   h  .
#
# Prediction 2 (To be):
# To bem Gus
#  eG
#   nsyetus
# sG
# l e io,Gnnein sr  E G aGe n difm rene   er  net E  snhetnt ye jdp nte l
#
#
# Prediction 3 (poison):
# poisons de
#  thtoi
# l  t y ylHg ntfs.dil.eato ti lueea
#  edcGu  tuedtysigai  bmr hwr
#  hemsf?
# n  gu e   u
#
# Prediction 4 (King):
# Kingb   toeim    Hnieer
# iislaln  t
# dd
# tneGtiHn v  lwtEldtEttgiretwbtttl GG' t b
#  vi gi   rn    o  Gern
#
# Prediction 5 (Queen):
# Queen e F  nr
# mnm raKHna  iya l one  y t r '   geEcusGtr rC  i?   et ble  ay eu  lt We   a  d h  yi
# o
#
#
#
# *****************************************************************
# Epoch 1, Batch 4500, Previous Loss 163.83989762997237:
# Prediction 1 (Hamlet):
# HamletttLd'htts-v.iattt rlrdty.elu vecdeo n,obltthotrQroaets tc 'v thterer
#
# elrt ei ethlthhaw  a pt
# tbd
#
# Prediction 2 (To be):
# To betvLQ  cd.toR d et 'conw u WhhdeeTtceecddnederhue     h b
# ase
# LttweMaetshheyelhtethtcif  tao
# tht lsht
#
# Prediction 3 (poison):
# poisoni;ctus ele'repnti'tIo
# in rehthth r r' hht s e
# o ldutse.aeHhteyhdihl rhwtt drS htu t tagoMeee eHtitgr
#
# Prediction 4 (King):
# Kingatas
# steesbohheh.;Qolrh-?ia w] itIhs ahEytttnclit ,tos
# t s eeewt]c
# i- eea o  itob h?ded'ttehe
#  oeh
#
# Prediction 5 (Queen):
# Queen t ewteBw ee A   twbo
# efros
# .dh.aawh h .rdth d lp aihto pcahes'edtd b[stft h g  e.hafde!rtr.dt
# drgt
#
# *****************************************************************
# Finished 2 epoches, Loss: 157.92538655251633
# Epoch 2, Batch 5000, Previous Loss 146.02581118583782:
# Prediction 1 (Hamlet):
# Hamlet n odTnee
# os   i
# osiaT  hitm n  dha ludyotsl
# m soe lhgo   a
# s tvm tuyet,inhh uhp    vd  omt.gohtaca
#
#
# Prediction 2 (To be):
# To bet  iht
# k wo i teom     oot tetyrt he  teuy
# .ox,.. Iosus.T alT !oeeur  mteb,o Snrrooo  e hor fioe  t
#
# Prediction 3 (poison):
# poisonlv'osc jTTgO amcr glrydet,tHmea ogN slefsh t tnry  lt  ttt o   id  s'vgr o n t   mte.rnosh rona ll t
#
# Prediction 4 (King):
# Kingeo h rwom
#  ehmrs r
# a t t l hirt  tcis wtrar  'sgtaaoot  mwhet ssonon.,Talicwleih o-Too lrrgmaohool s
#
# Prediction 5 (Queen):
# Queen  oun  smo.m oSoah dsmaeoni, oouo mst CNt i  wrltes oaho o o  .t  yo throngdl
#   oo e oAaht  ta h
# oto
#
# *****************************************************************
# Epoch 2, Batch 5500, Previous Loss 169.80190621941566:
# Prediction 1 (Hamlet):
# Hamlet   k k e,l   nh
#  edamk,  m,ehet,  p   th nv iiu  u i Isel lHe  vlitN usm  luieewo
# renyv ao
# i eb,
#
# Prediction 2 (To be):
# To be
# i  Ru
#  hHy ove hh    b    of esHs veg ..e deeevoF y  seel etu He iur   attealfreraulhttee wwwtho i
#
# Prediction 3 (poison):
# poison,ia  ,o msst a
# feesd  ralkwdn lall uvt e oeee aw   sio n
# a?tlla n s h
# y i?a  stge mme e,  fek  a ee
#
# Prediction 4 (King):
# King, i
# r Hsn
#  eye
# wyein ad oienlhh .c  B ,p
# e,olsn eshu ,antahnlrl eOeeg esicd nfet tqa fkim Aevw .lihb
#
# Prediction 5 (Queen):
# Queenl eoeat v oh   ee!
# dob ahiesu!eo eALMna ih  n eoe.r b o s aodeu Ies a
# s i enw,en,asa  h o  lileanlie
#
# *****************************************************************
# Epoch 2, Batch 6000, Previous Loss 146.9216330512736:
# Prediction 1 (Hamlet):
# Hamletol e dlouayGus ovt ueu co  t ns Qs u
# o.tp  a d truy
# o yow rr me Hso iTee  h  e n!    neislh ubmvh d
#
# Prediction 2 (To be):
# To bePuu   o ra lrwuue  e ctl hee udw
# srrje odenm;uv a   ondahmue i   YsalgvQ l
# iP. h ,m do   rn  ao
#
#
# Prediction 3 (poison):
# poisonee dwep
#  rn  un sA rtu aea mo he Br   eewr jcut
# .Qyuh tHrh
# aysc ie n ww
# eTeiac.ln ey oa d oe'
#
# Prediction 4 (King):
# Kingo
#    n o e'diteurdepe'
# tp eT Swof et    new     iom eeas cH nAr h e due ll ydangr  enwrdly Haooc!n
#
# Prediction 5 (Queen):
# QueenSo atnmnoo u     ely  as  Sn  'lHo!med.dw  .  do I  e ae ieeEreb. oatr  e  rralaK pdh  ce  s
# onBvatn
#
# *****************************************************************
# Epoch 2, Batch 6500, Previous Loss 139.05863198633017:
# Prediction 1 (Hamlet):
# Hamlets   ot ? m IthlaWn st   nwse!g   a .wgif,ns  h ,a  uwtw  i  g t A asa ks aetbnee n'uAaa .mt nf   ose
#
# Prediction 2 (To be):
# To be
#  n F yh  y    fb e tto o na t?n i  sis 'h  d trl, H   mta.ge  s  tayono  rs a b,au  H s h ,t z  s
#
# Prediction 3 (poison):
# poison nt    itn o  naaiS    na n l    tn   iyve  s a  ht  bt   rn u e [o y   l      a    nsntbtlte, kte h
#
# Prediction 4 (King):
# King ese , etd  o n   h    wOr  fkb  w    d eww  t e  u    o,id n  v- aSnhnya!s  s   er,wnSiH; e hn ttn
#
# Prediction 5 (Queen):
# Queenottlaa b   e   l. , a   ae dnunaQa antt  y a w theor   n ha
#   e  r
# a  sw rrna wdyo m  u,    aeeed
#
# *****************************************************************
# Epoch 2, Batch 7000, Previous Loss 157.86749791035268:
# Prediction 1 (Hamlet):
# HamletoLrheTnua u uornge[gs      o  cpnh t,   ohtlmb'-ty  rteoifmoarfrla l synllette mtcety m.m  le mhtce.
#
# Prediction 2 (To be):
# To befmthi fe thauei tet' et.i
#   e nch ompTfm eto  u Hh. .
# fnueor mig,mmcucag vttlly,  ny toclo  notu  s
#
# Prediction 3 (poison):
# poisonase
# k yir tntydolr ftu t  whfetl rd Ol kiouo
#  fn o,mosbgsi
# ecer
#    rheea isnm  nhi   lt  af  ,
#
# Prediction 4 (King):
# KinglHYon
# Tl me[  rt,    ei o.loht .l ySieey rof   u tmnh  rmHm ffcenmafnsthmere l .Htnewhlo n  t  e ne
#
# Prediction 5 (Queen):
# Queenftufee s,unrfine oiiefeior.regilt  lfl   atotodltarerh f, th h avlreieihTu i htfnefei ,bf
# te me  wa
#
# *****************************************************************
# Finished 3 epoches, Loss: 154.12039918907354
# Epoch 3, Batch 7500, Previous Loss 147.55985701899309:
# Prediction 1 (Hamlet):
# Hamletea.o aheb upeoreea oaieewnesllu se dkouetod lhhAteensin dietgodsuoakbedbha ouad   ?y t mogl
#  ooedowo
#
# Prediction 2 (To be):
# To bese oegee ee'gsehhse nafieieieess
# ueha auoesue Ionaapeoobsienougeopetilioitudu
# tluieeee. sniauodinl!e
#
# Prediction 3 (poison):
# poisoneacenu  e  gold
#  nss Agorii aishnn niehtehuemolnoa hanaete sea  isloe snaii,nf ,eau
#
#  osce   e ucds
#
# Prediction 4 (King):
# KingeocabmyheehrdteieE
# r  enuHogsasheds, no  aaehe meneneuubhglei,eleerleree n
#    neeragsl hlteshl fa
#
# Prediction 5 (Queen):
# Queenhoeesleiokor oUharttaciiu
# ieege bta iogeurueuse tshbh    hcuwhldsv c  ipshge aeu s  be sieeehehyie
#
# *****************************************************************
# Epoch 3, Batch 8000, Previous Loss 154.3044698002702:
# Prediction 1 (Hamlet):
# Hamletpri mari'vetha     tekhlho hea bh,acneeru ry l tns;  lhhes ihhhlhcawno bavrcathollani cea s  oetirs
#
# Prediction 2 (To be):
# To be ;fhel  slho
#  ciggstete nie  atey sa esh jle tethMkeie! wkroktnse hnses,a'nla f tlye  ogaRhiernlet
#
# Prediction 3 (poison):
# poisonay ge  to br ge ee  rhathlleno tsego ns  ;taokdtu,wlaiihl wu t n aascothk ssgnsfrislyp. the ye tsrhs
#
# Prediction 4 (King):
# Kingsrets  nsltsofR.nn  iaoa atssalky;folt sselerhovHnllhhsaeiae aronscera nesa ifraEfker eteo rhe'euul;
#
# Prediction 5 (Queen):
# Queens thwbotu sce  nohathygce   ;nla
# fllo  letasl io nharpe tflsafa  rn
# geel hk  lllhgeo-rdtona e;key te
#
# *****************************************************************
# Epoch 3, Batch 8500, Previous Loss 150.92429165257406:
# Prediction 1 (Hamlet):
# Hamletu   fetem r r:lechr.?oearoaneuca  i.a?
#  tter s ntoc.fy yyaihyeoumoob  ;rysukanos,f  rekukiu,  mme mi
#
# Prediction 2 (To be):
# To bedH?ss rlrgardmrn mo  nteut. Hiu cowh. riediu. rherkca    cen oa ta son nrnv saro nosm ufuch.noHuoto
#
# Prediction 3 (poison):
# poison
# ywtnTawsssch oa
# yy  n nnf chd  a  sin.da orir.    denoe  ynn  teu   r nrhonHruEo    ntoint u bory .
#
# Prediction 4 (King):
# Kingeelw?orniitse
#    ne m
#
# y  s  oeun.tannsti?ue
# sgynurdkadnuma co  s  s sa wc   slys ta
# roufed  ecitoH
#
# Prediction 5 (Queen):
# QueenIoenecu slurhedmolf dkansnhoHeninshicerlcle.hu  yiule   v nheHonvom  thauofrity teuGsmiHe yro f
# sod
#
# *****************************************************************
# Epoch 3, Batch 9000, Previous Loss 78.37551982997286:
# Prediction 1 (Hamlet):
# Hamlet's
# aN,
#  sa
# nhouonee  ,ii
#
#
#   leAnu
#  u
#
#
# Me
# n  a    ms
# gua
#
#  fe
# ,
# ee eo
#  baI
#
#
# .  Ye
#
# Prediction 2 (To be):
# To be
#
#    be
#  o.y't.    .
#
# yf h
#
#
#    s
#
#
#
#   goauor lhir l,
#  ge
#
#
#
# l.
#
#
#
# Ny
#
# An
#
# -
#
#
# Prediction 3 (poison):
# poison.
# l  o
#
#  l, go
#  foxan
# oeta yx
#
#
#
#
#
#   cy
# oo
#
#
#   x
#
#
#
# y
#
#
#
#   ,n
#
#
#
#  cet,
#
# Prediction 4 (King):
# KingyKi   a 'u'r  Noch
# eik
#   np, l o lipet
#
#
#   ceforei
#       oore
#  i
#
#   - ceL
# Qug   nu
# h
#
#
# Prediction 5 (Queen):
# Queen
#  ghy Ta
#  .   d
#   .
# oeod   fn     t  k    iw  si       x
#
#
#
#
#   gx
# uae
#
#  !t.   x
# nek
#
# *****************************************************************
# Epoch 3, Batch 9500, Previous Loss 90.8562271991505:
# Prediction 1 (Hamlet):
# Hamletoe,  Hho uo Khoa a    t.t a
#
#
#    tau
#  ho
# hh
# le       hhel;
# Wg  .         .
# pu   vg O
#
# Prediction 2 (To be):
# To be   hhoh  t, reaga,u  Wri,   davhoy  orrh       yia
#     she ta    hhe       . TeA a    i
#      eoe
#
# Prediction 3 (poison):
# poisone  . .hho    lh  t      h.or     h Aea  wap    pay ha
# eoa     ee   nha
# thhe pe       . I
#
# Prediction 4 (King):
# Kinge   ,
#   dor Te   a  o       .  t     ue.oheey co   nO
# ye  roa oo e a . ho Lh Brh we        ye
#
# Prediction 5 (Queen):
# Queen ea    tu
# teIl.
#   au uche
#  e       h.
#  nt nhhhee shc     caA   nt t.I  .tu
# fe yhe
# w.. owoa  hoA h;
#
# *****************************************************************
# Finished 4 epoches, Loss: 144.38281268295577
# Epoch 4, Batch 10000, Previous Loss 159.31176305284654:
# Prediction 1 (Hamlet):
# Hamleteek romam.hut.   ane n.hed  ssi  quBuA Illedheldilh gfokley  leen. l  m' rlin'ove  mrlune  pa     l
#
# Prediction 2 (To be):
# To beaBImeg
#
# ne'..met Ho:Thfnnten c,  Yesiakahy in.   noud  osIiirey   Ynnna'zarYak'ul hf  as.mnte l ln.
#
# Prediction 3 (poison):
# poisonontdhBnenisrnfhailaFhhererPnplramofeas    Biricuan. escodugBune ce tolf
#      hsy Bal. .rnelgeyeamy f
#
# Prediction 4 (King):
# Kingunlhhs nemm'ancetetesaD'dngl.  mafmd t Uhslume Balln   Uld
#  l. nendLasul'tett li Ro uil'te 't  ed g
#
# Prediction 5 (Queen):
# Queenni    nt w   Hr Kl t lolt d reatenr t.  y d   , Buf  fal ciltrrmn    he at dipd PsInhacirsirsns   pe
#
# *****************************************************************
# Epoch 4, Batch 10500, Previous Loss 248.5120631585251:
# Prediction 1 (Hamlet):
# Hamlet. goshi    o.    he
#  f foWeo atoosa'e res
#  w.  eals wo, meI
# onnone
#  T  De hh pe
#   Pestaon
# keat. bei
#
# Prediction 2 (To be):
# To beete  oli Bg   woNnPe
#  .hes  ml ;ye. aasf'  eey  hiA mr   sol arC
#  hd S
# yyheraneyisfent Cave TPrmeta
#
# Prediction 3 (poison):
# poison Pob ss .
#  Osi.   sayewy thrnerhe P ror   Py .  ; bholi  .foAdl-'a Aat y anPw,
# g  wy t te.cisP; iw.
#
# Prediction 4 (King):
# King
# tir P.h lol We -sonces   uy   yhe  oweo de mheceo   s S Po y
# laupe Pelforin    Ma sPy P     s mfbec
#
# Prediction 5 (Queen):
# Queen eA thett
#  PPg,
#
# le,, bq'thf    , sert e mems
#    tir nawl
#  ;  cos
#  he:
# ,aauoeO      t peuw'ha tatod
#
# *****************************************************************
# Epoch 4, Batch 11000, Previous Loss 140.6169325748899:
# Prediction 1 (Hamlet):
# HamletHuchyatos
#  t b b . Homdalo ggcoagoovamane sha  m', t, wh,
# oute [hreachomoma wexdir   hos sima] so
#
# Prediction 2 (To be):
# To be  u. tau, Gemo  whould mrltaretoLh.  I
#  I dgyanarnar     i  . . osdof. ren,wat.b.
#
# they, . t. eapo
#
# Prediction 3 (poison):
# poison sfen wof H. fot
# mhmet we aa . mete, Netos wemeamhin o
# ,anmmsgenrwav.'iene outheog. mAmdy ere.
#  a tu
#
# Prediction 4 (King):
# Kingor, memaEyay,Ianr.  t. le dasumes.ve gow P.
#
# . is  n lVi Hew,
# Pnt bon,shog M.   t.,ametamewnwameutaf
#
# Prediction 5 (Queen):
# Queeni,on. ,
#  u'Prn.en? Noteuwi cen ; micuf darg meunauN p  menreatet iibatea] tonhor Penmoayow at
# bdlgna
#
# *****************************************************************
# Epoch 4, Batch 11500, Previous Loss 134.1990440357192:
# Prediction 1 (Hamlet):
# Hamletinne
#     th 'cirwalou aThyouyenoueof h! photthiue'lhorerhers    ioryat .
#     nafoveone  h  han  hur
#
# Prediction 2 (To be):
# To beec,biter  hoonha
#  toorerW  t chchdyat bete hlero  fenkeolpe seoklute;AI    AAtdle'o   hiure da v.
#
# Prediction 3 (poison):
# poisonss s
#  coy diy  sf whh Kinhoe-
# direlurelhhthe
#    awhay ithne
# eouve sh    quceee.ie     celt de
#
# Prediction 4 (King):
# Kinghad ? H;boy'aneu   toe'u
#  lhhe  ?h t chhh'tiutici?t yie Arhrerpashiuu ?Whii  noegilina  tiut adhh  s
#
# Prediction 5 (Queen):
# Queenlynoehhiph, is    au. Re whersienmue?   v.    hicid he
#      h  te'dir h
# ham  uinrith   e saritoy w
#
# *****************************************************************
# Finished 5 epoches, Loss: 142.79313571330184

# %%
predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]

for num, phrase in enumerate(predict_phrases):
    result = rnn.predict(data_reader, phrase, 100)
    print(f'Prediction {num+1} ({phrase}): \n====================\n{result}\n====================\n')
# Out:
# Prediction 1 (Hamlet):
# ====================
# HamletP the beSke tiichofoy oele s  df  pent  ?   cSc  pisis het saniuchh    he h  phi''e aca I   ir has;h
# ====================
#
# Prediction 2 (To be):
# ====================
# To be Af samhiac  thhaycaId hase whaf .or Foovhar lat  bacheg   te phhiske  iyf .  halt  he  Kk   fe sFhh
# ====================
#
# Prediction 3 (poison):
# ====================
# poison ara .id hoeb
#
#    a   Fdaf. ienhleoncad 'e toa s ans che;hon A thit  wy    Yiu   .
#    chode  Hn tefa
# ====================
#
# Prediction 4 (King):
# ====================
# King . uWilat
#  ag s    h  tin   ; inWhhige c;anErer  wit   F phy dhi d     wi  holhhdche mr bnt daf did
# ====================
#
# Prediction 5 (Queen):
# ====================
# Queend
# Narwoov raEsaykhid     d mrfota hhe ler ch Ft     bs   uem hhhoinkemow.pshhhhuy
# o, ? whh boninmll
# ====================

# %%
func_string = \
"""
if batch_count % 500 == 0:
    print(f'Epoch {epoches}, Batch {batch_count}, Previous Loss {self.loss(ps, targets)}: ')
    # print(f'Starting string for last batch: {"".join(data_reader.ix_to_char[i] for i in start)}')
    # print(f'Input string for last batch: {"".join(data_reader.ix_to_char[i] for i in inputs)}')
    predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]
    
    for num, phrase in enumerate(predict_phrases):
        result = self.predict(data_reader, phrase, 100)
        print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
    print("*****************************************************************")
"""

predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]

for num, phrase in enumerate(predict_phrases):
    result = rnn.predict(data_reader, phrase, 100)
    print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
print("*****************************************************************")
# """
# predicted = self.predict(data_reader, 'Ham ', 50)
# print(f'Epoch {epoches} prediction (Ham):\\n==========\\n {predicted}\\n==========')
# """
rnn.train(data_reader, func_string = func_string, max_epoch=500)
# Out:
# Prediction 1 (Hamlet): \nHamletaumhe br f  ho   he   n teeunc seant f;thig po [    met      cech. chold Fomit  p te t
#      Bouat c\n
# Prediction 2 (To be): \nTo be
#  Ot
#        wl F
# ics
#
#    Rigc.as ;fa mi ch ;shhif  h dontoee     conthut bdua   hs   , ;  daw fldde \n
# Prediction 3 (poison): \npoisonchhh the;har   e tulaoil e lhif fea g; ;  c. wh oamais  or
#  lhdabe   B S theoc?w T. d   Sar l , i F\n
# Prediction 4 (King): \nKing  A     d
#     hhr kh; pe  de   hllhhesxa rikhha.onnrtbeswuh  glac hauas c hes a      pd ichhipa\n
# Prediction 5 (Queen): \nQueend thorw. moargha shr  h. heiradhhis cphot rod d i we lf
#    hm bua's chaam    t it c  sesHay  ;hahho\n
# *****************************************************************
# Epoch 0, Batch 500, Previous Loss 138.07872982929183:
# Prediction 1 (Hamlet):
# Hamlete seoroerol.  mear,, th  eeiarh   yoreraki arhfhquut yWis weolorh ris  whas
# yire?  d Hefor   fora to
#
# Prediction 2 (To be):
# To bele   ridl,,  Hoy cy rthrocorkaBod Tamnwher sod ses       eyHe  is lo,  wtet t  s
# ,  a'hiveutaunt uou
#
# Prediction 3 (poison):
# poisonlorhoa   serier'? piHrongaaseoncaSsaratoraccois OtCe,henaalronw serllyT,eunhors.  ,    ar tarauu hus
#
# Prediction 4 (King):
# Kingaanfot
#  besinc.
#  wseae
#      ers leueifErosser.     Aouraranore co deanrinoatin ti yortet,a '
#
#
# ,
#
# Prediction 5 (Queen):
# Queen botourad
#  lasisirronu tar   o. L,
#  nesL deuy. L d, cd  b,yora  T  Therere a  AeBldumraraa,ruanorc
#
# *****************************************************************
# Epoch 0, Batch 1000, Previous Loss 128.9202324991215:
# Prediction 1 (Hamlet):
# Hamlet To gemfthhigeanam.,   Qt,  ya   Mrlpinsf is minmole   theleetasey  Penn Mtherflunleoni lAnek daf M
#
# Prediction 2 (To be):
# To bers
#  yPmadnd,. t ssat s drr,i.ies se. venafe d.fe w h pheyathrniop   th g ant  se
#  g.sentme
# te
#  then
#
# Prediction 3 (poison):
# poisonfnloccutasnege cus fleteeur, brnmznesef ateanmallef yonMese mid geufet hi   yeas ey inaWa sy Yhentoa
#
# Prediction 4 (King):
# King
#  nuuumirpan( Wh teetkeas. d,
#  h,. tas
# Tu,     tpet  hhe ge Gnnit Tat clniithut
# te Het
# paljlselt
#
# Prediction 5 (Queen):
# Queenvlniceens tRanepeap fn. mesresRerThefves lfnsenInbre s,W, tenstheyavolapossestanfaldllaceanleysetoen
#
# *****************************************************************
# Epoch 0, Batch 1500, Previous Loss 131.2220058243575:
# Prediction 1 (Hamlet):
# Hamlet ft interorr, zsnr t  pgrut sewoous canls
#   m slandas t  go  sfy lullncs   theuvero to d cs  tL  se
#
# Prediction 2 (To be):
# To bely dstthadpas  muulcat tiuuunr Wou? tisiurustor hod thuC, I H 't   I Th,, r?  A s Tot   inIg
#
# Prediction 3 (poison):
# poisonf t     .Uf To mot prt !  fr s t ainnt cot ons  thrDre t     I ty    Whoroumtu surant icrontlot sthu
#
# Prediction 4 (King):
# King roret t  t    at
#  histhes WHUon gu puceun.     pyhecsouy aloufansrud tole rat fnd gir t hgp vot asf
#
# Prediction 5 (Queen):
# Queenw  y,  oy
# Hot Wastot trsthoyp s Boc!      hst
#       t
#   Ur ftToat neasat b  t Pus   tovotu  ?
# .m
#
# *****************************************************************
# Epoch 0, Batch 2000, Previous Loss 126.89448334743892:
# Prediction 1 (Hamlet):
# Hamlet.?
#
# slnc
#    n.ip it.softe Tpustins     E -
#
# Gals gs;
#   eos oam.iis Hnde t.Cos h'is  ananwh
#
# Prediction 2 (To be):
# To be leras
#  .
# hhe
#    Coerasas Tin  O stit    hr.
#  To ghie  n-   gig.  heceHetts kher;  Ag. kirrlosbniuss
#
# Prediction 3 (poison):
# poison.  atisews.    se
#
#
# hee, eananimit. v sic. ,  her. thatheec be The yinae that Tonit t  - be -    a
#
# Prediction 4 (King):
# King'tasaomn. a to sasTis !    Olangesas?H  tos sge    o
#  l. gieas so sy Cos   He. )is Tanindcere the th
#
# Prediction 5 (Queen):
# Queeninheteswhere
# intanap ginlag,
# is so g  ha get
#
#  en'tit     .a. m. sinnas
# send mstsatit   :in
#
#  Cos g
#
# *****************************************************************
# Finished 1 epoches, Loss: 138.63894991179276
# Epoch 1, Batch 2500, Previous Loss 146.48304079710638:
# Prediction 1 (Hamlet):
# Hamlet
#            De ler d.
#    maerinth O ro Do
#            w  ] aaur w,
# he k ous
#      k  Thh. eulof
#
# Prediction 2 (To be):
# To be in n,
#
#       rn e    tintoeskn a   c   Bom T, ti,
#        bn.
#       sam. FlttU
#    o koroperl
#
# Prediction 3 (poison):
# poisonoIid    fonk
#
# Uke ininit mf caras kad Gos,   inand can!
#   lay a   er nfs
#
#   mos pungpiuve  a
#
# Prediction 4 (King):
# King-run
#       m bos
#    tas gate kel.  H t 'ar
#
#         un gvekciy
# ? nalis bus
#   aphe gabai
#
# Prediction 5 (Queen):
# Queen a d
#  w Mans t
# s til. his an,    in sl mor'ilsm.  ocy  hs su,  pit khoMBs   Mr hl ye, yer    haiM
#
# *****************************************************************
# Epoch 1, Batch 3000, Previous Loss 123.86110057476152:
# Prediction 1 (Hamlet):
# Hamletid thevur p ]
# Lole h dr Ind  her thd I sdat        h tas     he m dirdimho g  amead t.   if hhid.wid
#
# Prediction 2 (To be):
# To be, fy  are dlamhad
# hed iuyathy
#   iu dhills 'wedt imetkt
#
#   peoGy he
#  A ghev pad Aa  Aurle dit   ni
#
# Prediction 3 (poison):
# poisonert bith depthhiv G thaldimodthapyad the tiroande dalurotir sp ent ueiel?hh
#  hif.mf   qlood
# A mosn
#
# Prediction 4 (King):
# Kingh  bey moy  thf a hald to u bold moe so in thetim re tit.A Kh dthh-eathuind do'de     o dad mo t
#
# Prediction 5 (Queen):
# Queenne   tumi:  Fd   Thh th quCmat Iroutath?   oosith, aret er  he theerhench iuta?
#    yeemas w  Ieite
#
# *****************************************************************
# Epoch 1, Batch 3500, Previous Loss 143.0163236237841:
# Prediction 1 (Hamlet):
# Hamlet OgofOcoasure sougiuathis herCopt.sit Bis -is ciar oor
#  sopourere p the nod deigilif do- Mouliiowof
#
# Prediction 2 (To be):
# To be ko So he Woarikere. artouBr foneive wo
#  tee
#  ler;
# apaltey e ci I ghengeuf yous sese dimos siw H
#
# Prediction 3 (poison):
# poisonmatie nds.oesreelutan p
#  In.
#  paut tideat     Se fe  T
#  Moleatpo
#  nig wo popot   hiraoners pa
#
# Prediction 4 (King):
# Kingh rhat tanhxeowals toooliir bit uriw. aentpinSlnthoth yygiy gliinn pilthisonlea, thhis tisistir ands
#
# Prediction 5 (Queen):
# Queeniw toas  fy,   I
#
#
#  ron fo paugicon-niai'the mhassLr Orilthay  or  hoiud iune pepyp 'go sent 'os   i
#
# *****************************************************************
# Epoch 1, Batch 4000, Previous Loss 130.9361538225982:
# Prediction 1 (Hamlet):
# Hamlethimy qansotis!xh.
#   K  u Tthe Ric. war. theshos Hot
#   hilttildBog's wowe    theecoe Ane musamonle fo
#
# Prediction 2 (To be):
# To be, he h.
# Bonse
# if le s'tils w.
#    Rule ; tleseens Hold maeth mend natr bf tte teirhilt d,
# RonReimte
#
# Prediction 3 (poison):
# poisonumeiaug Wa mutle g t Bottiuner, mu't.    iter dand A  Hl. ne, yey thoridls
#   t Gir Botds,AuanrRireir
#
# Prediction 4 (King):
# King gpuw .
#   har Ke?  Bond, it saklolins Gadt ams, woBt
#
#     bn
#  corg tantinit. Sosyerlarid Gose ls
#
# Prediction 5 (Queen):
# Queenwh. Enac- me'ja, wheem thekhirh. Wint.
#
# maSse thiQt me Thy   pumeathldthd ny BithlersW. massls  w
#
# *****************************************************************
# Epoch 1, Batch 4500, Previous Loss 138.7052147558252:
# Prediction 1 (Hamlet):
# Hamlett sylld Iwe I H- wa toert
#   iot whet   oot the clyeetssbuchige. Aseet o, hetmesaeet
#   pes. tiss witt
#
# Prediction 2 (To be):
# To beeg atun. but. ge jetas gade whe?
# aad.
#  e went.
#   W seet iage the tit Ni; whigse dis helt thtibd
#    f
#
# Prediction 3 (poison):
# poisonhereedtit thlt? dreseleutIeret pe gatfe-dit? oa-wlese dlesigd]
#   I tout thery mord inc'h teamateesdr
#
# Prediction 4 (King):
# Kingsd,atameteeshe pasedtevould [  hytet!he cethhey'd be    kfelledse.   Irelsadtbeld mers ise thete
#  le
#
# Prediction 5 (Queen):
# Queenlal'Th  teg'tdeltendLene Sliw'lontY'piveld ;  bot
# ! eoghe 'tet) bi'lighegt'thecthendarhessdutGate le
#
# *****************************************************************
# Finished 2 epoches, Loss: 132.14146895177026
# Epoch 2, Batch 5000, Previous Loss 115.90124944623204:
# Prediction 1 (Hamlet):
# Hamletf         Hoontar cac     !   tirton     lot     wn;'d sisonrc    hic   Cit    o    sit.     To .hc
#
# Prediction 2 (To be):
# To berlou orhe thet Hat oar t   ouas h u'd  E ga mim         is O nfNu g aquait  areroy hoalh Tir,  o   t
#
# Prediction 3 (poison):
# poison Th D Oar we mom Sy  torere wor-itit!par curdt    tatto thespo
#  He tomool o      yu imrs
#
# a coOmo
#
# Prediction 4 (King):
# Kingtors   o
#    Etee sf  aar wlar Cis elosanand Foout.sone n! h     Tojons,ge piterWh yo  ut T   yiet.
#
# Prediction 5 (Queen):
# Queento,   hTho)     Fo't          T or hd so hhs Dao.
#     Thelte
#   Hu tonoy  oit t       to     sm
#
# *****************************************************************
# Epoch 2, Batch 5500, Previous Loss 129.87718067737438:
# Prediction 1 (Hamlet):
# Hamletheny, Tite,
#   hon sont Asirentedhe me
#  Whe whytesr, Quatt yey ns anhes areamamat Ha, ury he'ke me be
#
# Prediction 2 (To be):
# To ben,hle
#  antd   n's Ir thd pe soat     by bende, Gn ueshantasmy
#   IbePAnd pond,
#  s Pas Ps Thens tens a
#
# Prediction 3 (poison):
# poisoneek. mamd Len, fe. Pivosgf Tind Lhessnatbs, kins t  Houmnthsenns  we f thes?sat. Onditlels Pf
#
#   h '
#
# Prediction 4 (King):
# King,, beyt?
#    ,moneeund se thekler,imi A ase was,
#   fonl rawmranhe t      oat. a ser'ir, fe,
#
# bnthe v
#
# Prediction 5 (Queen):
# Queensdunky Ime, we, mat? . Bad wheft Rl      Wase, A Analivenke tye sov, Anterence de iefe
# , Alirhe
#   he
#
# *****************************************************************
# Epoch 2, Batch 6000, Previous Loss 118.47050374202547:
# Prediction 1 (Hamlet):
# Hamlet nu(e donnf vuwrels b Tu T         co hs A pe w      ine bo'y motlow coran Kyey wa.
#              B
#
# Prediction 2 (To be):
# To be cy to sime        Te yoouvrs but
#            ]Thalis    Nur tione on geud
#
#  oerh'Be th mo or e aron
#
# Prediction 3 (poison):
# poisond       she po se Bon he     berot a Pannse
#     how r Qu ,   wenpuuasaen. lu he wi au. Ta tlauver th
#
# Prediction 4 (King):
# King a teer Keceen  he t] we t     u g        'o'im
#        madannt mens
#
#         ;       Hlonan
#
# Prediction 5 (Queen):
# Queene nont il. s] te cind
# anenconand mowie nusSI Ql wh   bold ir sand  we Bouwe t'or dutond bid ard
#
# *****************************************************************
# Epoch 2, Batch 6500, Previous Loss 107.68465422094827:
# Prediction 1 (Hamlet):
# Hamlet arll py w  Your S, 'e;
#      cowtat Nand y      Ta O ans               ]I r)entlet,,
#   Hopor Sesa, n
#
# Prediction 2 (To be):
# To be kand br t. ke T   aens     or dect cn goang-
#  Sf
#      oany nhet w   on poam Perlof    Halagd mintaa
#
# Prediction 3 (poison):
# poison
#          Hhice lu O  A aid
#          Qthe sine thnmas ws ite ciStivs kpit saMt. our o munthi au Ke t
#
# Prediction 4 (King):
# King
#     pr in nor fy b S   ,) ta       O  os uny   To toV ot, ar tins t  y ooon d,
#     ,
#
# Prediction 5 (Queen):
# Queens su thow wilth       Olone a wi  yit the, Oaw hon
# Singen; heeng woy w fu nark
# Sth?en
#   Cosul.
#
#
# *****************************************************************
# Epoch 2, Batch 7000, Previous Loss 134.80273214022864:
# Prediction 1 (Hamlet):
# Hamletherl mevosle cers therrld ta I Nu(m? thecd ut andte. winlfr.duslved Luu Iimltlld Dfss,
# Lod, Peet oou
#
# Prediction 2 (To be):
# To bent mloci,
#   fatid.
#
#        Tit. itl] busmellrem,.
#  henle pu,se mle'gelis FusAvy
#        met.,
# hs .Eu
#
# Prediction 3 (poison):
# poisonte yooulam Huct curis iit we tpentitiosh sovat mrenc, Guut luuliclisIt[denmal[ders flealeH; w eritho
#
# Prediction 4 (King):
# Kingens lory kndeet welgentisfelg?
#    erf movndvenabt Poterauveltould.
#   Cadtim.
#      A  Houd mendre tha
#
# Prediction 5 (Queen):
# Queends'cer,
#  , sal.
# nolst. fnete    onse tle,
#   mos mheuse me dey u foscot. Hyonus qonowotoou, Dooirers
#
# *****************************************************************
# Finished 3 epoches, Loss: 127.38576968831215
# Epoch 3, Batch 7500, Previous Loss 115.18545364012648:
# Prediction 1 (Hamlet):
# Hamleteandle, mand onuloninbonslatey uouns thatithounge Eot, p      uinige ton
#   soit  miawhilkia
#
# Prediction 2 (To be):
# To be, ineeukd co Irer cunger sigashirshind heime Whe poisis dolime sbolyher U gle bo boselist. toiaurte
#
# Prediction 3 (poison):
# poisonant Ereiteadithinde ankoutd   's
#       'y tthids, boued konitiwgeacd Noleullisinlils namesimeldgeinc
#
# Prediction 4 (King):
# Kingis, houvT iaketitaleriride un pofageeild dre bake cktaod woourim. are ktiumeerdateobanendononeredaro
#
# Prediction 5 (Queen):
# Queenthaghe    thelwev,teesik cu toyesdathideug. Monteals Tasinsas. thisicd. Are iome iiuds ime langa'de
#
# *****************************************************************
# Epoch 3, Batch 8000, Previous Loss 116.68684253618831:
# Prediction 1 (Hamlet):
# Hamlet
#       ; Thylb th Peke lesat he thy wats
#      overs? Pamer s  os jur a, aresbout lre 'll s h haoas M
#
# Prediction 2 (To be):
# To be fliyMBay saesstkt mle gas ar-
#         Nut Bore, bouass tha wer sharce yfour kart ulafs anlrouf lalt
#
# Prediction 3 (poison):
# poison soerll sheegl lalt lr oauf sheart
# arllr a cer, whes he su porR pagit lolhect I darltone is satheave
#
# Prediction 4 (King):
# KingR-s yof; dhes, Youce   h'it he.efghas feaang khant sas the. tere   lo tange cesd dove
#  bf shay gfn;
#
# Prediction 5 (Queen):
# Queend aaseesle ant df cather my sf y be cal. lit ar, coye goe eit
#  heth ank proceartelt sa toy'ey nhacom
#
# *****************************************************************
# Epoch 3, Batch 8500, Previous Loss 122.09497810227043:
# Prediction 1 (Hamlet):
# Hamlet ae sayirt avoy onoomryvorpn nunlur lonagjo. o?, vakke u Ta u du, o macd gde id ony, Honn    Gy  f Y
#
# Prediction 2 (To be):
# To be dous weiseby
#
#                 o dler, imine fyss dAs? tyeuce. goyyeer. aes usdAlnth, Yavy we.
# haemy
#
# Prediction 3 (poison):
# poisontrelery pray Yuam yuth mok the this
# colut
#  yus yey- theyYencn Gu gh!satithly   so hily unon on. ioue
#
# Prediction 4 (King):
# Kinginsatilid
#      ty HonevisentMuncsm? Nfass cy is Yhth yofefd core u dam; leenge they sfve, th'cesopo
#
# Prediction 5 (Queen):
# Queenssif mislloulie meer        irdr. Hous[is yous th One cose hid thosent Fant Hor    Aps Thent ves
#
# *****************************************************************
# Epoch 3, Batch 9000, Previous Loss 51.02869570033609:
# Prediction 1 (Hamlet):
# Hamlets
#  o onot munneaer thouur
#
#    hloreeerranghe,
#   oe ave toav,
#
#
#            il ge
#
# Prediction 2 (To be):
# To becdth yoame
#       iu. a may
# eur   robenl
#              wieus
#              Hoo hy fein. tfent
#
# Prediction 3 (poison):
# poisone ga. b    ixg yof mn the
#   he
#
#
#
#
#
#
#            iugy  fay
#  il cop we w
#        'mels
#
# a
#
# Prediction 4 (King):
# Kingie ean,
#     oig,
#
#
#
#  'y
#
# Sore w, ie t         Kt    ws Ere timt
#
#    W iu silf. ther
#
# Prediction 5 (Queen):
# Queenke peigy Is of
#      sa,
#
#     Teag, t' urt
#
#     wiserel gole. Thare
#    Notid
#
# *****************************************************************
# Epoch 3, Batch 9500, Previous Loss 58.87090336485818:
# Prediction 1 (Hamlet):
# Hamlet  aref.      bien
#   Seve gowhhas thatete, last this we the Le yos.
#  O iy Heilesawhit Kat. witap
#
# Prediction 2 (To be):
# To be Lry, Kpe. him waat;  Bow, Lavy pid thakle, Kaule Sovy I anlp at              Hath pat thelantt neey
#
# Prediction 3 (poison):
# poison
#            Mmive.
#        and Knorpent teaw hachhad      a Ra Gat         aad to d m't a nenesc cim.
#
# Prediction 4 (King):
# King Laythinge tiud     Thim
#  fneveiuerleie Ofe  A kvod aew Kpathatheelkeendd I we chinter yathoe
#
# Prediction 5 (Queen):
# Queenthonte bu whe caencendd
#             ynaud leir    he sh Ker do     thepid Ieenathont mue,
#
# *****************************************************************
# Finished 4 epoches, Loss: 124.36248546308718
# Epoch 4, Batch 10000, Previous Loss 127.24197243146294:
# Prediction 1 (Hamlet):
# Hamleten's lad; the 'f lh u unse day
#  oamhalglirt. fidiavallinn,
# 'ay ay mu mul bef teptd hacd fererldSer.
#
# Prediction 2 (To be):
# To be frlep th? lim.
#
# Ar
# mon thoe eisc yle,Hatele theng'd. asfed oam. u kasedlen Shig Aas hor     hes. o
#
# Prediction 3 (poison):
# poisonof
#      ther. inMrers  Wherirl'z Tha cid sis'd, infflash lonmllos whkh bodof'd- Asc me mu UnBlse Bod
#
# Prediction 4 (King):
# Kinghlend, Thate maligenn sil bfll' W iy thul, thadingsil! uvalln.
#             Thilild Whi.. he Ie fural
#
# Prediction 5 (Queen):
# Queentay. men,y mlanl moeylllycis mes.
#  Hanl w'gle
#  As. h.
#      Thettathavheepl       Therabteet.
#       Y
#
# *****************************************************************
# Epoch 4, Batch 10500, Previous Loss 139.7503619038805:
# Prediction 1 (Hamlet):
# HamlethPnssHengor, eod as, th, gft de ge thse wes., fow; w. der. 'lntos
#  Ay lor. bad, we;
#    ans wiri's Be
#
# Prediction 2 (To be):
# To be. th te d, oo clengh mold a sks pas Rises Pold fpis
#   sye Sofer Pu wol'phay 'ine sas folocer bf os.
#
# Prediction 3 (poison):
# poison hse we
#  cy 'ano1 b1 Pos and us
#
#    Qfthset areas wald koonr bor. ied th poum
# ine
#   apy teld mritd w
#
# Prediction 4 (King):
# Kingit.
#  at o1.
#          pos ou wisers Po lolcit.
#    Har.
#
#
#
# Askiv- th ms, wPe derd tr thas Le-gos ars
#
# Prediction 5 (Queen):
# Queenn
#   A orim
#      1. ousf ger.
#
#   1es lerde se. dult wstse 1 Pr heeuc.
# E Ge 1rte ay on? th spes ther o
#
# *****************************************************************
# Epoch 4, Batch 11000, Previous Loss 126.86342405362943:
# Prediction 1 (Hamlet):
# Hamlet,, murt. Thinn pe.
#    Hou sate's webn'd favr; th.;
#  Hy   a hus Huupate thaghare yoan. Htintime,. hen
#
# Prediction 2 (To be):
# To be y lou.
#
#
#   Muas thr Theirsfad aer th, wrnaas mu
#  Hu, ila. s. Hof.
# I maamV. bunge wit Pas
#
# Prediction 3 (poison):
# poison, your orimome Pe may h;
# neas fou, yat. Thaous Hald but        ,  ,iketge he, Pauk how, Meann mor? m
#
# Prediction 4 (King):
# Kingt. Moucha wher hanebut.
# hy
# 'eas
# hat po't Hiy
#    Pou wand hod mr, fon whif ghec'd cinmod, Mu manhat.
#
# Prediction 5 (Queen):
# Queenwhe-c. Mwelthert. [Tasd Mn do thatik,vve. Heenow Maid    Yorrey so mur mam su tim; by mos owou]  moe
#
# *****************************************************************
# Epoch 4, Batch 11500, Previous Loss 116.18840268972808:
# Prediction 1 (Hamlet):
# Hamlet  ber K
#    iusNaeserilgefins        Arophonh shee mous
#
#     'hik ol !     Aofdorenkheon uth'l
#
# Prediction 2 (To be):
# To be thour krheas shase cir Whhre cha nhe cou cat.   O Whee oc a?      and               Thie in dhit, c
#
# Prediction 3 (poison):
# poison cenh'eser   Teant. wh; rur, shee lor bu'K o cou'd
#
#      ishacer pou Thid on
#   ouchey a us tolhew Lu
#
# Prediction 4 (King):
# Kingheasi.  ban, in cinen hthherller tees' y Ke' ar gar.
#
#  Shhadeeands yofhe? whou. Be Is Ith ser
#
# Prediction 5 (Queen):
# Queengh soros uralich thour un yaetge whe.    hann ch
#         henw
#  Thhothou sh ge u so wree bu
#
#
# *****************************************************************
# Finished 5 epoches, Loss: 118.52006403788836
# Epoch 5, Batch 12000, Previous Loss 83.82546425769665:
# Prediction 1 (Hamlet):
# Hamlet toof
#   Hare    eutoer cAnk anl, Th.
#       eurtherte Kave anhame the Ereec. our
#   Tis tyern uone Pr
#
# Prediction 2 (To be):
# To bees
# Thpe Ferith Feog Mtithaenthine Whaad Tatoad ancet.   .     Thellitardimh andhisinhee th e,
#
# Prediction 3 (poison):
# poisonrr therlurite bamid? [Puew.     Hoanate thit weag. be Cage    Foute lastee bulith Gint thoves Wh hee
#
# Prediction 4 (King):
# Kingild Nad? Larhinl reaun.
#   arkatheum harath eagalaroucil pat ow.  Hastaagpite mavatre,
# aad. ?
#
# Prediction 5 (Queen):
# Queenddawh moandeus ace   Heree Hant OEm
# .             seelage Hoshart Sy
#      Hon nit. t  Fath, Sorid Gi
#
# *****************************************************************
# Epoch 5, Batch 12500, Previous Loss 110.63657920983388:
# Prediction 1 (Hamlet):
# Hamlet torey th w Hopiaghit iroshit botte! l'et re
#  Hasot.s.  H Ctot mu, mfes Noasg.
#       Horr dy'rndtins
#
# Prediction 2 (To be):
# To bes Hit   mernh daank
#      ta wo Geb. Nadt   Therebrrid t! gs osa mirs.
#     Hyer cras,
#       Sing se
#
# Prediction 3 (poison):
# poison. U Ser seounce roree brir wady wes a Soig?
# venSse on yow o pe hinses Yof crathe thomot ey brrrorse
#
# Prediction 4 (King):
# Kingslt gwonerit toarer Ter.
#
#       How.
# Hery thowarneple ramprepenlr cier. sree ttinbn the Dib nrawanke
#
# Prediction 5 (Queen):
# Queent. sorer!     easls, th. qrart.
#             ,        Hu.
# hessaky norrse betdert yopseey thaemverdand
#
# *****************************************************************
# Epoch 5, Batch 13000, Previous Loss 131.61174011292889:
# Prediction 1 (Hamlet):
# Hamlet oshe dolols wd lirinbe tout     sers os the widg Th aes
#      Thet on        Hid Is alTdiss woalt.
#
# Prediction 2 (To be):
# To beis Th; I dres hichs bowme Hu qu setcabe Thend
#  saj me'aance s I dit s yir thin Thenwt iglint
#
# Prediction 3 (poison):
# poisonTis harl ris-
#          Py as ws kr hit foss   wim;
#      ang Nolt sasges to aicit Te tevdas dar Id ai
#
# Prediction 4 (King):
# Kinges and hencis po'thasbl- Teis mpot ces
# soy boutlivr so thageir bais - yie bor bh ast'soleids
#  ims
#
#
# Prediction 5 (Queen):
# Queeng we ins Whes ald tfig os o qur     mit Thas as ToakM atenas mssefmonbs
#  The. ard tots The oxosh r.d
#
# *****************************************************************
# Epoch 5, Batch 13500, Previous Loss 121.66425502485386:
# Prediction 1 (Hamlet):
# Hamletfcitkirlotets;
# had; bnimndy hedeantold Thewrame ltave?
#   wisbercle dy th- doeranhemile Foss   I uenb
#
# Prediction 2 (To be):
# To beinur colenle whenkadmiss't.
# Qofe wandere repdeensuke Mlralind o boltclecacde,
# nraltbemie ofanmimomdo
#
# Prediction 3 (poison):
# poisonol bxy ces se is hedt rlast com. boungisdetith bus ly aide Thad, wh medorey momoddyowotanheucly ne,
#
# Prediction 4 (King):
# Kingd Wherd; Eralheake, lud;. burgensiesirwelinnlald we iwt drit Wherd oard Thabnethelteldeengaagle be p
#
# Prediction 5 (Queen):
# Queenhelt. lr jynand bucdeennmeenbase ant. bold'd Gink Upet, eom. tonyEudlene wouble;
# oeliterkelth, thent
#
# *****************************************************************
# Epoch 5, Batch 14000, Previous Loss 107.88595881045036:
# Prediction 1 (Hamlet):
# Hamlet mand mineln int in, ar         Tht hansn
#       So ow Ar t      ic             or coum!
#
# Prediction 2 (To be):
# To bef qot yof L uut cd dots
#  th'y sh s wavr fu con's of I baugt man,
#  Ancish thanmars.
#             is ao
#
# Prediction 3 (poison):
# poison  .
#   ir a hror I't, sithelt do o muf I chit Oaxit corecenves folt borenk w  bud '  Ain toit
#
#
# Prediction 4 (King):
# Kingh      Hertinis mut tpins ar ou
# hild doy mrier A tonh
#      ta,
#  io ke yidh ll gorit imes
#   in im. ig
#
# Prediction 5 (Queen):
# Queenn fat in in
#      waece thke    Hant Horlr
#   in thik thtisl hind, torech o hotiinsee thof bl
# w
#
# *****************************************************************
# Finished 6 epoches, Loss: 115.70831533016897
# Epoch 6, Batch 14500, Previous Loss 111.26000812123513:
# Prediction 1 (Hamlet):
# Hamlet pur she wind
#
#   Sd, o ders    amaw th nul dil      E whaud I bu qr theove? th. Ther nof be uum.
# G
#
# Prediction 2 (To be):
# To be on Larie mf yoI soralef lar, in Taun, iu bret
#                tak as
#
#    ar il tank hatd
#     ner
#
#
# Prediction 3 (poison):
# poison, t I duel.
# Se
#       noumr he f ppe laseepiroutt scate er Haas jas. lur ;I .   iw S  Tarech
#       Ti
#
# Prediction 4 (King):
# Kingay
#          Mu thout shountithsrifd mf tim, Dar dattlry tht, thoath
#
#      Fnispat, younk o pu,
# The
#
# Prediction 5 (Queen):
# Queeng
# Whit abt
#     Kor barm tobul     Iir ir Vy
#                Then! the. net mus lutaber
#
# E Kis kis
#
# *****************************************************************
# Epoch 6, Batch 15000, Previous Loss 118.99242070784243:
# Prediction 1 (Hamlet):
# Hamlet dimg
#      futgimn o fert afr ondour er nour u anes onol if
#    .  Se      The ne. pe
#      bod co
#
# Prediction 2 (To be):
# To be on   Pcouttou Fos f in I pe on hadtr ghof ome doule,
#       Kache'th fu w. whange  Cp- yacd wen com
#
# Prediction 3 (poison):
# poison ecow rl.- Rot movous un terit Gu hamave whis med domasm se fvol thans A, deeng Much   of u him
#
# Prediction 4 (King):
# Kings high th b'gim.
#       Lomsdy loee, tomais
#    Kim moerd, the be, comt Ky ge Sh so when we bav on For
#
# Prediction 5 (Queen):
# Queencind ouacom to o  fout h,
#   th heelt Gove whar  foumy pold moraes meie halch vovoutem se de se   ,
#
# *****************************************************************
# Epoch 6, Batch 15500, Previous Loss 93.7218678525329:
# Prediction 1 (Hamlet):
# Hamlet sh taml. ey sh ar adt lener deat matert it et herhin. Teng alt mad po hlee B the re fps imftiy Arth
#
# Prediction 2 (To be):
# To ber         fet thet
#   Fos dors a puf fmad th pst w          portet meth the ir I mor wy lert re mat m
#
# Prediction 3 (poison):
# poisonfrer acdlokg thesn
# Bam Ir le yret tat loud,
#       Han. fe thers Fons yow mtsor fut ber Nad ang,  let
#
# Prediction 4 (King):
# Kingame te whiln Se thot perle the
#
#                  is (E cor dpe me t  O mat
#        sn sofof oir the g
#
# Prediction 5 (Queen):
# Queent terle dos a poan dote cort mue anr thangt part kue dt sat thatt, or oaengheper oph avorte herh to
#
# *****************************************************************
# Epoch 6, Batch 16000, Previous Loss 112.31290222405619:
# Prediction 1 (Hamlet):
# Hamlet.. Heraggaldeenby lartlit. ins, my bot a sh pr ilp.ew
#   ] oudn when me ee. and hame Bunt. hor. none
#
# Prediction 2 (To be):
# To be, enafays mult te wivrid hat. Hastfind WhdaAlsh. yon Fet her wonaw.
# Dowe mu,
# Ant thattand thor hyomo
#
# Prediction 3 (poison):
# poison wiy The
#     os.
#   iw nrir [findersd.
#   He cowhss we,..
# A thiging anglepd an GoguyEufc-lamt Finciy d
#
# Prediction 4 (King):
# Kingdrenge Hakf
#       unbifsd thogidtomoulme.
#  Whess
#         And harne
#   En wyave win mott borel,.
#
#
#
# Prediction 5 (Queen):
# Queeny wias    Bas cpercdRaend in] a c ther Thy Lant mu boung] tat yof so mod merth asgimh moy drrsF worr
#
# *****************************************************************
# Epoch 6, Batch 16500, Previous Loss 110.3987462347675:
# Prediction 1 (Hamlet):
# Hamlet. hi.
#
# ForKdiim.       Tour Te;
#      on mn chh, thit I      Is Ivd pf gomy ? Calm          iu
#
# Prediction 2 (To be):
# To bels thag in le he go. the ditd mo neet liveelcoCe
#      Fit iphe. hophag!
#     o wpe
# hof she! of G- thy
#
# Prediction 3 (poison):
# poisonhit banh
# Qor '            Haon halp whe, nand hid a? noniatte tha't     them, thas uer The qlar mu.
#
# Prediction 4 (King):
# Kinge mathe Lu't thel, that and. rom mar't at iporel Pod or myon dole;
#  Hand thant. 'Whe
#      I moud]
# po
#
# Prediction 5 (Queen):
# Queeng. et'those woorinmengedh.d thus
#      halh 's. LK.
#
# sibpef Sh'te stig.
#       I        fo[gechi
#
# *****************************************************************
# Finished 7 epoches, Loss: 113.87703050606878
# Epoch 7, Batch 17000, Previous Loss 117.68496133437488:
# Prediction 1 (Hamlet):
# Hamleton..Wercid.
#     Bar us thindy iud nand theulpar a konh mamad osor on Baucomle. for mert ir py irp so
#
# Prediction 2 (To be):
# To be arrromlange
# we. yopong yourlirtamkint,
# Hore.         Way, Hory In iu Ko fam. mne brde Tere , oum u.
#
# Prediction 3 (poison):
# poisoninl oint.sHe ike th luve arink oth, E gath; in,
# ty torrieert So coad fuky the Breryast u Aminmik. Ha
#
# Prediction 4 (King):
# Kingoe.
#  Enotl.- O if thamiwh  Theut weut to on
#   Loat Laae foas er;
# Fulpith.
#   Mu tooakams
#            w
#
# Prediction 5 (Queen):
# Queent miget.
#     arinw muef tialt inte woels mrally or       Thopl urhary Rod,
#   But mory imer aw wy lu
#
# *****************************************************************
# Epoch 7, Batch 17500, Previous Loss 134.35740868538517:
# Prediction 1 (Hamlet):
# Hamletos.  E su, dy botyit? I wing biks oaypmenunt se sige yor, toy at. is,  Sae Por, yotk Bup. ar. Hol'un
#
# Prediction 2 (To be):
# To bess moter.
#     boxlltimde a hot bucllr theilasc ast. ore
#   ant aounmamak, ir, bisaw Qans, in
#
# Prediction 3 (poison):
# poison. Pot. o riy tone.s lut wobd in Hidl't y the murp thort Pend lur?
#       titpave this, fins   Oroucam
#
# Prediction 4 (King):
# Kingt lus I,
# yoans dint,
#   I youple thor sous in..
#  Burs fat. .rot ol Qe ance  o bom biv. it ty sonolinb
#
# Prediction 5 (Queen):
# Queendist. Ket nond gs.
#   boklge bodd woagt, Pnd mogl, t harn dot. ly cond cigs Bosc'am pesdhiginglinging
#
# *****************************************************************
# Epoch 7, Batch 18000, Previous Loss 110.98852226553828:
# Prediction 1 (Hamlet):
# Hamlete hewend, menveeep iusthins ther A tier
#    yraer wo ol poatengimate woonoleug sowhinkerenbafboone. t
#
# Prediction 2 (To be):
# To be, boourofow toernot.
#   Wiid voanhgrings ouxt's peogples -faer  ore Hamlos sfounapese tosewes dourit
#
# Prediction 3 (poison):
# poison fod how eukpurbe henthilteds   fasd Whof nor
# Tinbatevot seinvous
#      nuis so zee wpeebenge lene Qu
#
# Prediction 4 (King):
# Kingisense.     nous opeeldeavedpante. pe Are
#  ]               Dove uiund Younder ank
#         pow on
#
# Prediction 5 (Queen):
# Queenbat ave dive.pobakind sicl.
#   pout muste           owoy iDiy seebe whe mirunlee woon, a mast
#
#
# *****************************************************************
# Epoch 7, Batch 18500, Previous Loss 108.94005338316123:
# Prediction 1 (Hamlet):
# Hamletheef ly is thowt furtout
#      nos.
#     Githeed
#
#  Ot cos, nos eoghey
#  Rot ind si
#
# Prediction 2 (To be):
# To be ishiince.] Gat   mile urounsh galirlut eot mu wes it ther bucing; ore- tnim imorrilpiut a cod se ps
#
# Prediction 3 (poison):
# poison t; Gaage whllils,
#   Theugvatdinthing
#   hive timilt [heshind lus; erllmoend airs iturithe; Cor sefth
#
# Prediction 4 (King):
# Kingerinpcit; dolasit;
#       sore? wive hishewleld .          at, plow so t therrer iswe, a      Ardophi
#
# Prediction 5 (Queen):
# Queenthingy cens yope wt iradh Yeanmenge He,
# Hees   A jint Younhipitithinkith a ur yow ir thouw
#   poid gw
#
# *****************************************************************
# Epoch 7, Batch 19000, Previous Loss 121.88682294737005:
# Prediction 1 (Hamlet):
# Hamleth ther sloum wor. a ge sik. A then
# foun
#
# Thathe ther. nou. oxt'd spos moon hoef
#   Hs. thy is orhe.
# M
#
# Prediction 2 (To be):
# To ber.
#   Whisn if so syop. aree ade yof wept ius toe
#   ; Thesc'ppaantlt his.
#  rasaer orete which a y koa
#
# Prediction 3 (poison):
# poison foaurh mror maed honef hat cind in fadetes mors Hamfssesd auus dime br; hat .. Oertle
#      walt a.
#
# Prediction 4 (King):
# Kingo ores,, th in
#   Haws mislame il he ushist mxite, wongind im]   [dangcoel..
# heim woeclsis he Of wo k
#
# Prediction 5 (Queen):
# Queengo thes Hate domaar weame tarreit'h pe yias narbasligmit mosrsere,y wos.
#  Of poke mas.. aan on hilin
#
# *****************************************************************
# Finished 8 epoches, Loss: 113.6023385226652
# Epoch 8, Batch 19500, Previous Loss 105.5753651523738:
# Prediction 1 (Hamlet):
# Hamlet hathtaopyse thavte. A we laclts!
#       Pong, Pouepeag 'fersy tave    A A de. oxoshild Muldte Antres
#
# Prediction 2 (To be):
# To ben,se,, anvre of       aes helscikinga gt fyky arh foeee
#     A h we! yodes.n
# dillr. neme
#     iwlaen,
#
# Prediction 3 (poison):
# poisonlesll iy, arisige Mouus!
#   Moee lash. nult.
#       Alot Ies    ars ooconhe ach oe.
#     Ther hadisseni
#
# Prediction 4 (King):
# Kingenge hol her th re se ancey hav-
#   Por; oveus     Aech fore il Norelc Net nethe ar.
# heenseis. buvee!
#
# Prediction 5 (Queen):
# Queengeluge cEgd therye cot bont yof yoole  Suaciich thingeBith ve deartiint,
#  we, ant; lats herses boven
#
# *****************************************************************
# Epoch 8, Batch 20000, Previous Loss 121.1427035980005:
# Prediction 1 (Hamlet):
# Hamlethalyeth tooandy to e ther Hlaand quoy ae moerz ll Ray antiie lamess binbamis. aminthome.
#       Re iu
#
# Prediction 2 (To be):
# To belyoarh ke, ate ef and thimibo boy rye doot goceescot thofnotoand duome; us ans,
#         That thant.
#
# Prediction 3 (poison):
# poisonon hon ageeas onartanct. teottaecor, oreexs Cray
# Toeugenh Rey?   that t ulyawc thicker a the,
#    ami
#
# Prediction 4 (King):
# Kingars ssoloes oripce-
#     noakoe woouts.         ! epaon orime yoy llery thit hy, itay acd murn to bim
#
# Prediction 5 (Queen):
# Queenteagz ooy motkid non thes, pate ou qingar ath, urone- diett thet, mond, watico to thall
# issacde thea
#
# *****************************************************************
# Epoch 8, Batch 20500, Previous Loss 114.06242727346257:
# Prediction 1 (Hamlet):
# Hamlet pu.
#    ou le. th. niam u    , toyotee doye,
#       Him K, tkes lumy a welw anory as.   hmich long mu
#
# Prediction 2 (To be):
# To bec. ae, moyecm,
# se figiin,   Qu asdaud por.     Has the erit.
#
#  cirideutly Of po blangr ome,
#       So
#
# Prediction 3 (poison):
# poisonophe shas Sameemos.
#   Hiak a.
#  Ateaat hee manises yoy ringloe s
#       Gy onclatime,, ael.
#  Avende
#
# Prediction 4 (King):
# Kingilhyeee yore yoy Loy in yeeas an.se dpaenkep.
#
# y. punditoellae, ee th moy. s  Hadimlivesfeamingee ka
#
# Prediction 5 (Queen):
# Queenn wee mimethen oneaslowate,
#     may bo modl.
#   'as y thamer.
# teem   Nlat Ho inkee's opecy anl saup.d
#
# *****************************************************************
# Epoch 8, Batch 21000, Previous Loss 101.21123564039722:
# Prediction 1 (Hamlet):
# Hamlet thers yppod o        an fh- yeedsresf; heth sh. o bow. I bynresds:
#   roy muntt I. has t mat'd and t
#
# Prediction 2 (To be):
# To belon I.
#    eler orouwbave c fe ef have werte frout I Corouft. whor.   Kathes
#          ailcovech tLe,
#
#
# Prediction 3 (poison):
# poisoner w srat mond ee-tdeer yowe E rle fiss the pid eigh whad Kanh sooned the dh. uwe thalse
# pee she ber
#
# Prediction 4 (King):
# Kingfapt] sarchy whou o, cr? dem weld vaos Ke hiich I herrr thil.
#   t wo whe veus o ox.           Hoof I
#
# Prediction 5 (Queen):
# Queengde derf onet wherf thoph In Khatert ive lom o in she halh wo yEfhat that bous chiult fke wtow coor
#
# *****************************************************************
# Epoch 8, Batch 21500, Previous Loss 132.0259023326727:
# Prediction 1 (Hamlet):
# Hamlet Yowaus mant.]
#    Oe in bomp yhit.    Owime.s woroans yos .      Lit Kem be thers aalbarus the.  hir
#
# Prediction 2 (To be):
# To be    OOcom.   ise ssst orraam tive] thdalie gay! theeirr to-f
#  Peimy dureind thit muns. Qech Luslit t
#
# Prediction 3 (poison):
# poison. wart mall Lansagt t. The wacols y ip, the; cods] Haunry o Ge,
#        Tyg.
#     Lon
#   semare so har.
#
# Prediction 4 (King):
# Kingh trot soves Hykack yoand on is! cuy y is s mas hy noare ['Thot.
# fe t Whe freng, by tas Ony w' To mo
#
# Prediction 5 (Queen):
# Queeng fy th.   ly swe thort lo digdit w Qus, come imy Sc dinceagr. the lu]s Kink?ut harcos; and.
#   Hous,
#
# *****************************************************************
# Finished 9 epoches, Loss: 113.35350375192827
# Epoch 9, Batch 22000, Previous Loss 112.1725653227934:
# Prediction 1 (Hamlet):
# Hamlette siir loniret,
#     It theecetisgtanh biy
# Aid Haup heocteltate th, ofis har thiun ins't
#         Har
#
# Prediction 2 (To be):
# To belts sy Larst. Thnth forint wy murenceath agy that crind munchangorltliw ere munds ir heont tomlke Bu
#
# Prediction 3 (poison):
# poisonaste rror ate anon honenthid to'd mtay cugolle, phiter
#
#     at ginh
# rente hralllte
#   mus.
#  'pourd
#  !
#
# Prediction 4 (King):
# Kingbans llach warery tharn, bonn, thy hit thintres I ther uxilfse, brit kotse melsg poc.       tand yin
#
# Prediction 5 (Queen):
# Queent bante, thas'd a unr yorimate
#     Pos.
#
# Hirt thild in re. thlay  thrilg mitee,
#   hanglatll hon Di
#
# *****************************************************************
# Epoch 9, Batch 22500, Previous Loss 116.28620028738449:
# Prediction 1 (Hamlet):
# Hamlet, Olithe shoy ay hol. sor. it.
#
#     .         nulee rey v't avette w my hit mermaut coadse my wes
#
# Prediction 2 (To be):
# To be of. A serbre ibme barammar! irrits ferss hy lneuns'd.       hoy'sthofmr, mors
# ricot goder dol- hyer
#
# Prediction 3 (poison):
# poisonatserltim. Ame luly, oar ut whe wy mr thied verlr- to tiver wheivevlderrat eigsllliy fotemerells hmo
#
# Prediction 4 (King):
# Kingisher wes and eef lere wither thenkelwidces, picitameteuoms kur. my Dae hise puds hleng,
#
#
# Prediction 5 (Queen):
# Queenme yeeted thakly omh ors ther shlr'd,.
#   Narrtisemlees os. forik wiml shell.
#   Wh [sierllmey meee se
#
# *****************************************************************
# Epoch 9, Batch 23000, Previous Loss 109.6895219672394:
# Prediction 1 (Hamlet):
# Hamlet sroundy min net yount? onam thag; toisgitamenvelmn t musg and thof
#         The! ther yof to u ted
#
# Prediction 2 (To be):
# To bech, muts Mu?
#   sfiop Poch goint not fl,
#       and im mo pokr mut thy mind and
#    E a hat tee a
#
# Prediction 3 (poison):
# poison Pout nfcois wam thive. er sit, it at ppew     Quftn lterote
#   Thianr Kart
#          Mn at cougs luca
#
# Prediction 4 (King):
# Kingund luns se a bant a, a.
#
#
#    'fSirf the. avee geen hing oet, that   I 'cres wh'n o matd
#
#
# Prediction 5 (Queen):
# Queend
#     Aab of a Prang hrer,
# Huntt sltgeytanan tgat Lact Naerl; brrts the.
#         oms tEcot or Qles n
#
# *****************************************************************
# Epoch 9, Batch 23500, Previous Loss 114.93763927125876:
# Prediction 1 (Hamlet):
# Hamlet vudt. merchnot wo muthe
# tee
#     Hathengutrusinks buvevenc there?
#        otkant ant. cors   Axly wel
#
# Prediction 2 (To be):
# To be ing bate'l a Anqlertpe the wit is krils gle, sle- pur,
#   I lant And sord'sst Muam beraentear I corn
#
# Prediction 3 (poison):
# poison cole tharrengh rerech, onemeutce a,
#    Nor kpteson.         anh'd qy Shaufpe eud eort,
#   have pat m
#
# Prediction 4 (King):
# Kingatos u bp mlas I lushT'l Keme m. hyar nruld.    A, thal           aed I- foure fol, thact I yor dave
#
# Prediction 5 (Queen):
# Queenge ment.
#   ayerhopit yos thar meer thaus and-
#           Whins fols of hos
#   ofthand I beech uroueny
#
# *****************************************************************
# Finished 10 epoches, Loss: 112.55244917160543
# Epoch 10, Batch 24000, Previous Loss 117.8835729128546:
# Prediction 1 (Hamlet):
# Hamlet Hiy thigh git Eun kour yoaklisserlavom on to avir, the.po ir. Miout thiltasef wo weynath Ki.
#  wam t
#
# Prediction 2 (To be):
# To bee rer'p [fot uf at thech as, I a,
#  Goou oitabige shagh g thol.
#         Do lauthank, this a ding, are
#
# Prediction 3 (poison):
# poisonhee,
#     hou thop ghbagis Fik trame
#   Had to miow I o arc, Musf
#   Hats as I hit. A ke Dike iuter Mao
#
# Prediction 4 (King):
# Kingt the a. im, Mergpe Tik?
#     okrerisse rre ik? in
#  Min sie a ?     theasesp! Lanve Poant for I f
#
# Prediction 5 (Queen):
# Queengy so toafr he a git mr.
#   Baak
#   I the fopd ot onies bospa, ap. Thnr forS llat a he coown ae, forI
#
# *****************************************************************
# Epoch 10, Batch 24500, Previous Loss 120.06296443198165:
# Prediction 1 (Hamlet):
# Hamlet's.. Rowtiyt. Wheill. Cloy
#
#   Tyellly
#   Th. Pat.
# [Hinde
#   if
#  roty oon thes tiveent my le tonoy,.
#
# Prediction 2 (To be):
# To be.
#  Eriy He'satbinlenryRt,
#
# The Rilatong omand of lorl,- onyst the o firs aoy bnhe Olile inh Rorle
#
# Prediction 3 (poison):
# poisondodlootinnsote and-
#   colelg to o sy lde tibesst. hink wivind thald, soytir, mpisn Gall w ope on TRo
#
# Prediction 4 (King):
# Kinger guudL. mons futd oralittnry is pr, Roe, lian
# Reew shorlens thid in ou gyveliud.
#     Rrild, thou b
#
# Prediction 5 (Queen):
# Queenget.     R,
#   Rus irre. w imotorg, On veel. anrcist honsind
#
#         Relkirslaat. thitoelt. Ne opl,
#
# *****************************************************************
# Epoch 10, Batch 25000, Previous Loss 119.1427778221408:
# Prediction 1 (Hamlet):
# Hamletgaech.   modt.
#    rer
#       Hoon wocd so iy Thour youpd gike thittavefrld yunmad yy il boud hy, fol
#
# Prediction 2 (To be):
# To be
#
#     And-  Thour ly dooms chiced. orer gam.   I ur Ie putf ghyows sonl sf wiyk andae why whav
#
# Prediction 3 (poison):
# poisoneld pagocd u ang afd andor sur Eeut coult! y yonrene onhothy owive ln- Hisenn fed poen Mosladshave k
#
# Prediction 4 (King):
# Kinghaly, yret I faldhe rnou I hous iw of to dad a latimirseuw onowhers     I
#
# shoter,
#       The Iment
#
# Prediction 5 (Queen):
# Queend ike, marime Dorrint thaautaunt In athdtithe he- moench hiow, pnon sime mart Bod whence
# O dreltels
#
# *****************************************************************
# Epoch 10, Batch 25500, Previous Loss 106.6987685477111:
# Prediction 1 (Hamlet):
# Hamletonsrate se t satomer,
# I has
#       nolss. eeangitrilt thildone
#  amy lben wirhe   athess. nos   anh an
#
# Prediction 2 (To be):
# To benkas fis, ueut thiwy
#      wemoboll unolke Qlase cosintals lThat cod.       sous muves whiwh, matem
#
# Prediction 3 (poison):
# poisone the, mimwoondlvins il, id we, uogherse? soes gus yor Lrrerse crict
#  haght t cortish; weh pobllsos
#
# Prediction 4 (King):
# Kingersele, langlendatrrirrremhele as sostice my forme wherd fe!  onrestirefmen, irllrt tondaw,
#   yol. o
#
# Prediction 5 (Queen):
# Queengoyt'd therslam.
#    Lont
# T' rotstoumires henhirerfalerwis wo theris, ert obouthel, a Or, gorwetdithi
#
# *****************************************************************
# Epoch 10, Batch 26000, Previous Loss 119.09526643346159:
# Prediction 1 (Hamlet):
# Hamlet. He.           I' surt in thon tas Whante ofir, For thoron a ther mlikhc's had ereate you bindat.
# f
#
# Prediction 2 (To be):
# To be thivind
#         !  Wae kotaee maw  Theer, nowhus ror mr.           Hu.
# fur? fowed.
# u coun ararrsans
#
# Prediction 3 (poison):
# poison thecher
#   Feeve morimh s wis.
#  tuas wotidter it je thit oumee py har Yof lat tharen ox.    mae't So
#
# Prediction 4 (King):
# Kingteld her whachis Por tire Cive thirtiitet It han. ; Teal ther ou
#    Tit.
#     Cu the min was t the, s
#
# Prediction 5 (Queen):
# Queentoram tole bl.
#       coas
#  iin serackn ra u thhot sher hes foryte wauqo thar,
#       Har wyes
#  Wann s
#
# *****************************************************************
# Finished 11 epoches, Loss: 112.09656754090025
# Epoch 11, Batch 26500, Previous Loss 120.27055701721164:
# Prediction 1 (Hamlet):
# Hamlet, keunss jarrinte sowof thotderp it sey weeroulalitosse Il
#     siams eod her thaber, un Ith beey u o
#
# Prediction 2 (To be):
# To beaon!
#      Hatf yofernrreps
#  in pus doramirest lureme'd,
#     The wens h hirtinh thind baos manche, fu
#
# Prediction 3 (poison):
# poison had thamre. pitrilt oenke's. Vrauch.
#
#         trans.   His ey tow, cofs huraw and tome a pf of pat
#
# Prediction 4 (King):
# Kingle a Ith dure shern thir weuf, pe culs in wive,
#    aat thastort so thour ce shaenbrad, set, werrre c
#
# Prediction 5 (Queen):
# Queens,
#   o at, indnreroof shep toeessled axind I woske um ang he Ard, Thend urste unde Thivetor )Tsess t
#
# *****************************************************************
# Epoch 11, Batch 27000, Previous Loss 103.55446837371831:
# Prediction 1 (Hamlet):
# Hamlet irky theng.
#        at then I thas engd fild ates folte
#          On tfley ffus an buy
#   E comuc.   a
#
# Prediction 2 (To be):
# To bevee lation kngin, Kit.d fvot  :      I
#    And le wigh yon nod go, as, ble Key bere jor.   Lafme fouo
#
# Prediction 3 (poison):
# poison owin du-t Kilt dat Konet ulon bpe g  nos thaut mtencintgc.     -it bantdeldzid
#     Mocl hy thit the
#
# Prediction 4 (King):
# Kingay tay, a nolore. ae mutg. yoKt sh I,
#   Whis thenays I the day fnort pser thin th.
#        B im Hante
#
# Prediction 5 (Queen):
# Queenesh and the sing gachKigs Tham u,
#      Otomit.
#
#       Hinm noit,
#          A bat, dle
#
#   Acg Pougf t
#
# *****************************************************************
# Epoch 11, Batch 27500, Previous Loss 103.70152161201756:
# Prediction 1 (Hamlet):
# Hamleter in! hatit thas, harfe Whe kist tler I dos hett faln se, thans serctsnte Fontdt. loouriththetites
#
#
# Prediction 2 (To be):
# To beem a fofnaw   Pralare fnou veotge en thit.
# unlagt Ne yowendenst. yat. tharfercrefr rrodlet we,
#
#
# Prediction 3 (poison):
# poisonoatgarer tianr hatteny sofllinew halt
#
#    allnowel. Whathounw and bes Hatadrlare ot tonrris toaass w
#
# Prediction 4 (King):
# Kinglall noltaendtayfam.
#   affat pet, ant, aals, warn thans andtgam tiance farfy latter that sounkte tha
#
# Prediction 5 (Queen):
# Queengerinlt Tite
# e'dabse amles
#     Waat wo a thoaul   iinbicgaduttint gortey herer fous Pon noullrlet he
#
# *****************************************************************
# Epoch 11, Batch 28000, Previous Loss 109.01387259976069:
# Prediction 1 (Hamlet):
# Hamletsorte coos merer there they Kithe
#   ras]
# yrim arilim.
#  A we.terelly z ,
#   Hoteavhenigtackis per de'd
#
# Prediction 2 (To be):
# To be.
#   Bay. thes mome thee theethe thante?
#   Arr. onendeno'r. [fort, lune moll dincettte,
#   [Kither, po
#
# Prediction 3 (poison):
# poison] fathouint thelp kill Fowels, undes
# Bdid, ofe stache herou. andhit mavew!
# Deycanghilet.] su? Fer, o
#
# Prediction 4 (King):
# Kingamegle febisen,
# Geachomte sheglles sereserelllaseld.
#  Es andisse those male ase pf a slee wearnendel
#
# Prediction 5 (Queen):
# Queen,
#   , Gseree
#  Ofe,
#
#  Thessgy Monwhetate thass thepe. pos. il.
#
#   As;
#
#       Andebs so?] softdoinken
#
# *****************************************************************
# Epoch 11, Batch 28500, Previous Loss 106.14064569363819:
# Prediction 1 (Hamlet):
# Hamlet         Late cly to, a sher't HinlS famle shell
#
#       Haak mu'tser h.
#   Thilver mlaue so le nri-th
#
# Prediction 2 (To be):
# To be theellren Ef
#
#     Hus
#   Buerqu terdh ae'll a ter reut thee mim.     Hee nomee Extr otech thauiy't.
#
# Prediction 3 (poison):
# poison;
#   Horutenfrel bor the nad Ther ail    mit,
#  Tone weer.
#
#  uus
#     Lonts re dhmer; mre untes.
#
#
#
# Prediction 4 (King):
# Kinge thinl.  En waer Ishiw thend tans shre toy colen
#
# iklat.
# He pe bnlln thes sirls.
#       a gn.
#
#
#
#
# Prediction 5 (Queen):
# Queen o iles dwian.
#
#   So he he
#       Hat? nomanl]
#   a luns Yous her anot.
#     Ereinttes com oralen mler
#
# *****************************************************************
# Finished 12 epoches, Loss: 111.69178654674621
# Epoch 12, Batch 29000, Previous Loss 115.0843769148636:
# Prediction 1 (Hamlet):
# Hamlet, simailtind dith Band t Haveuds lill   Or daapbidcayn and sow at, tiendy thar of anlss
#     How Qivd
#
# Prediction 2 (To be):
# To bemtes
#       Yalt To ase weat, opr
#   wy u wolurlas toy m'drime
#   I se
#             Fod mand Burn ham my
#
# Prediction 3 (poison):
# poisont! holdtamre wpan. Erere thig?
#   Hart luy dhofind at simath haes urvit Iaml is! winpt my- ilend mled
#
# Prediction 4 (King):
# Kingd crad ly cus,
#   A,
#
#   ' sottos sind
#         Eudes seyse the wf col yad, doutd Hany I mlendamed a
#
# Prediction 5 (Queen):
# Queent ind lendiit innew Nerte nind, thanrosnild ory wirntenl f ur keld brads your ufd;
#   Muldlent key.
#
# *****************************************************************
# Epoch 12, Batch 29500, Previous Loss 119.11512027879114:
# Prediction 1 (Hamlet):
# Hamletaes that s'k sh.     aer bet a,
#     nol fome    Figmy ber of manes iupe by wive pe
#  Wtilt cind ee,
#
#
# Prediction 2 (To be):
# To belble, Hir, yd y my whe lateufn mer
#     ath, of nole mact Owe Prale fow thygn.
#   ve, leil', apcett mi
#
# Prediction 3 (poison):
# poison laalfy and tfeles, mthinlur arY ut, irll
#   Wo me?
#   Hold Git sl.
#   [Heelm set dfoundey mell lim as,
#
# Prediction 4 (King):
# King?
#   Pow ty lxild late my by to bre les, onou. with thy the ig terlr till bort, fons lamcol thim. lar
#
# Prediction 5 (Queen):
# Queenh and moxg he opiatclas id, a, I,
#     Penenbes thing wevol., livloo to, wow e, linl inche mret me '
#
# *****************************************************************
# Epoch 12, Batch 30000, Previous Loss 101.19342875597413:
# Prediction 1 (Hamlet):
# Hamletime breer lord kikhitt, pout Fver wite ey thegsiy waesdasel.
#        Hlee re wees,
#          Beres; co
#
# Prediction 2 (To be):
# To be an. iretacech and hed a withee kee wercsinr sheeate so lives.
#
#   Sher , bery ane mlert le shes;,
#
# Prediction 3 (poison):
# poisonene visper gy phe thter yon paansdee wind
#       Are wo akerer toshimellenc.   Se miset befete noreew
#
# Prediction 4 (King):
# Kinghevelelis heetode mundhee are na.             athe. Is a feree youushirQo!
#                 Weewbinh
#
# Prediction 5 (Queen):
# Queens. De t pliof)      Qavor toavadte he mle melte the Ne coup ilt a,
#     beenn df thing
#   I eed atime.
#
# *****************************************************************
# Epoch 12, Batch 30500, Previous Loss 92.34105007665251:
# Prediction 1 (Hamlet):
# Hamlet, Aer cind sceus
#            Abole Ly non atcip so'w therer thir,
#     is.
#   O heltey soit ee,
#     nod
#
# Prediction 2 (To be):
# ...
#   Hov oungh sty for-
#   Hood o on
#
# Prediction 5 (Queen):
# Queenim uch t tar, Pout so Ken.
#  Sate's]
#   Horee ce;
#   Have my the s onh. I rrare hings the
#  Anbed m
#
# *****************************************************************
# Epoch 45, Batch 110000, Previous Loss 94.21415449944428:
# Prediction 1 (Hamlet):
# Hamlet?
#
#     Thing Ig tarno owent, nomrar,
#  Cist youch ware sinn thasshn,d?
#   Tot I cock, anh your
#     The
#
# Prediction 2 (To be):
# To bentrem;
#   '  To bas swowenor'
#   Kingssdy, muis and,
#     Anfteny, t thlt wipry't   o cougicgento (shad
#
# Prediction 3 (poison):
# poison- wire;,
#   In m plout the is moilouss.
#     Doefw Diderer, his sect verlimteenn hinghn nenis enh to t
#
# Prediction 4 (King):
# King
#     o bofling and weang as in ont in u to ly mem t but meaat i'd- diy, foranges ae thut haseln noud
#
# Prediction 5 (Queen):
# Queent,
#     Tomest.
#     Theargactonting,, ise you his nok.
#       Thin-
#     Th' Sang; t lnonf, uar Cervers
#
# *****************************************************************
# Finished 46 epoches, Loss: 107.71114586959257
# Epoch 46, Batch 110500, Previous Loss 100.20609576958577:
# Prediction 1 (Hamlet):
# Hamlett pame lerrene honr it ing than a male hor. A'gounln.
#     Tove orols, hoolikymat pectoe beingamithil
#
# Prediction 2 (To be):
# To bee lale hall thell matcidpe Haven tosht my of'epey moud.
#   Ervin the met, thele ade c witce portill o
#
# Prediction 3 (poison):
# poison if and'd noblaty your sive wile and boonh nound shin tsess; and ind.
#                 'Eram. Holcto
#
# Prediction 4 (King):
# Kingais uf stot and tomo gath!! But bitile Sorudrim., maar it thiening a Hakl meyer. E pottirt' For.
#
# Prediction 5 (Queen):
# Queentermetiant deisenont. I't s'tt. Be eed nomn thas tom.
#   Hasin out thid thase!
#     But
#     You an ls
#
# *****************************************************************
# Epoch 46, Batch 111000, Previous Loss 105.66279189919243:
# Prediction 1 (Hamlet):
# Hamletarron. Wing.
#   Gufler thanke youocrencive woret qunme thor I ays' un, ony wonom pavrims; youll!   Ro
#
# Prediction 2 (To be):
# To beakt,
#   '' Guthis bend, suayny nos you dinct of paof pouk noliner you podtay, maser.      E a wo that
#
# Prediction 3 (poison):
# poison, a'd to taet- dlutd the comratherrot weovens!                  wigkey eom.
#   Kouuds aris, wlour qus
#
# Prediction 4 (King):
# Kingull shl'dent.
#     De.
#     Ce lioled funkvelen
#           Ree heens nith yrres I my whas, iesle theur?
#
# Prediction 5 (Queen):
# Queengrank, oond han, the song wnom goureacy noul thaonenw pall herpe trech ton? Congimoe me. Burr. In jo
#
# *****************************************************************
# Epoch 46, Batch 111500, Previous Loss 96.78353315547129:
# Prediction 1 (Hamlet):
# Hamletele.
#
#
#   Hangpoten of stough tomaser. Hy; afrsing maanss afd. I mered. Ae spenbit shatrenge ger sea
#
# Prediction 2 (To be):
# To bees
#     You ne prow, een.
#     Sowy adhas bigh
#   .
#   Woovils.
#   Hache! ell my to Hage eurke.
#   How? A
#
# Prediction 3 (poison):
# poison withermell le lo tonfeler.
#   Freaoke do.
#     Thrans so youp hererl.
#
#   Hame th 'ty poor.
#   Laroute
#
# Prediction 4 (King):
# Kingees, Haor, wnorer' . Oflling
#
# Hany gree
#     Mros ses sinh weese.
#     Is bure and by, dhive forees ll
#
# Prediction 5 (Queen):
# Queeny luce lork
#       Harr?
#   Him brers wurd and saw.
#     Hauk our digith doll o'd st. fout my band.
#   H
#
# *****************************************************************
# Epoch 46, Batch 112000, Previous Loss 91.28465349375543:
# Prediction 1 (Hamlet):
# Hamleththe g: my cais
#   King sore Learniverne o  Nuto'l thes muse clorounke med henlerer,
#             Mang
#
# Prediction 2 (To be):
# To ber your seing stomale eris!
#   and wyis
#  Eoth not dpee therse
# Eferite you wet my bnavid palde mame bri
#
# Prediction 3 (poison):
# poisonsear ur eor cot. Arlad.
#   The gane, in in, eld! Ks.
#   (  And ln ne marnaor.
#
#     Ases u!
#     So and
#
# Prediction 4 (King):
# Kingith,
#  tere, puwe!
#     Sincsed.
#   Sware you heus
#       Whe feis nos!
#   Low. I dille hor, Lerlos.
#  Has
#
# Prediction 5 (Queen):
# Queend ch, and weciivteer shingte and dritat bech. Voble'd?
#   les y's this the uss
#
#
#  Leelg, he
#
# *****************************************************************
# Epoch 46, Batch 112500, Previous Loss 102.16459053653313:
# Prediction 1 (Hamlet):
# Hamlet, ald live yrut giting.
#   Lutt kouces? in. ing I lentNst lulveger pe thant wicl slne su hagrerLet pr
#
# Prediction 2 (To be):
# To bey nos
#           -wise! ix uid and gall wise is on affend
#   you
#     In ingo wincill and potllfpherth
#
# Prediction 3 (poison):
# poisond histougto how'd
#     Hautie, o de.
#     Or llouss, ? Theencond
#   fis You wand,
#     Hor four.
#     In
#
# Prediction 4 (King):
# King; eef, [Youge..
#   Keaorse a hangly wead couge sheve cach
#     Therins
#     Korald from.
#   Heus ques, o
#
# Prediction 5 (Queen):
# Queenme this a, yornet, id llor woroyce whow- olrerg
#     Lash. [come cole then
#
# *****************************************************************
# Finished 47 epoches, Loss: 107.64395167056766
# Epoch 47, Batch 113000, Previous Loss 107.44651254488538:
# Prediction 1 (Hamlet):
# Hamlet ilive
#     Toucht in, an noss ricy theng- ronder
#     As swicher moucheet.
#     O- use
#     With tingde
#
# Prediction 2 (To be):
# To beards and shar yiton.
#   nutasccew and com
#   Harerly doand sericangithretiige.
#     Be thinge of thog a
#
# Prediction 3 (poison):
# poisons. fot.
#
#     Wtor gicd elline-
#     Thazgch rtonl m, farran.
#     Is rogheancchoud. Whetendce. focthe,
#
# Prediction 4 (King):
# Kingaav, musinnigerii Fave
#     I thergintce wer; the
#  wet, Siem- sourf,
#     Be
#
#   Hor. Whear paclosine;
#
# Prediction 5 (Queen):
# Queen pord dure whattid ing tounth'd tossef thors fan'dee
#     Wheathe fper of to fods utht menin. A Vevlm
#
# *****************************************************************
# Epoch 47, Batch 113500, Previous Loss 95.80672475471744:
# Prediction 1 (Hamlet):
# Hamlet be nenet shse hell, larh-
#     Bede yik your yonrom tham fril che ur heres; os
#     Thache-
#   H
#
# Prediction 2 (To be):
# To beas.
#   Harh bet so.
#   Howmy is whicof'd my he hed whe meucy puch ser.
#     My cue and lule thess. By s
#
# Prediction 3 (poison):
# poison. Wes' the no me with su her.
#
#     Er vourch his kutime lur vaid
#
# Prediction 4 (King):
# Kingas mosthe blienr's tht lodllaige yougcer most a?
#   a path eng pindt he linste com' me ank eok? heus
#
# Prediction 5 (Queen):
# Queenl mlowiildh. I      it, hy matceals,
#     I dom, mas, lo?
#     Tiv.                          Pars fose
#
# *****************************************************************
# Epoch 47, Batch 114000, Previous Loss 119.99826625760215:
# Prediction 1 (Hamlet):
# Hamlet,
#   Pove weae frile. Wotr'd we I tce of ran. To all thes but s!
#
# '
#     O's atd we't? In canik
#   Os?
#
#
# Prediction 2 (To be):
# To beorte ther
#
#   Poles ther for Ghe haas shas ercet so in conn crent a your trin. nend's thiff kutram
#
#
# Prediction 3 (poison):
# poisons to hel you, paclildhe of goth;
#     I'd pive youe
#       If cpe, I tat frout grind. O s; so thiste'd
#
# Prediction 4 (King):
# Kingherserse. Then        And the thathct atsenbund                             Fowst bel anl. With se'd
#
# Prediction 5 (Queen):
# Queend'euch momallK                caintw.,
#          Ot my'd wastits caut
#
#   Asd
#       O thes t
#
# *****************************************************************
# Epoch 47, Batch 114500, Previous Loss 114.03370266302969:
# Prediction 1 (Hamlet):
# Hamlet.
#     Thy buthisem'dsher. The. Glded?
#                                   Bose ltim. iin proutoud boci
#
# Prediction 2 (To be):
# To bens yave senie' in ticteytaye
#     Be therpereln sod, ham. Mang sit mlt yofemaance tour iad wleurpe al
#
# Prediction 3 (poison):
# poison fat bermlerissen. In lasen my Harl serd- sperer yosen meysilltaymetiet,
#                    Rod
#
#
# Prediction 4 (King):
# Kingend, nothangs as me thom wuocatherItirravingents You, I. an, hmlulet ture?
#   K ict,
#     I I and,
#
#
# Prediction 5 (Queen):
# Queendemaidteuch offcinh avoqyenh. If countbring eld eyitr gow yer dowenring hienriing thit Go trever. No
#
# *****************************************************************
# Epoch 47, Batch 115000, Previous Loss 91.5221680396234:
# Prediction 1 (Hamlet):
# Hamlet his or lirste is wfol, ttam.   Axco, tharn.
#   Hame waon theth thythanc!
#   [Fing the the nousie.
#
# Prediction 2 (To be):
# To betcthengamoinle.
#     Tot whave thell mlou. I and to ind of that hien Now. Bist o of so thol thang.
#
#
# Prediction 3 (poison):
# poisontere wey ce lartt. Theste a ce arkech.
#     Hamy wiv frinuf yis bat
#   Er. Thate
#  ie ther, fold.
#
#
# Prediction 4 (King):
# Kingantroutinglly couthis clert wit in Dead,
#          I rtgaanh!
#   Hamlatkaon byad   Hast se! Nouuth mor
#
# Prediction 5 (Queen):
# Queenw I distlert lim. Afd'tse dheve. ul trthas He whoseasest
#
#   Promen. I on theedd pived hangpes.
#     T
#
# *****************************************************************
# Finished 48 epoches, Loss: 106.41474752701248
# Epoch 48, Batch 115500, Previous Loss 86.16236122274023:
# Prediction 1 (Hamlet):
# Hamlet! Se ther. My ton!   Is, crom orl. Haare,
#   Sunlm. Catcto in!! ill son! st, Hamymimy qely o hom. Mo!
#
# Prediction 2 (To be):
# To beech lool mase lort?
#   I my sTavis, Hakm wime to uxlurl outonil rove, pr fain!, br?
#   Mar.. I bo, and
#
# Prediction 3 (poison):
# poison, ur.
#     I borl, llom,
#     I
#  Wht- ooute lut ibst,
#     Whiilt, beob bipes yroct's sring monss, uld
#
# Prediction 4 (King):
# King Nun I of a, Haon monlball coves wee, op ae that tow. Huuves, if wh. O.
#   O yigg, Que is, ill a dotr
#
# Prediction 5 (Queen):
# Queend ner!
#
#   Of, my llom. An rer Domy Chay mughem co, a, wekse.
#     Bit ellin bot.
#   Gike th; us, alsty
#
# *****************************************************************
# Epoch 48, Batch 116000, Previous Loss 99.06910975225672:
# Prediction 1 (Hamlet):
# Hamlete youf and,
#   Gu, ying,
#
#   Rerthin!
#     Thet to houf kord Hu thas ipem. I dh
#
# Prediction 2 (To be):
# To beand nurden Caond a me fore'dee I my theerer'd, feaksue it dit,
#     Butd'cilbe, outwe yopener farte o
#
# Prediction 3 (poison):
# poison
#   Canh icche,
#     A madetron? I- bewavels ing shetd at I
#
#     But
#     Geellrim dith bache
#
# Prediction 4 (King):
# Kingo she pasterese feedmy is herarter o hann thin u himatze his a leer.
#     A dhethtis thid therh ther'
#
# Prediction 5 (Queen):
# Queenlstamey diden wet no shere thesore ur and wham
#   T ame,
#     ferewewidef thoutesery, mirltick ily mul
#
# *****************************************************************
# Epoch 48, Batch 116500, Previous Loss 95.48740068858294:
# Prediction 1 (Hamlet):
# Hamlet, a tonean.
#     O!
#   ack.
#   Hy theand.
#   Leror the o malleollanse the w        Quentit, to the com f
#
# Prediction 2 (To be):
# To beorpt.
#   Opo dutote on theutit sat haont to prouthilsenu kist, heont to math is it rlbne feyth. Narma
#
# Prediction 3 (poison):
# poison. But hoy,
#     Not, notise dofdo the is spamiid to miing; tayseme
#     Thisont dost motaln,
#   Latd of
#
# Prediction 4 (King):
# Kingyient.
#   Prakemink,             Noare ioverner, woon
#     Ame?
#   youniy fore) notsiopiiletas.
#   so fa
#
# Prediction 5 (Queen):
# Queenede theene, coakdangess nae gnemeiland!
#
#   exer' to that and tose dukl and bes plounto!
#   Has verime
#
# *****************************************************************
# Epoch 48, Batch 117000, Previous Loss 130.51015390779844:
# Prediction 1 (Hamlet):
# Hamlet ons that. Af thir a haten wo lild yole.
#     Thaugen't;
#   Hawn ellolon.
# ffaon in and tlat'd; botvais
#
# Prediction 2 (To be):
# To bee?
#     Thit go iir the'lirhan In for worre wherll how fat me. To. Apfes
#
#   Cf nosatbe urlir heel uir
#
# Prediction 3 (poison):
# poisonanh nraves atte, It fmame stomoz. That is me, caip in thows.
#     Ser,
#     On
#   , weld ell, Caswinol
#
# Prediction 4 (King):
# Kingee sers.
#               'Tour, It arlen it as loravos, honthencen
#     Un tis, I thithe?
#     To wit! I
#
# Prediction 5 (Queen):
# Queen lloul mlung; theuthers how lyoond cay llol'd ofar, pr?
#     Whailk thy go w , br seathar thed ah. Co
#
# *****************************************************************
# Finished 49 epoches, Loss: 107.55635040108021
# Epoch 49, Batch 117500, Previous Loss 109.51839052610985:
# Prediction 1 (Hamlet):
# Hamlet my,
#     The on heckme ose fortay no the on, y St ur taak ul utoch hy horat. The iore.
#     As mo to
#
# Prediction 2 (To be):
# To be and of to har,
#   sure fat thy ony of they oss;
#     Gof the pr mall
#     Uu o hearhB tam] No artd hov
#
# Prediction 3 (poison):
# poisonar of the,
#     Hatte cpesaths be. The bet ghat mathalkive cort.
#     Stay noon fard.
#  olepchasst wara
#
# Prediction 4 (King):
# Kinghagtom.   The a ar af theant co deest, orach nor, to it cher thatd'quit thet no thit whive su
#
# Prediction 5 (Queen):
# Queent,
#  proutois hrou'                                 Coonh iils m  The,
#
#       Opharpam
#     Quurs! tei
#
# *****************************************************************
# Epoch 49, Batch 118000, Previous Loss 97.85638394154789:
# Prediction 1 (Hamlet):
# Hamlet buesto, quth nong het sitke, thet hoagceBus, of lrog merte bottsse'dvimlol comis thall she Pol thac
#
# Prediction 2 (To be):
# To bermall mor leld as yabsont, il shis hone hat,
#     Gor's hour he.
#   Do ne uld luved, ail hend mes',
#
#
# Prediction 3 (poison):
# poisonathiech ingn less? Horwhing wer yous seet'd sigt.
# Pon so what olith, an
#     Hass you owhas his noar.
#
# Prediction 4 (King):
# Kingrth shit wh le
#     [     Hath moyst o rang,
#     Noe do cach lodh on in dor, hor,               A,
#
#
# Prediction 5 (Queen):
# Queens ththat sezald, mist. This and tort ongark yat he do him ilt me fos
#     Bash [
#   Ham com shii
#
# *****************************************************************
# Epoch 49, Batch 118500, Previous Loss 98.445428151173:
# Prediction 1 (Hamlet):
# Hamlet my fee shen sirg fans
#    ne No afl?
#                 w'd ny a do dop of riflbut,
#     So shede I
#
#
# Prediction 2 (To be):
# To benss lesing.
#
#     If came Pruth.
#     Pour aef sand ryrer: fis't, th,
#  de,
#     Houf'd witrenile kich
#
# Prediction 3 (poison):
# poison
#       Sis mer of therom beque Kephat my so teng houf thas de and hy sherby wrive
#     Toans Hislis,
#
# Prediction 4 (King):
# Kingc
#     Mutgad   Slisem e in
#     Thiilnis ste ile hen- Taoth
#   Tout maste thex  [fou Let:
#
#
#
#
# Prediction 5 (Queen):
# Queen, cobeen for'd; quanss Lo lo ing you Fnee tharnis o of of cerest
#      ope thecer of haer aprang. Fot
#
# *****************************************************************
# Epoch 49, Batch 119000, Previous Loss 114.30132767577888:
# Prediction 1 (Hamlet):
# Hamlet kyousl tharilotd wiekessad go this.
#     At wed to do whie
#     Haytw as fatigh; me bouk taugiste whi
#
# Prediction 2 (To be):
# To bet.
#     Whet is me.
#   ingting. Bow- erdsam.
#          Have not bos, the,
#     Thaaksert. Fog.
#     [   t
#
# Prediction 3 (poison):
# poison, to gamath in blim. Horntes serse, withe.
#     Ham wn to ne the ttain, and w tikn loge bis?
#     Is t
#
# Prediction 4 (King):
# Kingede I thar lutt.           You yad.
#     Thalle outh gich. o tlersf asomiens do  Eot. Thy so cout not
#
# Prediction 5 (Queen):
# Queend Que mim. Clming horlcind'tery dheme flom weug.
# fol it a pusteud thangts thin totrow as somep llouk
#
# *****************************************************************
# Epoch 49, Batch 119500, Previous Loss 100.52522221279469:
# Prediction 1 (Hamlet):
# Hamletseregieth. We' ] we horsw for neath ul hort.
#   Hw. Thathe ler pthtd thon the, heass hit'd
#     The.
#
# Prediction 2 (To be):
# To beset theps, I be ne me well dor and seeins me be ladur ne with
#   Letd; blalomce me woe ther, the wepe
#
# Prediction 3 (poison):
# poison'd and git maserthip! Vee prer. Thar o butgarm fnom win. I patrn a Ghe- s'tter heer! Hiid Lotdist no
#
# Prediction 4 (King):
# Kingher mitis;
#     Voudd the anas,
#   ar withwith is me meis eed her?]]
#     O red who anh hanb't.
#
#
#
#
#
# Prediction 5 (Queen):
# Queenis,
#   Pot, oners; Le arpost my to me parch?
#     Maththentrerst'd cois 'haer fley glaton or ml tyant
#
# *****************************************************************
# Finished 50 epoches, Loss: 107.49685049625751

# %%
func_string = \
"""
if batch_count % 500 == 0:
    print(f'Epoch {epoches}, Batch {batch_count}, Previous Loss {self.loss(ps, targets)}: ')
    # print(f'Starting string for last batch: {"".join(data_reader.ix_to_char[i] for i in start)}')
    # print(f'Input string for last batch: {"".join(data_reader.ix_to_char[i] for i in inputs)}')
    predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]
    
    for num, phrase in enumerate(predict_phrases):
        result = self.predict(data_reader, phrase, 100)
        print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
    print("*****************************************************************")
"""

predict_phrases = ["Hamlet", "To be", "poison", "King", "Queen"]

for num, phrase in enumerate(predict_phrases):
    result = rnn.predict(data_reader, phrase, 100)
    print(f'Prediction {num+1} ({phrase}): \\n{result}\\n')
print("*****************************************************************")
# """
# predicted = self.predict(data_reader, 'Ham ', 50)
# print(f'Epoch {epoches} prediction (Ham):\\n==========\\n {predicted}\\n==========')
# """
rnn.learning_rate /= 10
rnn.train(data_reader, func_string = func_string, max_epoch=500)
# Out:
# Prediction 1 (Hamlet): \nHamlet ils, he drand.
#   Haws ank us her boff lord me maald thang in wiusess not, him wand gor; A, prom.   \n
# Prediction 2 (To be): \nTo bed.
#   '    Ose gant prere stamys a (Fy, of his daeld maebl. ave, cale fur
#  O und. Add ster Nhatte dDe\n
# Prediction 3 (poison): \npoison one mout eansDee,
#     The shas fupct!s mn fos a shatd logt; in with,
#     Buf fief thebr briinthfiid\n
# Prediction 4 (King): \nKingais sto's and hpen a jor bute haag.
#     Wht.
#     On onom jukes pe hat a ket hamres,
#     Youes, heal,\n
# Prediction 5 (Queen): \nQueendgam. Bucgimn cont thasse unzirr thabwis ginithsat uach esh Giospe ger ham. ies sorr me in Hagk suti\n
# *****************************************************************
# Epoch 0, Batch 500, Previous Loss 88.1733177434875:
# Prediction 1 (Hamlet):
# Hamleth, nots. Wworllilivr mave st, yout pare, her a
#     To gn thingount't, yore.
#
#   Hoos
#
#
#   shouggaingu
#
# Prediction 2 (To be):
# To bedry maante hiomaceunsit a
#     I mand I thare thas.
#     Buregsers my,
#     And the me so mre borphide
#
# Prediction 3 (poison):
# poison thanct kodimpt, my duoneeod olow? Meak comrmeat. are us camy dounh?
#     Well thale
#     An on doscta
#
# Prediction 4 (King):
# Kingo otrann wyur fach. Laer tond
#     Mare t i'se vill. Buthearh afr. fren Lorat band'd a
#  Dang thas ant
#
# Prediction 5 (Queen):
# Queenbran
#     Auntes! rant, ur,? Hamn wety
#       Whom. Olam fi,
#   Mweive nousirst thalcive dwerie, whur's
#
# *****************************************************************
# Epoch 0, Batch 1000, Previous Loss 100.74912431222698:
# Prediction 1 (Hamlet):
# Hamletvee ie mato Yentiur yhose le youp of lionionotte
#   Haully tong thaon thed ell- enicgWey waor. And my
#
# Prediction 2 (To be):
# To be, and to bel whet this puth mainn boortaoke! whe to hough and bus, fouug whes
#   Hint. Comlim
#     Exo
#
# Prediction 3 (poison):
# poison
#   Exs
#     Wios, ying. primer oDet a eth so ture theit and berrere with.
#
#   Us
#     Theris maags.
#
#
# Prediction 4 (King):
# King soreve               ' on him. The ies shaou
#     On. My lpace him shamed and, ent.
# Erebe he fow pro
#
# Prediction 5 (Queen):
# Queengenl notre thell mrikitat in Shee, ge of ethat holle ling.
#     andt?
#               Pol liming weld d
#
# *****************************************************************
# Epoch 0, Batch 1500, Previous Loss 87.27203818972654:
# Prediction 1 (Hamlet):
# Hamlet puad thy.]
#     Thy)
#     sple rifdive th so thit ther my thorsiont.
#   Homeeacles'd live wiysto as a
#
# Prediction 2 (To be):
# To beiss af it vadst vexely mamciz? Dirlo winh, and, the,
#   Ed plom; to us quen. That
#
# fald mumlarn ooxst
#
# Prediction 3 (poison):
# poison hosisse stine hiz o liconey nuld my the Pold, shitd bord, he?
#   Brow buty im iligy, isseningee- Ly
#
# Prediction 4 (King):
# Kingase thorave wh'd
#   Fue thew we, as in tvisl, fiy and themaed lorpelme yis soes is thelanivirke keach
#
# Prediction 5 (Queen):
# Queenmy but ol triik? Sain, tad owad oorour noend not fonte
#     Af so to wtall llolds shey so O dpnis you
#
# *****************************************************************
# Epoch 0, Batch 2000, Previous Loss 97.89463466506507:
# Prediction 1 (Hamlet):
# Hamlet wan erciken with ttalam tere yol.
#
#   Quast cae nougalw.
#   Gwe, cror mever?
#   Gsouf crore clat, henl
#
# Prediction 2 (To be):
# To bew you thateurd ham. Ther thepeesam theul Thin.
#     Sele. Creen, swhe,
#   Lead?
#   His wit
#
# Prediction 3 (poison):
# poisond thot mom. tatte tomy is drat I paon fond, buppe
#     I. Buch porhtheb stay loromesing. Of hony,
#   f
#
# Prediction 4 (King):
# Kinge wevem iveI ilillyme not timeble,, erd.
#   Hay mous anr vioft the
#   Lach srepell hit as a whas hrnel
#
# Prediction 5 (Queen):
# Queent ofenof to it with't whe. Hat'teustive.
#     They livlet, (Erincpeve hor of the, ul wingle buse in g
#
# *****************************************************************
# Finished 1 epoches, Loss: 105.32753339741414
# Epoch 1, Batch 2500, Previous Loss 122.24338640011173:
# Prediction 1 (Hamlet):
# Hamlet tor'dlemane
#   Ho of thaas
#   '  Malr in une my sore doud, dins
#
#     It brt.             Aswed wiate
#
# Prediction 2 (To be):
# To berachas lieshopaw- I the far.
#   Gue a doris of thas is bit of in this rlet sar.
#   Like be. Weaf't, ha
#
# Prediction 3 (poison):
# poison. I feouwey non, masrtas. Put uordatildebe be I stoee poncingpare
#   Be on'ds. As thit a a pr is lant
#
# Prediction 4 (King):
# King.
#   Ophes bim'lafchenbrince' Poto nomt ertough the In it bor. Thy lord a onousers maer, thiunthen, o
#
# Prediction 5 (Queen):
# Queense this com; stilsee thin thers thas.
#   Latd. Hameen, him. I bam
#   Queave fast; haaghing on not, if
#
# *****************************************************************
# Epoch 1, Batch 3000, Previous Loss 100.80926897909569:
# Prediction 1 (Hamlet):
# Hamlet when we soll lusen raonrind
#  o hor of Latvay toexsel he in laks e. You! As.
#   Sorer tote hat hemen,
#
# Prediction 2 (To be):
# To beds tionesis o cell do tons nosem asse;
#  Queintech)
#     Ham gor, nonr;
#     A of wam. Muell wivour wee
#
# Prediction 3 (poison):
# poison, Lomn furte beom. Ham.
#     W  Lasgnn and and
#
#     some lo wo wigher I
#     En.
#   Pranl be. Surs sidn
#
# Prediction 4 (King):
# Kinguell, su's pave tar, they not thed? Rollte shofss is Kerathis hay sAs, iif sthny dirgad four shet bl
#
# Prediction 5 (Queen):
# Queencrour.
#     E the or ct thly,
#     A so you, monghy houny ist. Iproum lust thisemk de liens ell lomr K
#
# *****************************************************************
# Epoch 1, Batch 3500, Previous Loss 147.63856035083228:
# Prediction 1 (Hamlet):
# Hamlethes com thent yonowtanmali't
#     O lovedece thesses thering to pany, grom be't,
#     Hamiytinrart?
#
#
#
# Prediction 2 (To be):
# To beyerh logquans, oP onray mail. Dogy of horath poreclavish-  Hrom onot geaw lats jurese. Thaw thet our
#
# Prediction 3 (poison):
# poison
#
#   siluey
#     'Tink
#     Buee
#
#     'as my thay prounspte ijithin,
#             Quer; frortost
#
# Prediction 4 (King):
# Kingust dach
#     PourY chestad yis atens, mirl. Tharh geiithst ancals and of ae hoonswom belath buk, we
#
# Prediction 5 (Queen):
# Queensochos, O ar sigke.
#     Do fener fein on thes? I hy cull [I
#     Thouche dead, weer of onring, ther t
#
# *****************************************************************
# Epoch 1, Batch 4000, Previous Loss 100.43526397176879:
# Prediction 1 (Hamlet):
# Hamlet the do'd!
#   Kough. aid not monle to hase bem.!e?
#   Brad yowem fill
#
# Prediction 2 (To be):
# To bee fatheoshel hit in, I deach ett thive woper, Whorbleontme on they, trtom ma.
#  'out yous vor. Thaif
#
#
# Prediction 3 (poison):
# poison'd.     Ro to weckindofe.
#   A thyouny i' sas, and
#     Haar orsede at suer , kerar, on so, nose ounll
#
# Prediction 4 (King):
# Kingarvert spol.
#     Of Plo and und!
#   Haurd ur thin]
#     Thin. Nes,
#       Bud paven I me theskall gorbu
#
# Prediction 5 (Queen):
# Queene hestaovt tam. Exeet? Surun- 'holppeter hashth wool!
#   Pry, igkowedous tallmath'tem mastens to yora
#
# *****************************************************************
# Epoch 1, Batch 4500, Previous Loss 108.26186883144491:
# Prediction 1 (Hamlet):
# Hamlet, muur,
#     Sow'se'de?
#  ou the bagh fred. Yis thenard. That,
#     Butrak is inge thoph horill wias ne
#
# Prediction 2 (To be):
# To bes fasze o hasat o ould suer thaad!
#    Savutuyce fot.
#
#   Whteucham
#     Thand to of wet halr ; and
#
#
# Prediction 3 (poison):
# poison
#     Thale a nom; notp the.] Oer-tse thy se ijete
#       Fighit? what coagte whae loghe,
#     Sow to n
#
# Prediction 4 (King):
# Kingime t'teren. Exon a?
#     o oghe-
#       Clall'dterort oph;
#
#
#
# Prediction 5 (Queen):
# Queen hat ril. Quer no thaeds.
#     Hauks touth whe.
#     Stom hare?
#   For a the ud dighethe's thewsaeoucoe
#
# *****************************************************************
# Finished 2 epoches, Loss: 105.22933565392935
# Epoch 2, Batch 5000, Previous Loss 101.15290381005002:
# Prediction 1 (Hamlet):
# Hamletem kor't; weor? Afls; themand forse rer, lase ley gears ble in thatco of so for most of raar to sen,
#
# Prediction 2 (To be):
# To berer math se on my fnomed ave noe of quet Bpive aud
#     Thas eespiebre, caeld lervere wijse. Aild.
#
#
# Prediction 3 (poison):
# poison Fnonte, st wivegsert be's mange the cad, nyou?
#   Hat you opew gort, of with mave thive
#
#     Hamirs!
#
# Prediction 4 (King):
# Kinganly pato.
#         Erd,
#     Horope, shew doptaeborerck. His lnosthes kour'dwe, yowomeavint not surli
#
# Prediction 5 (Queen):
# Queenz matiy thasithis weene; that and onorticteads werart; eson
#     Weln gop ouse as rians a but be. Let
#
# *****************************************************************
# Epoch 2, Batch 5500, Previous Loss 90.61702870308494:
# Prediction 1 (Hamlet):
# Hamletes, huron marce whomte.
#     Thy y wincer pav. witctte ged to's my ath'ly, theurn kar't. To thing cou
#
# Prediction 2 (To be):
# To betous wetgiee, the come whe land and in darck. The, thicrech mood womy bost tht
# for whoubfrans you di
#
# Prediction 3 (poison):
# poison shen.
#
#                 Lell yis is vert't thend be hije,
#
#  anh, witrort this pod the ol yold, hoak-
#
# Prediction 4 (King):
# Kingich andme iw,-
#   Ot ther.
#     Das ale
#               Fow, bed and muth aadth. Sat bake wher fot moll
#
# Prediction 5 (Queen):
# Queen is hans afr alstare Enhad, mam opin'd, jel hee,
#
#            Ham. Gitill
#
# *****************************************************************
# Epoch 2, Batch 6000, Previous Loss 105.58340060211967:
# Prediction 1 (Hamlet):
# Hamlet
#     Flale so youu, hagam.]
#   Haeld acirbive nartet i! Kall, thet youons an muis,
#
#     Fooy thest ma
#
# Prediction 2 (To be):
# To beas do you and and that) Of yighaint whel'-        [Of wy ener!. Whangad. I withty shis camord the hy
#
# Prediction 3 (poison):
# poison dant allens wellith. Gincy in I'd my, you, get dith,
#     Nulde [[hate manh widh whey shyoun, Theur
#
# Prediction 4 (King):
# Kingwenmour her, hor andeuf,
#     Pull- )
#   Ofvime come coveythe. O diede
#     (nale, Go wern nut to aser
#
# Prediction 5 (Queen):
# Queenste turais uld's mer dough ninceyWist, llich a ave bnot juang Posen houkcem.
#     Thett yow thex noqu
#
# *****************************************************************
# Epoch 2, Batch 6500, Previous Loss 94.97996601229372:
# Prediction 1 (Hamlet):
# Hamlets
#                       of lant din their as marang yous- Be illd to be. Oes, ath]
#
#
#     Wee?
#   Quae
#
# Prediction 2 (To be):
# To be.
#   Haoloup a the o lasp, it breche miof-].
#   Baine firr foe saenc'd.
#   Ham ploullcee four.
#   Exim i
#
# Prediction 3 (poison):
# poison it thend, wit fp, tandbourge the bul you s assy therjele noll tassening raad, on thell
#   Pot has, a
#
# Prediction 4 (King):
# Kingweowt notor an gyow, of tha!
#   Ope rorit.
#     Hath
#     Oph uppit,
#   Hat. Losedat, hiy'd ster. Thors
#
# Prediction 5 (Queen):
# Queende reth py care hbupsan. and Harkente has.
# Erle zet, for by shaancionger o dt sher horse]
#   1y the i
#
# *****************************************************************
# Epoch 2, Batch 7000, Previous Loss 114.31860046910573:
# Prediction 1 (Hamlet):
# Hamlet whe exs suon
#     Opeass?
#     To so), whosd tuansive mald
#     I Fore do himu, all]
#     Her term. Tha
#
# Prediction 2 (To be):
# To bey Ghet
#       Mouckurtte thach lirk, voor mem so and ur est macachs,
#     Op seld vor'tetn dses famy,
#
# Prediction 3 (poison):
# poison, shas, fotdaengtat or that be wis thow thans't mer.
#
# shorses ir that yham.
#     Er wfout coy leenchl
#
# Prediction 4 (King):
# Kingars arnn ae the mech me diste ing suenthens durrit not Goxigh of notall, and I fou!
#     Biint.
#     W
#
# Prediction 5 (Queen):
# Queenint's thor.
#
#   Kir il, merve. Lyicemonte, stan taml harse he and in Welondnas?
#   A bealsparomde ano
#
# *****************************************************************
# Finished 3 epoches, Loss: 105.26076661822881
# Epoch 3, Batch 7500, Previous Loss 95.68070426319932:
# Prediction 1 (Hamlet):
# Hamlet brourdey goning.
#   igang, dulle
#   eth. Oe swer be surd Son. Marel mand end ewin horavilloe le, ald
#
# Prediction 2 (To be):
# To beud hase fus. Would? Kitour Horispebler, ingd sule liysefle crotiigd'ce;
#     And.
#
#
#
#
#     And ning
#
# Prediction 3 (poison):
# poison eed. . And hy in,
#     And himiveenh eop tris ise etz. Bom. Mobe praliee rectceaes il ay for. Tham.
#
# Prediction 4 (King):
# Kingy spim. fry;
#     Withert'd etnstan'l'd you. Besiy m to, as, gack, qyound limlof wof; O gereail Gher
#
# Prediction 5 (Queen):
# Queens ulvourcof's, sice uf we momee hatd he, woor, rlk.
# fot vithe ase lirt- latgeold thas on ur sund the
#
# *****************************************************************
# Epoch 3, Batch 8000, Previous Loss 102.2904603561618:
# Prediction 1 (Hamlet):
# Hamlet my that onrer, a pimy e.
#     Yoadh ble yowt. Non they thased swowe, I ht and moorpackino-th, ulleln
#
# Prediction 2 (To be):
# To bereed, his shey ivp. But couk fall inctser, nour,
#     Ler thens, anvaon,
#     In the my wour, montilit
#
# Prediction 3 (poison):
# poison. And so this ar and rureecteit thran. Thes in tht theent, at lorle-, wile' I as, my, the thers the
#
# Prediction 4 (King):
# King fazgens Co ne your that surs yeas bickt'd. therenr theestalugerse dotest no' The'dw is stell so you
#
# Prediction 5 (Queen):
# Queen ealeaid, of lifad theall essclontep, it wo u quer eors me wher Nomirlin' im lpete toell lainthis lo
#
# *****************************************************************
# Epoch 3, Batch 8500, Previous Loss 97.1440775970867:
# Prediction 1 (Hamlet):
# Hamletvertthey. Anlow. To dourpresirntu an our me afd or and cyopinh wearnele thel pace harme hamem ll tha
#
# Prediction 2 (To be):
# To be sion sire; of Haok. We tharmy ipfy mnouctanch bove es live shack so for. Whelpt, not 'frendan)
#
#
# Prediction 3 (poison):
# poison wise my nose thent your herir thin ie hey seens.
#
#  falden on so's; a nitg. Grer,
#     And diytee
#
# Prediction 4 (King):
# Kingarr, and
#     Iink,
#     Hess crom ther eld wloues. Matiinpes,
#  ourlante
#                             d
#
# Prediction 5 (Queen):
# Queentray'd. Nose hisentny siro arer, our ss moslin, an noph com. Nom goghe for you brou witoul grino dua
#
# *****************************************************************
# Epoch 3, Batch 9000, Previous Loss 33.56313900168084:
# Prediction 1 (Hamlet):
# Hamlete
#   'Exfs m uth macen in to then, my if ulour tne ithep bu, bet mak.
#     Rot yile font.
#
#
# Prediction 2 (To be):
# To bear lerlace
#   suren angbe ur ganern'te have mair wheanl onclose ly to yfit sey of puou hi. On
#     Wha
#
# Prediction 3 (poison):
# poisont, bich pamus wadfer dras, and ache saet, and a! O rrenbray go in Gonsertis.
#     And, cad t vas?
#   H
#
# Prediction 4 (King):
# Kingaser's seall sundper, ps lonsh. from magyeer hener Kit of gan'd that yolertr,
#     For I thivild,
#
#
# Prediction 5 (Queen):
# Queengary no ext go.
#
#     Averlest susour,
#     And lenl. To onhes, have oEd Quing.
#
# pwis'd
#
#
# *****************************************************************
# Epoch 3, Batch 9500, Previous Loss 41.20805425916251:
# Prediction 1 (Hamlet):
# Hamletheyopimy, ip ney no K'o thet etd su weint; and thing bost is theste.
#
# Prediction 2 (To be):
# To berew ais!
#   Quer? surel pingealf. Whem. Teene
#     To notind wink-.. Koroe ot rongedh, weng? Cy s' toi
#
# Prediction 3 (poison):
# poison,
#
#   Howist
#  Enon, his Cing him fely sheakenr yowh tiiy to thele my hai, the thay went s'd shart; mi
#
# Prediction 4 (King):
# Kingiak the whor ineple rel.                  Had!seen hatd
#       Ot gnoe le'dend in
#
#   Ovals yol yole
#
# Prediction 5 (Queen):
# Queens Yourlebre wnos fon                    urr sortherdind feriingmer wonge fald' I ut utough yow tvek
#
# *****************************************************************
# Finished 4 epoches, Loss: 105.24597927178411
# Epoch 4, Batch 10000, Previous Loss 109.90609199464541:
# Prediction 1 (Hamlet):
# Hamlet we soner's,
#   Hame and.. Surs unabe if ftaer whaingedtayir ils, I
#
#   Miwe gonitoudle eth caungadone
#
# Prediction 2 (To be):
# To be's vark of and I    Wo iif and and I lach Ktictaendt dnamed dwe it Bome be or les thep?
#   Ham.]
#
#
#
# Prediction 3 (poison):
# poisonete hase in if sae!' dour, I] I I gee.
#   Opead artend, ie cort,
#     a luent. I ullor flerens send yo
#
# Prediction 4 (King):
# Kingeing cake,
#   Pok, ooxing
#     Won iges. I fallien.                                                  L
#
# Prediction 5 (Queen):
# Queeng derere shie sht I, a, like and, tham. How!
#     An foar stot hass.!
#     A from malin nosh teak. Wit
#
# *****************************************************************
# Epoch 4, Batch 10500, Previous Loss 126.88291524182937:
# Prediction 1 (Hamlet):
# Hamlettee.
#     Mast so ind weas ou or to fats th my and tith enhowenrink winite owew uf hor punn and hente
#
# Prediction 2 (To be):
# To beel nitoreis ellen fo?
#
#     Tuenth counte lorch notsanh melor fam oslel. Wheche, Quen
#  [Tomts, that t
#
# Prediction 3 (poison):
# poison. is crysuer do frours,
#     Busp ding,
#     Youch Hagas! is yot yound ouge avowikbost pors lerl'sscer
#
# Prediction 4 (King):
# Kinglae, so wheagsemastedthes kor and lerigsoren my i't ibly's thas,
#   Le ily? [anss rogithef le, menst
#
# Prediction 5 (Queen):
# Queen'd to rald. Idse limy, woond
#     Najelcde
# Erind; aflass,
#     frangjath ous.
#     Margarnces
#  De sue y
#
# *****************************************************************
# Epoch 4, Batch 11000, Previous Loss 99.96980156634322:
# Prediction 1 (Hamlet):
# Hamlet mighew my a shen.
#   Bublar geann        [Wot
#       Guad, what noy thoslenre morh st mling in com yo
#
# Prediction 2 (To be):
# To benout coeckpen thas, not non
#     Boak fran you anlese,
#     T Why asaaghas a, ress the; affeats monh
#
#
#
# Prediction 3 (poison):
# poison'd to, weove wevem lingeseils comeselre-, wows.
#   sombinro de to whenke gome sor,
#       Fav,
#     And
#
# Prediction 4 (King):
# Kingwameorre pove mdees nithach marllangent.
#     Of I keen if mys path thy dore hat tke cor pang thaarei
#
# Prediction 5 (Queen):
# Queend e icorzme glal'd. Seattaly hit arde, thy hat. No thelesco,
#     Ther. If wor link mienthl. is momik
#
# *****************************************************************
# Epoch 4, Batch 11500, Previous Loss 98.12324607706215:
# Prediction 1 (Hamlet):
# Hamlets shat.
#     We if rzy
#     O as thilit ricen it the ffousherest                              Late of
#
# Prediction 2 (To be):
# To bend'diin. O andere eand,
#     Thocere rim. a dirr frorer, this wee suand. Goy he.
#   Bell fonorh'd aal
#
# Prediction 3 (poison):
# poison men toar
#     Hamy Do you! ul maes wher porth; ot or thas cost;
#   Enraag. The mlut.
#     mante'd wbol
#
# Prediction 4 (King):
# Kingrind mlom vien sly he?
#
#               Gagleors ighave de thearst. Amath trentents pxoas, moy, witam.
#
# Prediction 5 (Queen):
# Queen the warutill thise                                                     ichistes Haoss ellep [Buw th
#
# *****************************************************************
# Finished 5 epoches, Loss: 105.33604626302647
# Epoch 5, Batch 12000, Previous Loss 74.08921509604895:
# Prediction 1 (Hamlet):
# Hamlet mimeserso prour.
#
#   Quaven,
#     Thead of thas I] thems]ctor. I spis I
#     Corray tyorpe ler hack'
#
# Prediction 2 (To be):
# To bear hind rung;
#  Fortd tey fertacly'd!
#     Nour;
#     Tomnow thionte-seunce stit hing, to noy nolltive
#
# Prediction 3 (poison):
# poison a yaesh not.
#   fod
#         OEd and parrel cas.
#
#
#  For. Fansshrl, wisearce nosD, norirror: Gove
#
#
# Prediction 4 (King):
# Kingonik. Botch'vest o rint fiich maly my uss.
#  Gange haclor. Frot I dirh, apinh, wowe blee, fast
#
#
#
#
#
# Prediction 5 (Queen):
# Queenteritgt. Invener red,      th rlsobrinl uth,
#       Lech yout, Nurour ard.
#   so.
#   Han. (fat bee, on
#
# *****************************************************************
# Epoch 5, Batch 12500, Previous Loss 92.197786621395:
# Prediction 1 (Hamlet):
# Hamlet me du. Tow,
#     But ser sht yow;
#
#   Hour,
#   Gue,
#     Ros thcom sarur!
#     So merexicher.
# for deriir
#
# Prediction 2 (To be):
# To be dete tiof- Howsthpat IGle hingde rirband tris paiond froue curn frigonianh yolty croul thist uno me
#
# Prediction 3 (poison):
# poison. Wioldy pri'd whars. Whbe cars my buth. I boslen you hey thagomthas, how
#   Hart.
#   Hamcell booreard
#
# Prediction 4 (King):
# Kingat's, meris othar
#           Hans what sors, be to and wisy cled nos'd thes rors notk you haalf. Be,
#
#
# Prediction 5 (Queen):
# Queen thed.
#   Hame w'] jots I soanntianinds. Sfojol.
#   ! Bon. Mloukjyt doren, so arr. My hes!s? Ale othe,
#
# *****************************************************************
# Epoch 5, Batch 13000, Previous Loss 116.40948974487429:
# Prediction 1 (Hamlet):
# Hamlet. Ot ther        And th-stest op is a farst, sone
#            Angate
#     Wit sallet of diss. Noads, n
#
# Prediction 2 (To be):
# To bes nossper      Que dy fit hast; E 'ly but, lee that Cox mond, bisongace for.
#     My ler of, norir in
#
# Prediction 3 (poison):
# poison maglonh no rtupquer. Becing!
#     Thacs?
#     Gons it med hse I cay werves,
#     Thad yach. The'd yous
#
# Prediction 4 (King):
# Kingerzer har. Whinst daakd. And, wh thit do deang thernirs coer but to orlasen! I thoriviof
#     As mood
#
# Prediction 5 (Queen):
# Queens, prer and thupt
#     of as le hiors. Ge.
#     Wour thes, forse he mashee arlomizlaml yout mave leis
#
# *****************************************************************
# Epoch 5, Batch 13500, Previous Loss 109.40787741265613:
# Prediction 1 (Hamlet):
# Hamlet t'd mu'            Erangenn fast, fidiwg, Citr, jloud.'
#     Ques,
#     A thersorele youds ounf,
#
#
# Prediction 2 (To be):
# To bee't mank Deesly pemer as ser ttacoe therpvaane-cieser,
#
#   ighhencedd tham mitinn;?. So on of lo lr
#
# Prediction 3 (poison):
# poison
#     And of and spete and ceer onrno fis a's do thank once thops and. You you
#     Horallo mis.   st
#
# Prediction 4 (King):
# Kingaze nop my.
#   Bugh
#     Trurbaile oull.
#   Haones on braes, Peunth moronte haorterar. Of luid,
#     Aee
#
# Prediction 5 (Queen):
# Queencogt
#     The that yas oifg iillce.
#     Gurs istebly siy ther tay no goly meps, py fllit , pleretsran
#
# *****************************************************************
# Epoch 5, Batch 14000, Previous Loss 89.34132553638335:
# Prediction 1 (Hamlet):
# Hamlet, sit the sifl songew geos heujear,. The howow viss'd
#     HaorS; mis.
#   Ered.
#   Exing?
#   anl wised C
#
# Prediction 2 (To be):
# To ben, fang and pre is thtt sher.
#       Thiss theavethingiy-]
#
#       got; hazelvee
#     Nonh it it thin r
#
# Prediction 3 (poison):
# poison
#     Thas souok
#     Ar caclichit for yol,
#     And thence theny, beuctereer the
#     Frant merly you?
#
#
# Prediction 4 (King):
# Kingund do't kell,
#       I nfaseyssaad comye yous hove I fead as we. Ar inf she thilege wetch wep. Thes
#
# Prediction 5 (Queen):
# Queengse;
#
#   '    Marht ilwing
#     Osootach, it rour., lotlck sheakeg. L ofe hich o              I, t
#
# *****************************************************************
# Finished 6 epoches, Loss: 105.38490297584582
# Epoch 6, Batch 14500, Previous Loss 89.17535787111824:
# Prediction 1 (Hamlet):
# Hamlet. Fout?
#     diang ard-.
#     Thearew, a'. Quent the wetccighindiutikikink of wht ofrall, ny therjusta
#
# Prediction 2 (To be):
# To be stond, im of in dwike the it and riemyingith prour heren ie wough,
#     Wharch paingade't.
#   Lath!
#
#
# Prediction 3 (poison):
# poison [as thes I
#
#
#     So so wer utren.
#   At so like in ther of bprrert mlbavuouath mans thas
#       sir
#
# Prediction 4 (King):
# Kinglary so dwe of sid axthoan! sactanst ichach was'd ing.
#   How,
#     Latd hengitd sisite, ofle Kim; of
#
# Prediction 5 (Queen):
# Queen I and.
#   Proot. ?
#   Hour fold and tas,
#
#     Tus!
#   Hosh noth' Sorann pet.
#   atilst.
#
# *****************************************************************
# Epoch 6, Batch 15000, Previous Loss 100.86470972027992:
# Prediction 1 (Hamlet):
# Hamletdse, in.
#   ear, fod ifsors wiogas with mistencor dell nitlmy tlaly.
#
#     Wind,
#     and youche onat h
#
# Prediction 2 (To be):
# To bee rthasst lo gxou souns bord wignels
#     eln gid. Thaik lord. So gy and t I Poudpitow of wirs is How
#
# Prediction 3 (poison):
# poison it hooteuchin gralor ad wich.
#     F'lert?.
#  Whot bet. Hat you the Pod his shat in r
#
# Prediction 4 (King):
# Kingiich mechoproment afes mmeyt she sins so of shis poen your your; goglill be.
#   Kighougith and Yours,
#
# Prediction 5 (Queen):
# Queens and Pouge. Ffog mom whomt, de heme me the yous so yryeble grom bite thiy the fim. I dile the, me
#
# *****************************************************************
# Epoch 6, Batch 15500, Previous Loss 83.73733224555565:
# Prediction 1 (Hamlet):
# Hamlet. To hiblom; hickt' Go lildt hatg ilpenoriif, opy no a woupived spes, foves me. And ther hey Gueters
#
# Prediction 2 (To be):
# To beall.. A a llarolppyte ou thou ile uetraen,
#           Pave.
#     Birthsens in st wad plat f' we,
#     A
#
# Prediction 3 (poison):
# poison,
#     Wethme and offis there I I ine my aold
#       Wet on twoolders errente
#   '    Muich they whe de
#
# Prediction 4 (King):
# Kingbaollmefe, ife, nodrgo Sery mubp nust. Sfethbes hllde notre fot hoch thay lortsed hitir. En'tave not
#
# Prediction 5 (Queen):
# Queene haat in and therttek thas so Haont,
#     Tighitniectercce youveee kee gathe pitoe, if the. To!
#   Os
#
# *****************************************************************
# Epoch 6, Batch 16000, Previous Loss 99.3810244092612:
# Prediction 1 (Hamlet):
# Hamlet a chey maand not;
#   Hakn wose!
#     The;
#  Daste youk, Gors af'w. An the. Whar?
#     To hee ther, is l
#
# Prediction 2 (To be):
# To beay bo'd opheece hebvey de-deny nor davers, fod ethy bun my patder, so luphemer I Gold cow. You.
#
#
#
# Prediction 3 (poison):
# poisontFal wing us as wand and eronhals her.   -ake'd
#   R't,
#     A-d wey lund. Trast?
#   Hlike quing wham.
#
# Prediction 4 (King):
# Kingoay to therert it it grom
#     Loors cogeschit hell.
#   Hameme biv,
#     Thequel witomittw,
#   yon Domla
#
# Prediction 5 (Queen):
# Queengam. Whoakens- few that heres..
#     Ly not,
#   Hamlaes, ad tache a horn ben. Thilf,
#     Deach. tow're
#
# *****************************************************************
# Epoch 6, Batch 16500, Previous Loss 90.11856629429084:
# Prediction 1 (Hamlet):
# Hamlet paeen'   waarban'ly harver wirt- I's affss dlas?
#
#     And how. Whasp'dhels lorpen ee of a whing win
#
# Prediction 2 (To be):
# To bees. This lorlopex criissgs ageansh. Let of tans blac? vime blastim. no' is
#     Ther, so sirtet hatne
#
# Prediction 3 (poison):
# poison. Fuldenge. Swan m whe gim me?
#
#     Hy has at orerrarcreack.
#   '      Whinnenm, sare rresh't thers h
#
# Prediction 4 (King):
# Kingacty fier
#
#     When ane witd hes;
#     Thell erte twer
#     I'd his, an maer wh. Bycuw be mast hor l
#
# Prediction 5 (Queen):
# Queens rllert, and id,
#                      Hatklagtebitosaonel pat.
# Exo t siel Les you, me 'Thien
#     To
#
# *****************************************************************
# Finished 7 epoches, Loss: 105.3288009508395
# Epoch 7, Batch 17000, Previous Loss 95.00123371735454:
# Prediction 1 (Hamlet):
# Hamleth'dce
#   Os. Yomevel thend thow?   Hout
#     Whayitcew webl, ding nos ue it Do wh coy     And
#   sule n
#
# Prediction 2 (To be):
# To beurg to pr.   Ild o llovinceln busw Querer a, krourciont, draed of ll m ofrakisse ge Quereun!
#     Ap
#
# Prediction 3 (poison):
# poison,
#     Thily,
#  O aenenis hode, Gowtoancen any man! that
#    osh mustw crow thery me wheldo homaang ale
#
# Prediction 4 (King):
# Kingo anlyinte maktew? Wham pase if gifrer minl to sank cuans daant sosveun. Lely on nats Hantall ererea
#
# Prediction 5 (Queen):
# Queengencert thmem,
#     Go lordin- We and brico iy ue, sore pafl on Lerl knom, o intinhe ing; coundadensi
#
# *****************************************************************
# Epoch 7, Batch 17500, Previous Loss 118.14595183224507:
# Prediction 1 (Hamlet):
# Hamlet my there
#
#   Hathe not is hive co mielugrere so gorreale not lnotheens hiil a'te gnosrin so the the
#
#
# Prediction 2 (To be):
# To bethraads com thes wow wilch ttiy'd stoals, coe s't as 'ha-le hene witgem. Weever matome; thope roughc
#
# Prediction 3 (poison):
# poisonne! And there be.
#   Pot wy cing
#       I the. Or I keerongay mos!
#
#     Tinmy, sy caen not she
#
# Prediction 4 (King):
# Kingire howhves, with, my mlul dexans,
#     Yedenner, saensth,
#     T maouteeve, Leckem's brow is my quens
#
# Prediction 5 (Queen):
# Queent
#     Cankt. Go whemas.
#     O                             is has! miournare- noble thenlun.
#
# *****************************************************************
# Epoch 7, Batch 18000, Previous Loss 101.60680600299595:
# Prediction 1 (Hamlet):
# Hamletere theonts,
#     Fow wo, ablater, be cat
#     Well lacan,
#  Enmat geenve. Bullind. Ham. To hos a dourd
#
# Prediction 2 (To be):
# To bee dall lnrokad de traonras; hers, mroingen!
#
#                                           Futild to yin
#
# Prediction 3 (poison):
# poison Piks dnip'd my saremave row, watabnop]
#  Ke the a-  Pipce;
#
#   To, ford woey
#
# Prediction 4 (King):
# Kingnaive- on you for't. Thoshisel arle oplare wines. I, thmloul gove,
#     Outd,
#     Camithe is fey
#
# Prediction 5 (Queen):
# Queenh. Bassss he,
#      [Le ing fuks perato slevefghe mimpet, is Lath. What ave myso,
#     Be Pougror'd, g
#
# *****************************************************************
# Epoch 7, Batch 18500, Previous Loss 100.10318525608089:
# Prediction 1 (Hamlet):
# Hamletver-s.
#       Siist shick and soofct?.
#     The gangeun. Arfulgonray
#     Lebl as fagassen it my ateter
#
# Prediction 2 (To be):
# To be gais eiin,
#
# Er'd hood one ene
#     Yol. O uilh?
#   Hat,
#     Merny in
#   Ham
#     Quey
#   Oper whest]
#
#
# Prediction 3 (poison):
# poison godenklome.
#     WhomEticim. Bot ale'd lo halst
#     croco.
#     Cang to kin isisorie. Co shitoy liol,
#
# Prediction 4 (King):
# Kinguln dude my cdo-
# for steras prordtennaans parrouth hangse a the no your tear!
#     Him reen,
#     Fryo
#
# Prediction 5 (Queen):
# Queence llanid ter of is Your touns,
#   Of dirly neln whit dast an of as, and it ther seance siclce;
#
#
# *****************************************************************
# Epoch 7, Batch 19000, Previous Loss 102.43602575475971:
# Prediction 1 (Hamlet):
# Hamlet will a th. Thetserts.
#   Ef me cruriblick bils cxeow it gise gere
#     Wo anly word!
#   Homannim a wil
#
# Prediction 2 (To be):
# To beis, of ur offer fing nom wifd I's youte, ductin,
#     Qut mave to; an of wids, you.
# dit the les; farl
#
# Prediction 3 (poison):
# poison hor uld thes butom. I a thy.
#   Hamn o ath suartiyst'
#   Elat ane whe my a; boutiis not thes care, wi
#
# Prediction 4 (King):
# Kingosid, wiagh hat hore wh sant; I'proursarle?
#   -ramew mor. Hame
#                 Or. O hors yowdex rey
#
# Prediction 5 (Queen):
# Queen.     Forken
#   (     Oll; apout
#     Tooss anmalfe or tyeckytheny feuk masis bet Fasse
#   Hain blowmar
#
# *****************************************************************
# Finished 8 epoches, Loss: 105.24158265955023
# Epoch 8, Batch 19500, Previous Loss 87.15484086513267:
# Prediction 1 (Hamlet):
# Hamlet thenbovedouto dithe haald de. And math ertay thim wowe cage-]
#   How]
#   Hasinh. In ther for.
#   Hatt.
#
# Prediction 2 (To be):
# To beles ties Potingh youcer weld not your to in blomt.
#   Hamelimedse if frounir yaer ablatho my t, mabe,
#
# Prediction 3 (poison):
# poisonst. I sist olaruft momr drire- Be,
#     For freucay wofriser to welughe bethein,
#   Korapenquengo, th
#
# Prediction 4 (King):
# Kingave your gnay heed ar fourhes.
#              Tish kike?
#   t a dikens.
#   Haif
#     swe,
#     Hamtee farh
#
# Prediction 5 (Queen):
# Queen toquigle harpe crhimech and tor yle swem wk, uer the dith whsow
#     Sind
#     In you, horow ty;
#
#
# *****************************************************************
# Epoch 8, Batch 20000, Previous Loss 106.77912086167154:
# Prediction 1 (Hamlet):
# Hamlet,
#       Anh.
# foriik, borlcenMm. Be, at ther path le thend, ofou what the let, mos. Roul!
#
#
# Prediction 2 (To be):
# To bed. Whor tores'd to ier tan. ionr it, thour woff's, but cer) anct. Then
#     Wete a hiet il wsttin'd q
#
# Prediction 3 (poison):
# poison yougy y dave magh'd me bey sibleenth itly Enach I on hath
#   nougeuin younar. Ans Reret.   Ase tan I
#
# Prediction 4 (King):
# Kingare thit. orann
#     A, horbewine him.
#     I be I, thoust.
#   How mall in st tamiespels, is and dray t
#
# Prediction 5 (Queen):
# Queendar?
#   Hochsp. Weytomebrly to and keen,
#     Bold on'd dquou some
#     Erovet, sh to; freth   Tonlll b
#
# *****************************************************************
# Epoch 8, Batch 20500, Previous Loss 103.03933460588138:
# Prediction 1 (Hamlet):
# Hamlet his dime cos wowrmy, I's dwoshad,
#     Of Kern ther ke; as lery-earid caon hese to, hown is is not k
#
# Prediction 2 (To be):
# To be, as he thend; on I ickangh evot are bing bo thed pikenge oul bew; laoldeud, in now not sp. I koor,
#
#
# Prediction 3 (poison):
# poisonw, he soyn tomlagh'so ulle this to thort s he hat, that. Gors, Ven sir.
#
#   Hoare he taer o gath
#
# Prediction 4 (King):
# Kingaee] im the, whososs wert ow, nitor, ace, bnope whe meD dellier ur tomave st murtionhst yousd'theves
#
# Prediction 5 (Queen):
# Queentay shat wo serense-s shat the ho Him notolt ils dillo Lern, rolling to celd my dout; of deble matow
#
# *****************************************************************
# Epoch 8, Batch 21000, Previous Loss 97.48546273496339:
# Prediction 1 (Hamlet):
# Hamletrow, I dre sarlion
#     [  Prill of but he and eancy dad!
#   a mum.                Gurout with wiin I
#
# Prediction 2 (To be):
# To bes? Lame
#
#     A woox thear.     [prassenconer wiie, how rowtom I] sheygam. Tham.        E keet.
#   it
#
# Prediction 3 (poison):
# poison me,
#   ] Magk thelset be weln Les dewttis bove Eyt is hat spe harad'lminst whis.
# Tothand, pasim. [
#
# Prediction 4 (King):
# Kingaet. Frovt che of thenofted                  sule of a mr mong,
#     So mice hey,
#   Pot a sispe unhav
#
# Prediction 5 (Queen):
# Queenit ule Hogist theyils chuever pamy prinu?
#     Fors O blom
#     Wuolle allme mom hawgh,
#
#
# *****************************************************************
# Epoch 8, Batch 21500, Previous Loss 110.84715661456872:
# Prediction 1 (Hamlet):
# Hamlet.
#     Ley fis mic, her
#     What t'tare to ull hie wand.
#
#
#   Wet wes pam this that. Tam. Feries jodis
#
# Prediction 2 (To be):
# To bes
#   Heueentad weucastet oorce will Kied besere- I'd. So ther whit w    Les cougt. You nom. Mang wigt
#
# Prediction 3 (poison):
# poisonadh ty, pense you le hash dusen, in to dpesews Doven parlatim. Exouce kimes?
#     And for witt.
#     H
#
# Prediction 4 (King):
# Kingin pad aseate to now car. If on. No sofse stomyde.
#     I don- I sh's ouf but cous fas frit mnow
#
#
# Prediction 5 (Queen):
# Queens, ruldte
#     Now Stom afs thim of fat
#   [
#   Puting thiis her, a gik'd'd Ceypes not il memen, i
#
# *****************************************************************
# Finished 9 epoches, Loss: 105.25017512629891
# Epoch 9, Batch 22000, Previous Loss 91.33767348028451:
# Prediction 1 (Hamlet):
# Hamlet rarl a ft, not hatd youw is haont lath sill py gand thieud and the forarr,
#     it themprathar poom.
#
# Prediction 2 (To be):
# To ber this you rill wey. Hore,
#     Thing, men.                 bren?.
#     Ed)
#
#     Homrin hingtsens hers
#
# Prediction 3 (poison):
# poison ole com     it of lord mar. Bele mealt dot.                                   Madstinissey dlaint;
#
#
# Prediction 4 (King):
# Kinging. Nope she tuly wern the nilnme do, he. Aciste shy maont
#     Thas lore maesed Hath. This juad,
#
#
# Prediction 5 (Queen):
# Queen,
#       Or ridiss's cele mut.'
#     fol. achem delch wour's yome siis as'd.     Enell for and twigenm
#
# *****************************************************************
# Epoch 9, Batch 22500, Previous Loss 97.54418183786372:
# Prediction 1 (Hamlet):
# Hamlet maute now wee, ars th. grak'd.
#       I whuid bis'd desert tht thould I- crest maroblas!
#     Isd in
#
# Prediction 2 (To be):
# To bee a then-
#   Polor sror mee,
#     Hy sten
#
#     The me thar o'd id, we llefrak so be a
#
# Prediction 3 (poison):
# poisoniket hill of uist- I lovy dould on a llale binsy gover caden lyhess thitwe.
#     Ar shentaurcn's brin
#
# Prediction 4 (King):
# Kingwealtdn coven, mle.
#   Haody Pry, dentaks, beech virer, If her mach kookniver and- ras robd; powt for
#
# Prediction 5 (Queen):
# Queen coridel hablop ad thess shen ther!
#     For be, as pern igh st, brols in then. Bed keer of rem.
#
#
# *****************************************************************
# Epoch 9, Batch 23000, Previous Loss 90.71047084568863:
# Prediction 1 (Hamlet):
# Hamlet.
#     Thisle ofctonrck.
#   Hate norringanh you thind us hy in and mall, mars a-d they Haagt,
#
#  yid th
#
# Prediction 2 (To be):
# To being horathe fing,
#
#   Er on!
#     To my be's-seant ceen ae ll we thath his mey, dlage. Ther?
#   Ham. Th
#
# Prediction 3 (poison):
# poison thalt fatk ther lunkont shell how think is be hails a wh hit taave
#     O t'
#
#     Wigse'l lu kovet
#
# Prediction 4 (King):
# Kingano taand, thin woore of.
#       Naon uthmlurd. Brim
#   Olht; bloutw maset bott.
#            Shar co as
#
# Prediction 5 (Queen):
# Queen mloutsees hassay cotdinsme. Manchis yot
#          As ur whey wive.
#   Keam then wo wfe. Leald, lung's
#
# *****************************************************************
# Epoch 9, Batch 23500, Previous Loss 99.51085360240364:
# Prediction 1 (Hamlet):
# Hamletmase cont?
#   Hand, gy I thentam
#     And and batrow boods the thrilud. A kofs, whe so shithelard ferl
#
# Prediction 2 (To be):
# To bead what and heansing.
#   Had do yon if shae the do and boclicoud a in whes andsters Tin nor thear and
#
# Prediction 3 (poison):
# poisonsemen be in me thy:
#     Dedhte wigints Go             Se! ste wink.
#   Kittt letbe,
#     Kind. Was shi
#
# Prediction 4 (King):
# Kingans in In;
#     In you the proul; now of them. Thom wese thy dors it wiy hor bebece
#
#           for ge
#
# Prediction 5 (Queen):
# Queen!
#   Quer, therman! Is dow, for] Hinhed. And
#     Wour blantingd. I they no lhe lang ilchesteugh ie si
#
# *****************************************************************
# Finished 10 epoches, Loss: 105.18577738089994
# Epoch 10, Batch 24000, Previous Loss 103.10220728462201:
# Prediction 1 (Hamlet):
# Hamletd. Tans, to kver, matd,
#   ruld as do stes
#     Cn bod opould the wy anme nas.
#   '  Horned and mlonfe
#
# Prediction 2 (To be):
# To beadt serch Hake.
#
#     Lerrerse !
#   Hashcer. And, sinh somicote moe five if
#   Com. Mof m
#
# Prediction 3 (poison):
# poisonts thot I her honiterin'laeser com ach ilfis ar and,
#   Hate ard pe) Guer with-w. Give whor ard noess
#
# Prediction 4 (King):
# Kingtoten beV bernw rukre if cokhOs
#  Iat oastyeneerrn karind.
#     [Wofet. The on ived quinn calner hannt
#
# Prediction 5 (Queen):
# Queentisee bit it lrolg marerly!
#   Latd fos,
#     O as to kriy cuar.      '    Whe your to uistiils
#  Hamy
#
# *****************************************************************
# Epoch 10, Batch 24500, Previous Loss 107.6510368975578:
# Prediction 1 (Hamlet):
# Hamlet, maysps Dins the uch, dor. Camiss orOstadtris sar! (                           it
#            ! Hacl
#
# Prediction 2 (To be):
# To be--Thyeatiib tiul heald noth;
#       I, casingathap hinge, of hith ther.
#     'ther! This,
#     Tould bn
#
# Prediction 3 (poison):
# poison.
#     Lare'd's torkiche cad as gor. Whash whow of chatome ouf of ae Gheet, as is it fod witomoul ard
#
# Prediction 4 (King):
# King' visedte fish areave eom or ther inrthronke hie in thatick.
#   Hougerund!
#
#     So the
#
# Prediction 5 (Queen):
# Queen drerls pus cutrom.
#   Hask my liil dnessfar,         He to thelltor slmy. Do be.
# soles therss. Ther
#
# *****************************************************************
# Epoch 10, Batch 25000, Previous Loss 99.2792329955233:
# Prediction 1 (Hamlet):
# Hamlet moulle us is for; eade riseln Hamighasey, Is toull colck. Ties?
# HegsAet otay makn thestat Kiild men
#
# Prediction 2 (To be):
# To ber les, ie o dey a thais yow lutels of heest voor,
#     Enhe will on it
#
#   Cretpry to soase,
#     Suer
#
# Prediction 3 (poison):
# poisons
#       Noll diyne
#     Ads spels bmagere withere but the yir thit cee coor touk. Yeall my therent!
#
#
# Prediction 4 (King):
# Kingluculn thee cuorf,
#     Bout thee ut the youf waet weing or her, of lence ould favid.
#   Haeak sollese
#
# Prediction 5 (Queen):
# Queenavive
#     Or wafl end of this , I
#
#
#     Aif
#     By ne,
#     Himamens thew mave il a whowd. And suld b
#
# *****************************************************************
# Epoch 10, Batch 25500, Previous Loss 98.81469235164931:
# Prediction 1 (Hamlet):
# Hamlett see?
#   Ede then shis wnos ogto ubveor banct; magropcrel yowise oor tos?
#   Pret.           Quis fee
#
# Prediction 2 (To be):
# To bentiste nond,
#     Opebinks, mable wpes, you os ad, a a; bes tee thou..
#   Hamach. Lor. But thes.
#     W
#
# Prediction 3 (poison):
# poison moth sicvetrld as his fabee,
#     But that thend stiort of tine sosso;
#
#   fome to spe he blolsing sw
#
# Prediction 4 (King):
# King En ie of kofd coud? I me is eth. Hamerviontionach. We my, putm nite duat nos theit tirtserst. Whe r
#
# Prediction 5 (Queen):
# Queensesse the!
#
#     No bess maven.
#     Vom spt ete me thy cay lere youst mloune and couth. As, niins;
#
#
# *****************************************************************
# Epoch 10, Batch 26000, Previous Loss 108.12006253859495:
# Prediction 1 (Hamlet):
# Hamlet yat thto cet of mu, 'Frre,
#     Hak. For gr. Is enk feld whans be of nuth ne'sceyt thighin in to lfo
#
# Prediction 2 (To be):
# To beablate.                                 Puls in lis's, wer worel watk.
#
#     Aid'd.
#   Hall totrerc
#
# Prediction 3 (poison):
# poison of ster pan!
#     Conlis side thline earer. And to to the met;
#     Ham. The;
#
#
# Prediction 4 (King):
# Kinghe maint. I tithe Hake of hert' I thy'd his not shey. This open, thee-?
#       A pe frory at bour in
#
# Prediction 5 (Queen):
# Queen
#     Go.
#   Hak.
#   Gued sfir wasryol'dt!
#     Wees How nouch. Thosear wirt lu't.
#     A to, I
#     I cay
#
# *****************************************************************
# Finished 11 epoches, Loss: 105.16665513851129
# Epoch 11, Batch 26500, Previous Loss 104.04312544874617:
# Prediction 1 (Hamlet):
# Hamleteengers s'larhs thavtow thas my seienquen wisper,
#     Gulo, the garkenerr, shes, On to bid. Seys som
#
# Prediction 2 (To be):
# To beyst oas goutingI wof! Shit zo an ar why erars afereuln thilf onriy of of orsew hitrren thar hasmFall
#
# Prediction 3 (poison):
# poison so ich
#   Hoagighas both cringu ser andlour? Lace lim.
#   Lath comaly us goges blain For reral horor
#
# Prediction 4 (King):
# Kingo Ge cow in wettin in coy   You, Maverin.
#     Thesoup;
#   Erens. Frerorertpere wy so lich soQuttan qu
#
# Prediction 5 (Queen):
# Queen, thee dikt com.     Hather. Youlsens ller. Theud! Able ly;?
#     Hy to is hountink wnoasem bispoest.
#
# *****************************************************************
# Epoch 11, Batch 27000, Previous Loss 90.42514955796102:
# Prediction 1 (Hamlet):
# Hamlet?
#   En, Hayts Go Dectechon thon simae, Ho and Narlolone youn thaedbrasst u, comanter grom.
#   O,
#  So
#
# Prediction 2 (To be):
# To bey shountey
#  Deilg ophas, Is, I opowoun-.
#   Latd' lust wellmy gees a dranveg' duads, sheer iceer has.
#
# Prediction 3 (poison):
# poison ophaw!
#     To theese of opon. Topmey shall youce the lne. and.         ,
#     [e Hamysed, yon infts,
#
# Prediction 4 (King):
# Kingus, my vovely tomo, rough coam toont limase igr'len himu the so to, ost JuerBut, Marmrechet
#     Is s
#
# Prediction 5 (Queen):
# Queent..
#     Letees,
#   at bedem not a to do gae,
#     Ful. Butce mand that lle
#     And witg    Whtames wit
#
# *****************************************************************
# Epoch 11, Batch 27500, Previous Loss 95.75871475789539:
# Prediction 1 (Hamlet):
# Hamlethincirs, throm woor thar, I yyat wuse att
# Extublaseange lak.
#  WRit thad youf he the, hanc. [Is hy no
#
# Prediction 2 (To be):
# To bed and youredh orro gaud O, your
#  acw Korlet'thim herense siomh.].             Hall the tas haoks fan
#
# Prediction 3 (poison):
# poison; Giverrshe him
#     Theanmel the I and on thech kith'taey flomart-,
#  yor.
#
#
# Prediction 4 (King):
# Kingring.
#   nougty then- Pot thentrad to not fer he som'dse-st. Whwim of woflls. Les bets)t hie do ins r
#
# Prediction 5 (Queen):
# Queenk thizst the,
#       Hathit he rin thich muen iild, weld, fowl my Kchmy puel wisichit my theen
#     Or
#
# *****************************************************************
# Epoch 11, Batch 28000, Previous Loss 96.81094691191197:
# Prediction 1 (Hamlet):
# Hamlet nowe anep any doll lf comy mind my buth. As gheron kids rnes to thar hawgsaintitw, if bathbaghst gn
#
# Prediction 2 (To be):
# To bemilor Sermy my hithe lloons hit this in sotgo hutcead exc. Not kmom the mave Gacteinstt nopito
#     N
#
# Prediction 3 (poison):
# poison
#             you bin stouthar. I me wo es and crutris hatceald ky gall, but to in high spom. Thy.
#
#
# Prediction 4 (King):
# Kinghers but youe?
#   Ham this whwak.
#
#  'D.   Kealctid my the.       bupe ing?
#   Quals buporamyse Criy, a
#
# Prediction 5 (Queen):
# Queenthes.
#
#   Hamy po moen thast.
#   '
#
#     Fonte dell you to whalor
#
# *****************************************************************
# Epoch 11, Batch 28500, Previous Loss 95.43029347857109:
# Prediction 1 (Hamlet):
# Hamlet bese
#   Hit now nos whe.
#     Houndped. So hae. crour and beaks-
#
#             baancinking. Las clom,
#
#
# Prediction 2 (To be):
# To bek..                  , En
#   - wide all w  Ous hy thout whalson nos fatnset to of on
#     Foviste what
#
# Prediction 3 (poison):
# poison sing bed, sifs, and thee theen ilf shever.
#  mene hims of yooren
#       tour, me it nnotill.
#   Reell
#
# Prediction 4 (King):
# Kingow. So uing'dey llole. As ourn mowar grom el wh.
#                                 . A hert wijrese my
#
# Prediction 5 (Queen):
# Queens.
#     Soranget detre blar wall.
#     Fr machevent. A che momen's is teink and cour him in shing. My
#
# *****************************************************************
# Finished 12 epoches, Loss: 105.13386924046208
# Epoch 12, Batch 29000, Previous Loss 109.13068436172082:
# Prediction 1 (Hamlet):
# Hamlet thelitdon I samy't; wethy the,
#     toul sollon thet, of is killenes and hener I tceans.
#
#
# Prediction 2 (To be):
# To bedtinconas is to Hie, dortay ach. Whaon fing,        Deane de and brist rrar.
#       [The, so your bet
#
# Prediction 3 (poison):
# poisont me thive
#     Buth, n' ale Coornt dote goce clat's futl com pe,
#     Ope ur marlave mlense         w
#
# Prediction 4 (King):
# Kingard Wech hame           furr me owis yat, asvoug. Ot sostwTte friolarle on Losorcstow.
#   Hatfcerable
#
# Prediction 5 (Queen):
# Queentitwinte dre os mremas; theut st and march
#     But.] Masounkiste ce,
#     To as,
#     Whtirf afdriist.
#
# *****************************************************************
# Epoch 12, Batch 29500, Previous Loss 110.98738868095299:
# Prediction 1 (Hamlet):
# Hamlet
#       [Ento uifble seud bit. winverd. Yoles dnot ant.
#     I a win! Saly Guint) in Ghe.
#
# Prediction 2 (To be):
# To beangiin. Sher lion's taans gomlim. Fout prow igpencas.
#     is we; toufts ge, afse, of co'dw. I prenom
#
# Prediction 3 (poison):
# poisond any hy
#     Bolls.
#   Lats, out.
#   Hi'd alln's crouf tiene cy my laven, dongenk! Theramisesed- I wht
#
# Prediction 4 (King):
# Kingay, kis'le Exoeforay shy whamn seen
#     Os vor. You is eoudvew' red's, to rover, sool hens; beted yo
#
# Prediction 5 (Queen):
# Queengeriorg; her, theln, ofeld
#
#
#     I blim aliffe torolothe,
#     Anh the. Uf bram
#     O witry witheld,
#
# *****************************************************************
# Epoch 12, Batch 30000, Previous Loss 97.91946809407958:
# Prediction 1 (Hamlet):
# Hamlet ae the wonce. For. A, mave peyenFrfe whe. not. Ae, dill.
#
#     Rer? I vow moollam igdes I me ginke s
#
# Prediction 2 (To be):
# To bee howt hy him.
#   Hon' coe it doons heemear a coquap fort thiklad.
#
#     Oss and favid me. I aniverg
#
# Prediction 3 (poison):
# poisons gorasty thellsst. Otest to lut;
#    Co thenmy gee
#  [than lyorr ay lortall fuldt th. Furs and duots
#
# Prediction 4 (King):
# Kinglind theoland is kithe bry siex. sooncid withing, blaly, fouge w  [   docteadk. feyid thet. so lupai
#
# Prediction 5 (Queen):
# Queent. W'see lords thels maach sish?
#     Mile wengat, the
#     As be Luth?
#                         but of
#
# *****************************************************************
# Epoch 12, Batch 30500, Previous Loss 84.64908227640134:
# Prediction 1 (Hamlet):
# Hamlet in am wo oonrmy stit? Uf ther;
#    it yougue,
#     Thas.
#     A she she bit.. fongimest, fror.
#   Fe's
#
# Prediction 2 (To be):
# ...
# Kingseinc.
#       thaset yit it, il sceds woor. If donte but yas my, is I, do loms me maph chis, erd; as
#
# Prediction 5 (Queen):
# Queen
#     Swich,
#     Owtcor'd.
#  ouy shoutveas
#       A se.
#   Ost. Tser Put this or mlat, don, perer the ca
#
# *****************************************************************
# Epoch 20, Batch 50000, Previous Loss 116.14999724401899:
# Prediction 1 (Hamlet):
# Hamlethmiee muth, tow. Sufd'd brame swimarin,
#   . Our ky welyslans,
#     , giste hee hew. Wham. Andwe.
#
#
# Prediction 2 (To be):
# To beay do thesel alery nowtmay a is treak;
#     Gorly stey sheld?. Lachgy bam.
#     Ot ll redy buthanl ken
#
# Prediction 3 (poison):
# poisonf thomlee that hobel geenemers?
#   ard ther, town- gish. Anditris colllare both hoy cochee but I a
# fh
#
# Prediction 4 (King):
# Kingry ther, is
#     Yoush. Anh-Y onele
#          Let; in! Wey m? Thae o't King sisilcmin! jo' is borrt
#
# Y
#
# Prediction 5 (Queen):
# Queendet! put le
#     Polcriont. Haf, not
#     Ther'd
#     Theal
#   -herall seron'd the; oxhean. Bud so moofs
#
# *****************************************************************
# Finished 21 epoches, Loss: 105.10842949254506
# Epoch 21, Batch 50500, Previous Loss 107.91222128240393:
# Prediction 1 (Hamlet):
# Hamletives goe,
#   Buteanting sond ofy th shaprswaer as thares-.
#    '             Hywbee. Poun as paysanclr
#
# Prediction 2 (To be):
# To bey in
#     Mrops, dithse,
#     Gorund a'sen wh sinn
#   Hamse my bear fiboodis thy hare weadest witrall c
#
# Prediction 3 (poison):
# poison, and nos le tomy row a oo chin blommeod so toont.
#     TingeterteDat'd
#
#   Exangad my Hartitry a ther
#
# Prediction 4 (King):
# Kingacost
#     the ofow,
#   )f the boten gore                      uld uckyte hor. Bughens wongeees thall
#
# Prediction 5 (Queen):
# Queentt, com?
#   O wigtralte,
#     Whoses
#     Thack   Whe and the shitrew do, of Que-s surlire that feite r
#
# *****************************************************************
# Epoch 21, Batch 51000, Previous Loss 113.00774933679588:
# Prediction 1 (Hamlet):
# Hamlet puve toorrt koceret. Thit youtor thang an simn Rupeincrinsteree the.   Olr is last, ice him las, is
#
# Prediction 2 (To be):
# To bey senans.
#   '    We wiy durath lord) giry dogy can's en; shotrast ssell hiflim's alf so bull, and di
#
# Prediction 3 (poison):
# poisonhmich hollougtcern.
#         Priver.
#   it weeroubous whe hat iovighe hene iant:
#     Spernon weave you
#
# Prediction 4 (King):
# Kingackith i'd bist hey powthis glut of onrinot phedathe bast thertce arlankang't obharlo fispech-que
#
#
# Prediction 5 (Queen):
# Queencat whencet,
#     Mour, and fray lo, isty.
#     An
#                                                 fe
#
# *****************************************************************
# Epoch 21, Batch 51500, Previous Loss 107.67647545365814:
# Prediction 1 (Hamlet):
# Hamlet. Myoshal mare my hive onesew thiy he, ily?                     Glouk ount toud mofthe.
#     It os wh
#
# Prediction 2 (To be):
# To bey, he's bods- owalay bory fout afrar. Gueen then garh markird a viythis not
#     Most stat; from. Pou
#
# Prediction 3 (poison):
# poison pler inh thit gochaangach ell su'y delseof meceley the thing I dourn fuges of pagl feris onarr'd hi
#
# Prediction 4 (King):
# Kingost thith
#   [A the cliokhe        mankes. I
#     Thile live mf, fle wenren as the.
#           Kow. A w
#
# Prediction 5 (Queen):
# Queen?
#     Remy fat.
#     In it he feref? Hamy not wearnasmisly afe shaag!.
#   Hat, prom th's gof hiid.
#
#
# *****************************************************************
# Epoch 21, Batch 52000, Previous Loss 98.20783530021315:
# Prediction 1 (Hamlet):
# Hamlet serars in ave, thars gure bove?
#     Hamsn shet sworrpe Poln. My; sivlt atay, wifche of broullebfabq
#
# Prediction 2 (To be):
# To bes an be deterstate ders whiw Is linler guve) I a st be uf wise deathet! (Char to hing ilg cad,
#     t
#
# Prediction 3 (poison):
# poisontisinkdbeans bey nour. Thie.
#     Potrane fancief sitheld,
#     Elmingt. Is my-ramlow.
#
# Prediction 4 (King):
# Kingtine
#     Sutress wo id of he not,
#     As mow? Ye bes; on atvose lortpser her.
#     Yole if hasoe gull
#
# Prediction 5 (Queen):
# Queenstartike-; Quesence..
#   Keowon heneanteor and ay mion jut!
#   I'dtidif and withaygall so in inst cour
#
# *****************************************************************
# Epoch 21, Batch 52500, Previous Loss 99.31342313699177:
# Prediction 1 (Hamlet):
# Hamlet a geunravies, thmay ear kiliomiser
#     Ip wan
#     Surlay, ot if starce tallancen hinl- In teus duth
#
# Prediction 2 (To be):
# To bery tter ubprom. Thiengill'
#  ol thaen ais to my no doend.
#   Has?
#   How nirsive heal thost sist thes;
#
# Prediction 3 (poison):
# poisonispespacrom. Wh's nit. Afep thit it wirs hor bitwyiy ente thels and Fod woud poves,
#
#
# Prediction 4 (King):
# Kingy huth bitl muth lord; thore;
#     A ce. Harthaes thas: of cer, ched lron, to I hanbry?
#   Ourar bus a
#
# Prediction 5 (Queen):
# Queend, you. Promd his thes)
#                      '  Hamy. King
#   Osafl thathe
#     in a it therd your not
#
# *****************************************************************
# Finished 22 epoches, Loss: 105.09141437387662
# Epoch 22, Batch 53000, Previous Loss 89.5561317433649:
# Prediction 1 (Hamlet):
# Hamlet and ith frost Oudtale
#   Kerte.
#   How yon ders thathe reremeds opead,
# anlmake
#     That spes, you, of
#
# Prediction 2 (To be):
# To bee; grops. Sion pave i's
#   Lofccay , lorlerage tais goud doroud bech I with suof'e
#         Dand, hier
#
# Prediction 3 (poison):
# poisonts eld the rier, hitkanvey shus, thou, sull! In the eth. Nice hast thulscctseytithe the tie,
#
#
#
# Prediction 4 (King):
# Kingantt. Fis, wee jene formnas ouca) thend deorh'win ath' in [Enderine nile if tijace,
#     Ul  Hartese
#
# Prediction 5 (Queen):
# Queendte dutre yougly, fathse o diy four. Do is oorpe wo and tam.
#   Hotert ut he yod?
#
#
#   Hors os's thin
#
# *****************************************************************
# Epoch 22, Batch 53500, Previous Loss 103.65288795620326:
# Prediction 1 (Hamlet):
# Hamlett wise rusensee.
# fole hakn, lr tacs.
#     Osis?
#     Whs: bchedind bizgens our anlveufollurl! En
#     e
#
# Prediction 2 (To be):
# To ben thill sor gintraak le hithon
#     I tham.                                    Wh. Fuld hense; if ekn
#
# Prediction 3 (poison):
# poisont so seaon. And,
#     Whes I hecencer'd; hiileugge rouve thell gore endeld deal a. aved- Gors, that y
#
# Prediction 4 (King):
# Kingan,
#     ano whens a.
# nou what to,
#                              serger frevime dont omre
#
# Prediction 5 (Queen):
# Queend!! and rucemastaly ich.
#      Ere the our and hit I show pogem ial gadilme mlenecow lagh tht bite ag
#
# *****************************************************************
# Epoch 22, Batch 54000, Previous Loss 104.2634334324596:
# Prediction 1 (Hamlet):
# Hamlet gucoeve owt. Uedt lnot nyour thing siysad'd Deed, hy you howitosronter dpale
#       Frougeupckaant d
#
# Prediction 2 (To be):
# To be cire thang, I dashe arere hee, and u yoags heave
#  [avist wh comis! You stat, weand, ang henterates!
#
# Prediction 3 (poison):
# poison in gorstex shermed.
#   To ple so ary male deandss wigsonkese for erdrol yould of or su'sim.
#     Thak
#
# Prediction 4 (King):
# Kingurly ct fam. Mof lorday you is a'promt ony's the dito'd, you sish,
#       And it thile
#     Wht ekler;
#
# Prediction 5 (Queen):
# Queenmy whilsn cam.
#
#   Hame noss pe. And aflminst; lowtan, to, thace me tuup yowen rew hing.
#     Andsen g
#
# *****************************************************************
# Epoch 22, Batch 54500, Previous Loss 89.14174295006163:
# Prediction 1 (Hamlet):
# Hamletirh geen.
#   not qued wik. Lock hithe
#     This, hus.]
#
#     Put bot, aasurs.
#
#     I su dinh erom I
#
# Prediction 2 (To be):
# To benwower per'd! sam dh?
#   Hall puout. Migpem mad knoang.
#
#     Woorives gonrey?
#   Homang of luees;
#
#
# Prediction 3 (poison):
# poison,
#     Wigikenster cinl w oshe prill maveaveakee mato pprell easter, maep whas axge if ferile ser gun
#
# Prediction 4 (King):
# Kingurly the kim. Maul whak whaet for enkee, bt in wooe tauss
#     All sert bith.
#   Go
#
# Prediction 5 (Queen):
# Queen'pang hor.
#   . I' hit.
#   Lus himad ll beroe his wtotill wijediy higer bondevenst Cey not fur.
#
# *****************************************************************
# Epoch 22, Batch 55000, Previous Loss 94.95989242536027:
# Prediction 1 (Hamlet):
# Hamlet
#            a dere bork. I dethe, yous af lim sheroffr fuld. Ig tueer'd yolekeld zito?
#   Haodive
#   P
#
# Prediction 2 (To be):
# To beten pasers hatherd terir t in oor unow whalls as ror notsenth, firnmete, yee yilst ull. Slinr]
#     F
#
# Prediction 3 (poison):
# poison dlom quing and;
#     And thimirmem
#                  surtiscere unge so his but engn
#     And fam.
#
#
# Prediction 4 (King):
# Kinganh porteoid aid'tint,
#     The the- waspern thend) bite skase. To staysTopenim. Am tont. Youth. Hone
#
# Prediction 5 (Queen):
# Queenn
#   Hocd be thon brouls,
#
#   Hathacewsfrew Quty no rer; yole dan. Whee serray thour.
#   Ho ur yowe fee
#
# *****************************************************************
# Finished 23 epoches, Loss: 105.09224157966428
# Epoch 23, Batch 55500, Previous Loss 90.05875598969601:
# Prediction 1 (Hamlet):
# Hamleth, winge onisry atit thaet, yup,
#     Put thannt ul! Higo the hem Faeiz,
#
#
#   in
#   Hy lonlasstimr gaeg
#
# Prediction 2 (To be):
# To be you Youn wiry notom. Lan Ve a, wnok's barteudtend theunts, yofesse,
#
# That famarm ques Moch echw feu
#
# Prediction 3 (poison):
# poison, mysliy wead wis achis in. [Ding- gavely Haar hours hacisuge dele. and vermyiy botrer,
#     Hor?
#
#
# Prediction 4 (King):
# Kingand wo iif foled.
#     Wh
#       Erol pere tad, mutraolat ach Ound.
#     Fons, bisik. As hoaglam fors t
#
# Prediction 5 (Queen):
# Queen haledriy!
#   Cn, mat.
#
#  axborece and no!
#     Wealk anlathon ar daglals
#     Go oflowarr all fas I now
#
# *****************************************************************
# Epoch 23, Batch 56000, Previous Loss 99.43133122214637:
# Prediction 1 (Hamlet):
# Hamlet?
#     Ancente. winth ur gogy,
#  Gach abort, this fymy, a dimy thy ello thang
#       Pry ne.        Har
#
# Prediction 2 (To be):
# To bey loverer whoactamik, this thesce headsterBul fonts carr quey , the. o gach mam?.
#     Ther
#     Youra
#
# Prediction 3 (poison):
# poison a 'e, ad'd masoastaangiy thad ponte thedvet. A hialy       Owse mar spincef sissanh quer hey so so
#
# Prediction 4 (King):
# Kingutd'd at gogdinst weur lombrme ie dors oror im Poth bedighe if and sopimen.
#     Ws lak. Houtad, tret
#
# Prediction 5 (Queen):
# Queentt hor for and me hime I nosh-nas, whebly 'hinger's mageak quous pove.
#     Rowth a, fokinend hecour-
#
# *****************************************************************
# Epoch 23, Batch 56500, Previous Loss 95.93631658297255:
# Prediction 1 (Hamlet):
# Hamlet?
#     Nreunterst, wee morscel llef noulk malugout to but my fat! of the'd gaenn me to.
#   Othen he no
#
# Prediction 2 (To be):
# To be plumeupy bue thave lancer.
#
# Efdseew toser thes,
#     And wours wiytess] In rur
#     Thecers she so th
#
# Prediction 3 (poison):
# poison,
#     Gute maker.
#     ? The hast;
#                   Heuk the Lest in a eemable thave youllant I sle?
#
# Prediction 4 (King):
# Kingam wingisterptome thorom,
#     A, o veate, nege thes oshensuas you here you wike.
#
#
# stay ut my brow
#
# Prediction 5 (Queen):
# Queen ond sans wessach. Rot thive Go
#                   coarster crw.
#   E the lord?
#     Nase prow.
#     Tho
#
# *****************************************************************
# Epoch 23, Batch 57000, Previous Loss 86.52072758048097:
# Prediction 1 (Hamlet):
# Hamletoaf withost ie the yighien. Sol eaate nlend liar sw maagaes sousingagt ditry, ,
#     O, mor sh. Mase
#
# Prediction 2 (To be):
# To bee yhe thy ur po thouge in ly Sey nour. Of affik, yrief fam. Acan do] uaverem myserzif as ket?
#   Hor.
#
# Prediction 3 (poison):
# poisontout fije who
#     tall.
#
#
#   fooviot theuse to Deraysee's' bet maon, but sne sifl- not troste you?
#
#
# Prediction 4 (King):
# Kingbe mon. Masevtormat daveer serem ry wer.
#   Que tly noong this ie Bumy bouts then tiis withet. And iy
#
# Prediction 5 (Queen):
# Queens ble goms bromrer the gfol,
#       I?
#  Enom meur rus,
#     Than palre fage,
#     , lorl. Aw thewenth t
#
# *****************************************************************
# Epoch 23, Batch 57500, Previous Loss 100.99592374558027:
# Prediction 1 (Hamlet):
# Hamlet ore I but hanpd
#     thoem shornass. larh murlath sale weal.
#     A aset, rike I my, lo seact. tat to
#
# Prediction 2 (To be):
# To bey mant.
#     The kads, pace witdale
#     Les hath highmaveur andees, Haont, be yoretenart lance by pix
#
# Prediction 3 (poison):
# poison to and coll,
#     And.
#
#          Ot Langaols not oH ound I ich an th.- Luth. Thi's heat thif gare it
#
# Prediction 4 (King):
# Kingrim noth!
#   Ros fash; theyerit dourich my, rth wiell's tinh mee buth, ich theysinebp- be loem and ba
#
# Prediction 5 (Queen):
# Queence?
#   Er und
#     The is thex. Har, a
#       Exest.
#   Quing ar's Gheworer exseirh mast
#       Lised hiv
#
# *****************************************************************
# Finished 24 epoches, Loss: 105.03682587149629
# Epoch 24, Batch 58000, Previous Loss 75.61099827402207:
# Prediction 1 (Hamlet):
# Hamletrannow il dill, fe.
#   tot these and good high?.
#     And toals.
#   Go ched bnraviogead kilk, thol, co,
#
# Prediction 2 (To be):
# To beat. Or enganct Ro eain?
#   Four '    Rom and comlad that up I partier' I reke, an rachofowen
#     I po
#
# Prediction 3 (poison):
# poison
#       Atmy Quer mus.
#     And, wham ore fasse htoln de, is the ualfllouge co,
#  Gurdte sue. Tilk in b
#
# Prediction 4 (King):
# Kingans K opheenl and ass, to pomost?.
#  med I hinl per. Thans; ge' not
#   Hark,,
#     As gy couk botk a on
#
# Prediction 5 (Queen):
# Queenentoult. Mo thate in fith stiud. O a houf sente his you?
#   Hom. weedlude
#     Aof do biil goyt in sur
#
# *****************************************************************
# Epoch 24, Batch 58500, Previous Loss 65.45460711888634:
# Prediction 1 (Hamlet):
# Hamlet pe kuods thand lict, pisiind ar ared that, 'S        Poupnour and as his inceald an whe.
#
#     To
#
# Prediction 2 (To be):
# To be feald in
#   Swied fe'tenme, for thow desy ath,
#     I hey maged to my the he'teur weaks bes that cay
#
# Prediction 3 (poison):
# poison u her owing?
#   Haed lorinddt manst.                   Cich the sind, thounrefer Kilt is
#     Nachild
#
# Prediction 4 (King):
# Kingpe you.
#     Und, these- Qus keuld now Mual whopiorce.-fis mos.
#  ours.
#   Hards per you lordesl fut he
#
# Prediction 5 (Queen):
# Queener binh it thase. Wheste dolls ee Roon the I bnon bim.   Houe be deet pe. You latitor simete
#     To
#
# *****************************************************************
# Epoch 24, Batch 59000, Previous Loss 117.43212643517718:
# Prediction 1 (Hamlet):
# Hamletingead, hore is on farg. A.
#   Ham.
#   Had hor o- to doosiind; dill,
#   Kow, thae deund.
#       Weliof
# n
#
# Prediction 2 (To be):
# To bellive, par.
#     Andgeand chouquece
#
#   Ass thetheers ik., anmies,
#     prelde of mam. Bus o'd llour
#
# Prediction 3 (poison):
# poison.- Go theing's rare cyoreladen
#     Ham have, Fadt, a, no feaphiok pak
#       [Ass. (
#
# Prediction 4 (King):
# Kingusse end. sorneok me ie afente aik ptosen, fow sur, boschied moth; in meges, maderem?
#     cry me.
#
#
# Prediction 5 (Queen):
# Queent and ive,
#     Ort; ou. Ur stol malltamte
#   Pris I'd ut ing. The ganerey ste by jorer al
#
# *****************************************************************
# Epoch 24, Batch 59500, Previous Loss 107.79895899886148:
# Prediction 1 (Hamlet):
# Hamlet in thich Qut but liser sh, hithignubus bl me wios that te anlring thes toid, elanh'tht
#       Axn ha
#
# Prediction 2 (To be):
# To be loceay ste, boovesisilk.
#   Quing;
#     They Ko shi-cive her part,
#       Maten simarlat. Whe,
#     Yil
#
# Prediction 3 (poison):
# poisoncew.
#   Kit grad.
#   com.
#   Nat bather car th; to noacoserlchquemtinstt leog.
#            Ree, for fog.
#
# Prediction 4 (King):
# Kingyeley, bath of hanginrar.
# She?
#   Butch mish tring
#   Tht
#
#   Nothas whon,
#   Laind in
#
# Prediction 5 (Queen):
# Queen lo dhis,
#       Beriete that hang the fas! I be lith ur me theulfst ol thas hartas, is lord spe mo't
#
# *****************************************************************
