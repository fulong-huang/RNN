# %%
import numpy as np
import random

# To read the training data and make a vocabulary and dictiornary to index the chars
class DataReader:
    def __init__(self, path_en, path_de, len_en, len_de):
        self.len_en = len_en
        self.len_de = len_de
        try:
            fp_en = open(path_en, "r")
            fp_de = open(path_de, "r")
            data_en = fp_en.read()
            data_de = fp_de.read()
        except e:
            print(f"FAILED TO FILE\n {e.what()}")

        # split lines
        self.lines_en = data_en.split("\n")[:68930]
        self.lines_de = data_de.split("\n")[:68930]
        # find unique words
        word_set = set()
        for line in self.lines_en:
            for word in line.split():
                word_set.add(word)
        words_en = ['-'] + list(word_set)
        self.vocab_size_en = len(words_en)
        
        word_set = set()
        for line in self.lines_de:
            for word in line.split():
                word_set.add(word)
        words_de = ['-'] + list(word_set)
        self.vocab_size_de = len(words_de)
        
        # create dictionary mapping for each word
        self.word_to_ix_en = {w:i for (i,w) in enumerate(words_en)}
        self.ix_to_word_en = {i:w for (i,w) in enumerate(words_en)}
        
        self.word_to_ix_de = {w:i for (i,w) in enumerate(words_de)}
        self.ix_to_word_de = {i:w for (i,w) in enumerate(words_de)}

        # total data
        self.lines_total = len(self.lines_en)
        
        #num of unique words
        self.vocab_size_en = len(words_en)
        self.vocab_size_de = len(words_de)

        self.pointer = -1
        self.indices = [i for i in range(self.lines_total)]

        # close file
        fp_en.close()
        fp_de.close()

    # en -> 17 words max per line
    # fr -> 23 words max per line
    def next_batch(self):
        if self.pointer >= self.lines_total:
            self.pointer = -1
            random.shuffle(self.indices)
            return None, None
        inputs = [self.word_to_ix_en[w] for w in self.lines_en[self.indices[self.pointer]].split()]
        targets = [self.word_to_ix_de[w] for w in self.lines_de[self.indices[self.pointer]].split()]

        # padding
        # inputs += [0] * (self.len_en - len(inputs))
        targets += [0] * (self.len_de - len(targets))

        # increment and return
        self.pointer += 1
        return inputs, targets
        
    def get_first_10(self):
        inputs = []
        targets = []
        for i in range(10):
            inputs.append([self.word_to_ix_en[w] for w in self.lines_en[self.indices[i]].split()])
            tar = [self.word_to_ix_de[w] for w in self.lines_de[self.indices[i]].split()]
            tar += [0] * (self.len_de - len(tar))
            targets.append(tar)
            
        return inputs, targets

    
    def new_epoch(self):
        return self.pointer == -1
    def start_epoch(self):
        self.pointer = 0
    
    def validate_input(self, input):
        words = input.split()
        for word in words:
            if not word in self.word_to_ix_en:
                print(f"Word not found: {word}")
                return False
        return True

# %%
class Encoder:
    def __init__(self, hidden_size, vocab_size_en, seq_length, learning_rate):
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size_en
        self.learning_rate = learning_rate
        
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size_en), np.sqrt(1./vocab_size_en), (hidden_size, vocab_size_en))
        # self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size_de, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        # self.c = np.zeros((vocab_size_de, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        # self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        # self.mc = np.zeros_like(self.c)


    def forward(self, inputs):
        # xs, hs, os, ycap = {}, {}, {}, {}
        xs, hs = {}, {}
        hs[-1] = np.zeros((self.hidden_size, 1))
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size,1))
            xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
            hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
            # os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
            # ycap[t] = self.softmax(os[t]) # probs for next char
        # return xs, hs, ycap
        return xs, hs, hs[len(inputs) - 1]
   
    def backward(self, xs, hs, dhnext):
        # backward pass: compute gradients going backwards
        # dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        # dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        # db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
        dU, dW = np.zeros_like(self.U), np.zeros_like(self.W)
        db = np.zeros_like(self.b)
        # dhnext = np.zeros_like(hs[0])
        for t in reversed(range(len(hs) - 1)):
            #through softmax
            #dh includes gradient from two sides, next cell and current output
            dh = dhnext # backprop into h
            # backprop through tanh non-linearity 
            dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
            db += dhrec
            #calculate dU and dW
            dU += np.dot(dhrec, xs[t].T)
            dW += np.dot(dhrec, hs[t-1].T)
            #pass the gradient from next cell to the next iteration.
            dhnext = np.dot(self.W.T, dhrec)
        # clip to mitigate exploding gradients
        for dparam in [dU, dW, db]:
            np.clip(dparam, -5, 5, out=dparam) 
        return dU, dW,  db
    
    def update_model(self, dU, dW, db):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.b],
                                  [dU, dW, db],
                                  [self.mU, self.mW, self.mb]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update

    
    def predict(self, data_reader, input):

        #initialize input vector
        x = np.zeros((self.vocab_size, 1))
        words = input.split()
        ixes = []
        h = np.zeros((self.hidden_size, 1))
        for word in words:
            ix = data_reader.word_to_ix_en[word]
            x[ix] = 1
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            ixes.append(ix)
            x[ix] = 0
        return h

# %%
  
class Decoder:
    def __init__(self, hidden_size, vocab_size_de, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        
        self.vocab_size = vocab_size_de
        
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./self.vocab_size), np.sqrt(1./self.vocab_size), (hidden_size, self.vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (self.vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((self.vocab_size, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, hprev):
        xs, hs, os, ycap = {}, {}, {}, {}
        hs[-1] = np.copy(hprev)
        xs[0] = np.zeros((self.vocab_size, 1))
        for t in range(self.seq_length):
            hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
            os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
            ycap[t] = self.softmax(os[t]) # probs for next char

            ix = np.random.choice(range(self.vocab_size), p = ycap[t].ravel())
            xs[t+1] = np.zeros((self.vocab_size, 1))
            xs[t+1][ix] = 1
        return xs, hs, ycap
    def backward(self, xs, hs, ps, targets):
        # backward pass: compute gradients going backwards
        dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
        dhnext = np.zeros_like(hs[0])
        self.c += 1
        for t in reversed(range(self.seq_length)):
            dy = np.copy(ps[t])
            #through softmax
            dy[targets[t]] -= 1 # backprop into y
            #calculate dV, dc
            dV += np.dot(dy, hs[t].T)
            dc += dc
            #dh includes gradient from two sides, next cell and current output
            dh = np.dot(self.V.T, dy) + dhnext # backprop into h
            # backprop through tanh non-linearity 
            dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
            db += dhrec
            #calculate dU and dW
            dU += np.dot(dhrec, xs[t].T)
            dW += np.dot(dhrec, hs[t-1].T)
            #pass the gradient from next cell to the next iteration.
            dhnext = np.dot(self.W.T, dhrec)
        # clip to mitigate exploding gradients
        for dparam in [dU, dW, dV, db, dc]:
            np.clip(dparam, -5, 5, out=dparam)
        return dU, dW, dV, db, dc, dhnext

    def loss(self, ps, targets):
        """loss for a sequence"""
        # calculate cross-entrpy loss
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
    def predict(self, data_reader, h):
        #initialize input vector
        x = np.zeros((self.vocab_size, 1))
        ixes = []

        for t in range(self.seq_length):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            # p = np.exp(y)/np.sum(np.exp(y))
            p_shift = np.exp(y - np.max(y))
            p = p_shift/p_shift.sum(axis=0)
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size,1))
            x[ix] = 1
            ixes.append(ix)
        txt = ' '.join(data_reader.ix_to_word_de[i] for i in ixes)
        return txt

# %%
class Translator:
    def __init__(self, hidden_size_en, hidden_size_de, \
                 vocab_size_en, vocab_size_de, \
                 seq_length_en, seq_length_de, \
                 learning_rate_en, learning_rate_de):
        # hyper parameters
        self.hidden_size_en = hidden_size_en
        self.hidden_size_de = hidden_size_de
        self.vocab_size_en = vocab_size_en
        self.vocab_size_de = vocab_size_de
        self.seq_length_en = seq_length_en
        self.seq_length_de = seq_length_de
        self.learning_rate_en = learning_rate_en
        self.learning_rate_de = learning_rate_de
        # encoder / decoder
        self.encoder = Encoder(hidden_size = hidden_size_en, \
                               vocab_size_en = vocab_size_en, \
                               seq_length = seq_length_en, \
                               learning_rate = learning_rate_en)
        self.decoder = Decoder(hidden_size = hidden_size_de, \
                               vocab_size_de = vocab_size_de, \
                               seq_length = seq_length_de, \
                               learning_rate = learning_rate_de)
        
        
    def forward(self, inputs):
        xs_en, hs_en, last_hs = self.encoder.forward(inputs)
        xs_de, hs_de, ycap_de = self.decoder.forward(last_hs)

        return xs_en, hs_en, xs_de, hs_de, ycap_de
        
        
    def backward(self, xs_en, xs_de, hs_en, hs_de, ps_de, targets):
        dU_de, dW_de, dV_de, db_de, dc_de, dh = self.decoder.backward(xs_de, hs_de, ps_de, targets)
        dU_en, dW_en, db_en = self.encoder.backward(xs_en, hs_en, dh)
        return dU_en, dW_en, db_en, dU_de, dW_de, dV_de, db_de, dc_de
        
    
    def loss(self, ps, targets):
        """loss for a sequence"""
        # calculate cross-entrpy loss
        # ps_len = len(ps)
        # tar_len = len(targets)
        # if ps_len > tar_len:
        #     targets = targets + np.zeros((self.vocab_size, 1))*(ps_len - tar_len)
        # elif ps_len < tar_len:
        #     ps = ps + np.zeros((self.vocab_size, 1))*(tar_len - ps_len)
            
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length_de))
        
    
    def update_model(self, dU_en, dW_en, db_en, dU_de, dW_de, dV_de, db_de, dc_de):
        self.encoder.update_model(dU_en, dW_en, db_en)
        self.decoder.update_model(dU_de, dW_de, dV_de, db_de, dc_de)
        


    def train(self, data_reader, threshold = 0.01, epoch=100):
        iter_num = 1
        
        while epoch != 0:
            data_reader.start_epoch()
            inputs, targets = data_reader.next_batch()
            while not data_reader.new_epoch():
                xs_en, hs_en, xs_de, hs_de, ps_de = self.forward(inputs)
                dU_en, dW_en, db_en, dU_de, dW_de, dV_de, db_de, dc_de = \
                            self.backward(xs_en, xs_de, hs_en, hs_de, ps_de, targets)
                loss = self.loss(ps_de, targets)
                self.update_model(dU_en, dW_en, db_en, dU_de, dW_de, dV_de, db_de, dc_de)
                
                inputs, targets = data_reader.next_batch()

            if iter_num % 1 == 0:
                i, t = data_reader.get_first_10()
                total_loss = 0
                for idx in range(len(i)):
                    _, _, _, _, y_h = self.forward(i[idx])
                    total_loss += self.loss(y_h, t[idx])
                    
                print(f"========== Epoch {iter_num} completed, average first 10 loss: {total_loss / 10} ==========")
                text_to_translate = "new jersey is sometimes quiet during autumn , and it is snowy in april ."
                if data_reader.validate_input(text_to_translate):
                    print(f"ENG: {text_to_translate}")
                    print(self.predict(data_reader, text_to_translate))
                text_to_translate = "the united states is usually chilly during july , and it is usually freezing in november ."
                if data_reader.validate_input(text_to_translate):
                    print(f"ENG: {text_to_translate}")
                    print(self.predict(data_reader, text_to_translate))
                print()

            iter_num += 1
            epoch -= (epoch >= 0)

    def predict(self, data_reader, input):
        h = self.encoder.predict(data_reader, input)
        result = self.decoder.predict(data_reader, h)
        return result

# %%
input_file_name_en = "small_vocab_en.txt"
input_file_name_de = "small_vocab_fr.txt"

seq_length_en = 24
seq_length_de = 24

#read text from the "input.txt" file
data_reader = DataReader(input_file_name_en, input_file_name_de, seq_length_en, seq_length_de)

valid_words = [k for k in data_reader.word_to_ix_en.keys()]
valid_words.sort()
print(valid_words)
print(len(valid_words))
# Out:
# [',', '-', '.', '?', 'a', 'am', 'and', 'animal', 'animals', 'apple', 'apple.', 'apples', 'apples.', 'april', 'are', "aren't", 'august', 'automobile', 'autumn', 'banana', 'banana.', 'bananas', 'bananas.', 'bear', 'bears', 'beautiful', 'been', 'between', 'big', 'bird', 'birds', 'black', 'blue', 'busy', 'but', 'california', 'car', 'cat', 'cats', 'chilly', 'china', 'chinese', 'cold', 'december', 'did', "didn't", 'difficult', 'dislike', 'disliked', 'dislikes', 'do', 'does', 'dog', 'dogs', 'drives', 'driving', 'drove', 'dry', 'during', 'easy', 'eiffel', 'elephant', 'elephants', 'english', 'fall', 'favorite', 'favorite.', 'feared', 'february', 'field', 'football', 'france', 'freezing', 'french', 'fruit', 'fruit.', 'fun', 'go', 'going', 'grape', 'grape.', 'grapefruit', 'grapefruit.', 'grapes', 'grapes.', 'green', 'grocery', 'has', 'have', 'he', 'her', 'his', 'horse', 'horses', 'hot', 'how', 'i', 'in', 'india', 'is', "isn't", 'it', "it's", 'january', 'jersey', 'july', 'june', 'lake', 'last', 'least', 'lemon', 'lemon.', 'lemons', 'lemons.', 'like', 'liked', 'liked.', 'likes', 'lime', 'lime.', 'limes', 'limes.', 'lion', 'lions', 'little', 'loved', 'loved.', 'mango', 'mango.', 'mangoes', 'mangoes.', 'march', 'may', 'mice', 'might', 'mild', 'monkey', 'monkeys', 'most', 'mouse', 'my', 'never', 'new', 'next', 'nice', 'november', 'october', 'old', 'orange', 'orange.', 'oranges', 'oranges.', 'our', 'paris', 'peach', 'peach.', 'peaches', 'peaches.', 'pear', 'pear.', 'pears', 'pears.', 'plan', 'plans', 'pleasant', 'portuguese', 'quiet', 'rabbit', 'rabbits', 'rainy', 'red', 'relaxing', 'rusty', 'saw', 'school', 'september', 'shark', 'sharks', 'she', 'shiny', 'snake', 'snakes', 'snowy', 'sometimes', 'spanish', 'spring', 'states', 'store', 'strawberries', 'strawberries.', 'strawberry', 'strawberry.', 'summer', 'that', 'the', 'their', 'they', 'think', 'thinks', 'this', 'to', 'tower', 'translate', 'translating', 'truck', 'united', 'usually', 'visit', 'want', 'wanted', 'wants', 'warm', 'was', 'we', 'weather', 'went', 'were', 'wet', 'when', 'where', 'white', 'why', 'winter', 'wonderful', 'would', 'yellow', 'you', 'your']
# 228

# %%
# hidden_size_en = 300
# hidden_size_de = 300
# learning_rate_en = 0.009
# learning_rate_de = 0.009


# rnn = Translator(hidden_size_en, hidden_size_de, \
#                  data_reader.vocab_size_en, data_reader.vocab_size_de, \
#                  seq_length_en, seq_length_de, \
#                  learning_rate_en = learning_rate_en, learning_rate_de = learning_rate_de)

hidden_size_en = 300
hidden_size_de = 300
learning_rate_en = 0.009
learning_rate_de = 0.009


rnn = Translator(hidden_size_en, hidden_size_de, \
                 data_reader.vocab_size_en, data_reader.vocab_size_de, \
                 seq_length_en, seq_length_de, \
                 learning_rate_en = learning_rate_en, learning_rate_de = learning_rate_de)
              
# rnn.train(data_reader)

# %%
rnn.train(data_reader, epoch = -1)
# Out:
# ========== Epoch 1 completed, average first 10 loss: 34.16428653980186 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# l' jersey est gÃ©nÃ©ralement agrÃ©able en mois de mars il il agrÃ©able est pamplemousse janvier . . - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est le au en avril , il il est son chaud jamais avril . - - - - - - prÃ©fÃ©rÃ© -
#
# ========== Epoch 2 completed, average first 10 loss: 22.011560456374795 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement occupÃ© le l' Ã©tÃ© , il et fait Ã parfois mars . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est jamais froid en l' , mais et fait est pluvieux en fÃ©vrier . - - - - - - - -
#
# ========== Epoch 3 completed, average first 10 loss: 27.670125163693093 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois calme au mois rendre et aoÃ»t est merveilleux en froid en - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois enneigÃ©e en octobre , octobre il est parfois doux en mai . - - - - - - - -
#
# ========== Epoch 4 completed, average first 10 loss: 22.755996671934856 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# l' france est habituellement enneigÃ©e en septembre de , il est merveilleux en hiver Ã froid . - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# la Ã©tats-unis est gÃ©nÃ©ralement de en avril , et il est parfois doux Ã septembre . - - - - - - - -
#
# ========== Epoch 5 completed, average first 10 loss: 25.50728882522717 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois chaude Ã septembre automne aoÃ»t il , il doux au septembre printemps . . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# california est est relaxant au au fÃ©vrier , et il est gÃ©nÃ©ralement enneigÃ©e en juin . - - - - - - - -
#
# ========== Epoch 6 completed, average first 10 loss: 19.028011674061467 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est jamais merveilleux au septembre de aoÃ»t il , est en en en - d' . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est habituellement froid en dÃ©cembre , et il est gÃ©nÃ©ralement sec en janvier . - - - - - - - -
#
# ========== Epoch 7 completed, average first 10 loss: 16.942805015468913 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# l' jersey est jamais occupÃ© en en de , , est est en printemps . juillet - . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est relaxant pendant en juillet , mars il est gÃ©nÃ©ralement merveilleux Ã novembre . - - - - - - - -
#
# ========== Epoch 8 completed, average first 10 loss: 21.599798140892876 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement calme en printemps , mais il est merveilleux en janvier . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# california Ã©tats-unis est gÃ©nÃ©ralement enneigÃ©e en l'automne , mais il est relaxant habituellement au l' . - - - - - - - -
#
# ========== Epoch 9 completed, average first 10 loss: 29.062729401002365 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois agrÃ©able en automne , mais il , chaud en en en . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# california Ã©tats-unis est parfois occupÃ©e aime juillet , et il est jamais agrÃ©able en dÃ©cembre . . - - - - - - -
#
# ========== Epoch 10 completed, average first 10 loss: 25.666051650332644 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est relaxant clÃ©mentes en cours , et il est sec au fÃ©vrier . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# californie Ã©tats-unis est gÃ©nÃ©ralement occupÃ© en avril , mais il est gÃ©nÃ©ralement merveilleux en dÃ©cembre automne - - - - - - - -
#
# ========== Epoch 11 completed, average first 10 loss: 23.902010603807497 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement merveilleux en mai , , il est pleut en doux . . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois tranquille en juin , et il gÃ¨le jamais relaxant en mai automne - - - - - - - -
#
# ========== Epoch 12 completed, average first 10 loss: 17.162267977420026 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est fait agrÃ©able en printemps , et il est chaud agrÃ©able automne automne - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est jamais chaud en dÃ©cembre , mais il est jamais agrÃ©able en avril . - - - - - - - -
#
# ========== Epoch 13 completed, average first 10 loss: 19.883320237572917 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement agrÃ©able au l' , et il est il en printemps . en - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois Ã en fÃ©vrier , mais il est jamais agrÃ©able en l' . - - - - - - - -
#
# ========== Epoch 14 completed, average first 10 loss: 23.90681857131264 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# l' jersey est relaxant merveilleux Ã cours automne novembre il est relaxant en aoÃ»t - octobre . - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois humide en hiver , mais il est gÃ©nÃ©ralement frisquet en avril . - - - - - - - -
#
# ========== Epoch 15 completed, average first 10 loss: 13.066718437801892 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois chaud au mars , , il et il en froid . Ã©tÃ© juin - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois humide en mai , mais , est est est en hiver hiver hiver - - - - - - -
#
# ========== Epoch 16 completed, average first 10 loss: 18.79504179841361 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est jamais humide en l' d' mais , est est beau hiver . - novembre - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est jamais occupÃ© en juillet , et il est parfois le gel . Ã©tÃ© - - - - - - - -
#
# ========== Epoch 17 completed, average first 10 loss: 15.455952083469194 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est jamais merveilleux au printemps automne l' , pleut merveilleux en avril . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement occupÃ© en octobre , mais il est jamais doux Ã mai . - - - - - - - -
#
# ========== Epoch 18 completed, average first 10 loss: 15.920313018342998 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement doux en dÃ©cembre , et il est agrÃ©able il humide automne juillet - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement doux en avril , mais il est parfois chaud Ã juin automne - . - - - - - -
#
# ========== Epoch 19 completed, average first 10 loss: 15.945940767508352 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# l' jersey est habituellement froid pendant l' , mais automne , en en fÃ©vrier en - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est jamais pluvieux en juin , mais il mais parfois chaud en aoÃ»t automne . - - - - - - -
#
# ========== Epoch 20 completed, average first 10 loss: 16.92652794637237 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement chaud au l'automne mois l' il , est en en janvier . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois doux au juin , mais il est gÃ©nÃ©ralement agrÃ©able gel . l' en - - - - - - -
#
# ========== Epoch 21 completed, average first 10 loss: 10.737261252130187 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement tranquille Ã cours , , Ã est est en mars avril . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement calme sec dÃ©cembre , et il est jamais en en Ã automne . - - - - - - -
#
# ========== Epoch 22 completed, average first 10 loss: 23.373628301395385 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement pluvieux au allÃ© de l' mais , il il est octobre avril aoÃ»t - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est merveilleux pluvieux en juin , et il est jamais relaxant au l' automne . - - - - - - -
#
# ========== Epoch 23 completed, average first 10 loss: 14.291165482133167 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois Ã au cours automne l' l' et chaud est en automne . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois beau au dÃ©cembre , et il gÃ¨le jamais printemps en l' juin . aoÃ»t - - - - - -
#
# ========== Epoch 24 completed, average first 10 loss: 16.086616832292652 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement doux Ã l'automne de , il il et sec est . en - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois doux en juillet , et il l' jamais merveilleux en beau automne - - - - - - - -
#
# ========== Epoch 25 completed, average first 10 loss: 16.89621994592691 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois merveilleux en l' , mais mais est est occupÃ© juin . - . - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est jamais occupÃ© en avril , et est est parfois jamais Ã juillet automne . - - - - - - -
#
# ========== Epoch 26 completed, average first 10 loss: 10.850821792263922 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois merveilleux au l' de l' automne , beau en en . l' octobre - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est relaxant occupÃ©e en dÃ©cembre , mais il est jamais agrÃ©able mai . automne - - - - - - - -
#
# ========== Epoch 27 completed, average first 10 loss: 16.742968421997837 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois occupÃ© pendant novembre de l' mais , neigeux en est . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois froid au janvier , et il est parfois en novembre au . - - - - - - - -
#
# ========== Epoch 28 completed, average first 10 loss: 15.942367449015943 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement merveilleux en l'automne de , il est gÃ©nÃ©ralement il en printemps - - . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement tranquille en fÃ©vrier , et il est jamais en en en - . - - - - - - -
#
# ========== Epoch 29 completed, average first 10 loss: 17.18879418161396 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois merveilleux au cours , l' il , doux il humide . en - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement tranquille en janvier , et il est jamais ne froid en juillet - - - - - - - -
#
# ========== Epoch 30 completed, average first 10 loss: 11.330854819446511 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois agrÃ©able Ã l'automne , novembre il est occupÃ© il en Ã au - . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement merveilleux en octobre , et il est jamais en gÃ©nÃ©ralement en . - - - - - - - -
#
# ========== Epoch 31 completed, average first 10 loss: 13.914544767671993 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois pluvieux au l'automne de l' il il est agrÃ©able juin aoÃ»t - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est occupÃ© doux au avril , mais il est jamais chaude jamais en - . - - - - - - -
#
# ========== Epoch 32 completed, average first 10 loss: 11.348039483731851 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois agrÃ©able pendant cours , , automne est humide froid beau chaud en - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est relaxant habituellement en juillet , et il gÃ¨le habituellement en sec en automne - - - - - - - -
#
# ========== Epoch 33 completed, average first 10 loss: 17.651882627554794 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois froid la l'automne , et il gÃ¨le humide janvier juin . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement cours en juillet , mais il gÃ¨le jamais en printemps . mai - - - - - - - -
#
# ========== Epoch 34 completed, average first 10 loss: 11.674660102629293 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois chaud Ã l' l'automne mais mais il est Ã avril merveilleux . l' - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois agrÃ©able en fÃ©vrier , et il jamais gÃ©nÃ©ralement en dÃ©cembre . . . - - - - - - -
#
# ========== Epoch 35 completed, average first 10 loss: 20.65711618911738 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement occupÃ© Ã cours automne , et il en en en Ã©tÃ© - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois sec en avril , mais il est relaxant merveilleux en en Ã©tÃ© - - - - - - - -
#
# ========== Epoch 36 completed, average first 10 loss: 13.608056872609106 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois agrÃ©able au cours automne et automne , merveilleux relaxant il novembre . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis gÃ©nÃ©ralement gÃ©nÃ©ralement chaud en avril , et jamais de habituellement relaxant Ã . - - - - - - - - -
#
# ========== Epoch 37 completed, average first 10 loss: 11.419456225821296 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement froid au l' automne , automne il , il printemps hiver - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement pluvieux en avril , mais il il parfois Ã agrÃ©able avril mai . - - - - - - -
#
# ========== Epoch 38 completed, average first 10 loss: 16.147278563311055 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est relaxant sÃ¨che en l'automne de et et est pleut froid est . - janvier - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois chaud en octobre , et il ne jamais pendant enneigÃ©e en avril . - - - - - - -
#
# ========== Epoch 39 completed, average first 10 loss: 12.591896542288065 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois doux en cours automne l' automne , et il gÃ¨le en . - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est beau chaud en printemps , mais il des jamais en neige en automne . - - - - - - -
#
# ========== Epoch 40 completed, average first 10 loss: 19.619441441135123 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois frisquet au automne , , il , et il dÃ©cembre juin . printemps - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois merveilleux en dÃ©cembre , et il est jamais enneigÃ©e janvier . hiver . - - - - - - -
#
# ========== Epoch 41 completed, average first 10 loss: 15.77280825643606 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement merveilleux au cours automne , l' , pluvieux il en . en . - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement agrÃ©able en juillet , et il est jamais occupÃ© agrÃ©able en - . - - - - - - -
#
# ========== Epoch 42 completed, average first 10 loss: 10.602924091038268 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois chaud Ã cours de l' il est relaxant neigeux est chaud au aoÃ»t . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les californie est occupÃ© froid janvier janvier , et il jamais jamais en en en mars - - - - - - - -
#
# ========== Epoch 43 completed, average first 10 loss: 17.50281728103322 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement occupÃ© au cours , mais mai il humide en pluvieux septembre - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement belle en avril , et il est neige de aoÃ»t en - . - - - - - - -
#
# ========== Epoch 44 completed, average first 10 loss: 23.17083180229837 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est relaxant sÃ¨che pendant printemps automne l' automne , mais en est relaxant . juillet . - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est belle humide en avril , et jamais gÃ¨le jamais de jamais . - . - - - - - - -
#
# ========== Epoch 45 completed, average first 10 loss: 12.191102839370464 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement doux pendant l' , , automne , et il Ã©tÃ© octobre - janvier - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois beau en octobre , et il ne jamais jamais gel en septembre . - - - - - - -
#
# ========== Epoch 46 completed, average first 10 loss: 12.034879359494562 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement chaud pendant de , l' il , chaud en avril . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois beau en septembre , mais il gÃ¨le jamais en juin . - - - - - - - - -
#
# ========== Epoch 47 completed, average first 10 loss: 13.379942056683655 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois occupÃ© au l'automne , mais il est calme en Ã©tÃ© . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est parfois agrÃ©able en janvier , mais il ne parfois froid hiver en hiver . - - - - - - -
#
# ========== Epoch 48 completed, average first 10 loss: 12.079239053748232 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois occupÃ© au cours , l' il gÃ¨le relaxant Ã est . - - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement sec en avril , mais il gÃ¨le froid en froid . Ã©tÃ© - - - - - - - -
#
# ========== Epoch 49 completed, average first 10 loss: 16.17121195753642 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est gÃ©nÃ©ralement pluvieux au novembre , et il est froid en octobre . en - - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est gÃ©nÃ©ralement agrÃ©able en janvier , et il est jamais en janvier . - - - - - - - - -
#
# ========== Epoch 50 completed, average first 10 loss: 13.633050647969398 ==========
# ENG: new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois froid Ã cours automne et automne il parfois pleut est avril - mai - - - - - - -
# ENG: the united states is usually chilly during july , and it is usually freezing in november .
# les Ã©tats-unis est relaxant merveilleux en juin , et jamais gÃ¨le mais en juillet . - - - - - - - - -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 rnn.train(data_reader, epoch = -1)
#
# Cell In[4], line 65, in Translator.train(self, data_reader, threshold, epoch)
#      63 inputs, targets = data_reader.next_batch()
#      64 while not data_reader.new_epoch():
# ---> 65     xs_en, hs_en, xs_de, hs_de, ps_de = self.forward(inputs)
#      66     dU_en, dW_en, db_en, dU_de, dW_de, dV_de, db_de, dc_de = \
#      67                 self.backward(xs_en, xs_de, hs_en, hs_de, ps_de, targets)
#      68     loss = self.loss(ps_de, targets)
#
# Cell In[4], line 28, in Translator.forward(self, inputs)
#      26 def forward(self, inputs):
#      27     xs_en, hs_en, last_hs = self.encoder.forward(inputs)
# ---> 28     xs_de, hs_de, ycap_de = self.decoder.forward(last_hs)
#      30     return xs_en, hs_en, xs_de, hs_de, ycap_de
#
# Cell In[3], line 34, in Decoder.forward(self, hprev)
#      32 xs[0] = np.zeros((self.vocab_size, 1))
#      33 for t in range(self.seq_length):
# ---> 34     hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
#      35     os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
#      36     ycap[t] = self.softmax(os[t]) # probs for next char
#
# KeyboardInterrupt:

# %%
text_to_translate = "new jersey is sometimes quiet during autumn , and it is snowy in april ."
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))
text_to_translate = "the united states is usually chilly during july , and it is usually freezing in november ."
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))
# Out:
# visiter Ã©tÃ© rendre proches notre intention pourrait Ã‰tats-unis - Ã‰tats-unis rendre grosse sur aimeraient notre intention - - - - - - - -
# aiment-ils beau blanche redoutÃ©e mouillÃ©e Ã‰tats-unis aimÃ©e mouillÃ©e oranges rendre limes neige poires serpent poires - - - - - - - - -

# %%
# Out:
# (348, 1)

# %%
text_to_translate = "our least liked fruit is the lemon , but my least liked is the grape ."
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))
# Out:
# notre moins aimÃ© des fruits est pamplemousse raisin mais mais mais aimÃ© moins moins la . - - - - - - - -

# %%
text_to_translate = "california is usually hot during december , and it is never dry in autumn . "
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))

text_to_translate = "california is usually hot during december , and it is never dry in autumn . "
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))

text_to_translate = "california is usually hot during december , and it is never dry in autumn . "
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))

text_to_translate = "california is usually hot during december , and it is never dry in autumn . "
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))

text_to_translate = "california is usually hot during december , and it is never dry in autumn . "
if data_reader.validate_input(text_to_translate):
    print(rnn.predict(data_reader, text_to_translate))
# Out:
# californie est gÃ©nÃ©ralement calme en avril , mais il est fait Ã gel l' automne l' - - - - - - - -
# californie est jamais enneigÃ©e en juillet , mais il est jamais froid Ã l' l' automne - - - - - - - -
# california est jamais occupÃ© en avril , et il est jamais Ã Ã l' automne automne - - - - - - - -
# californie est gÃ©nÃ©ralement chaude en juin , et il est jamais Ã Ã l' automne . - - - - - - - -
# californie est gÃ©nÃ©ralement pluvieux en juillet , et il est jamais Ã Ã Ã automne hiver - - - - - - - -

# %%
# np.savetxt("encoder_U.out", rnn.encoder.U)
# np.savetxt("encoder_W.out", rnn.encoder.W)
# np.savetxt("encoder_b.out", rnn.encoder.b)


# np.savetxt("decoder_U.out", rnn.decoder.U)
# np.savetxt("decoder_V.out", rnn.decoder.V)
# np.savetxt("decoder_W.out", rnn.decoder.W)
# np.savetxt("decoder_b.out", rnn.decoder.b)
# np.savetxt("decoder_c.out", rnn.decoder.c)

# %%
rnn.encoder.U = np.loadtxt("encoder_U.out")
rnn.encoder.W = np.loadtxt("encoder_W.out")
rnn.encoder.b = np.loadtxt("encoder_b.out")
rnn.encoder.b = np.reshape(rnn.encoder.b, (rnn.encoder.b.size, 1))

rnn.decoder.U = np.loadtxt("decoder_U.out")
rnn.decoder.V = np.loadtxt("decoder_V.out")
rnn.decoder.W = np.loadtxt("decoder_W.out")
rnn.decoder.b = np.loadtxt("decoder_b.out")
rnn.decoder.c = np.loadtxt("decoder_c.out")
rnn.decoder.b = np.reshape(rnn.decoder.b, (rnn.decoder.b.size, 1))
rnn.decoder.c = np.reshape(rnn.decoder.c, (rnn.decoder.c.size, 1))

# %%
rnn.decoder.b.shape
# Out:
# (300, 1)
